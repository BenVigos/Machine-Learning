# %%
import keras
import pickle
from matplotlib import pyplot as plt
from dicewars.match import Match
from dicewars.game import Game
from dicewars.player import AgressivePlayer, RandomPlayer
from playergroupLocal import Player  # Import the agent
import matplotlib.pyplot as plt
from IPython.display import clear_output
import numpy as np
# %matplotlib notebook

# %%
model = keras.models.load_model("dqn_model_1.keras")
model.summary()

with open("training_data_1.pkl", "rb") as f:
    training_data = pickle.load(f)

# See what's inside
print(type(training_data))
print(training_data.keys() if isinstance(training_data, dict) else training_data)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │        13,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 900)            │        58,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 228,494 (892.56 KB)
#  Trainable params: 76,164 (297.52 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 152,330 (595.04 KB)
# <class 'dict'>
# ...

# %%
plt.plot(training_data['losses'])
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.show()

plt.plot(training_data['reward_history'])
plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)


plt.show()

# %%
model_2 = keras.models.load_model("dqn_model_2.keras")
model_2.summary()

with open("training_data_2.pkl", "rb") as f:
    training_data_2 = pickle.load(f)

# See what's inside
print(type(training_data_2))
print(training_data_2.keys() if isinstance(training_data_2, dict) else training_data_2)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │        13,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 900)            │        58,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 228,494 (892.56 KB)
#  Trainable params: 76,164 (297.52 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 152,330 (595.04 KB)
# <class 'dict'>
# ...

# %%
plt.plot(training_data_2['losses'])
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.show()

plt.plot(training_data_2['reward_history'])
plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)


plt.show()

# %%
model_3 = keras.models.load_model("dqn_model_3.keras")
model_3.summary()

with open("training_data_3.pkl", "rb") as f:
    training_data_3 = pickle.load(f)

# See what's inside
print(type(training_data_3))
print(training_data_3.keys() if isinstance(training_data_3, dict) else training_data_3)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 64)             │        13,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 900)            │        58,500 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 228,494 (892.56 KB)
#  Trainable params: 76,164 (297.52 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 152,330 (595.04 KB)
# <class 'dict'>
# ...

# %%
import numpy as np 
# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_3['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
rewards = training_data_3['reward_history']
x_reward = np.arange(len(rewards))

# Reward plot
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: 3.075414595435299e-05

# %%
model_4 = keras.models.load_model("dqn_model_4.keras")
model_4.summary()

with open("training_data_4.pkl", "rb") as f:
    training_data_4 = pickle.load(f)

# See what's inside
print(type(training_data_4))
print(training_data_4.keys() if isinstance(training_data_4, dict) else training_data_4)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 22)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         1,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,848 (73.63 KB)
#  Trainable params: 6,282 (24.54 KB)
# ...

# %%
import numpy as np 
# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_4['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
rewards = training_data_4['reward_history']
x_reward = np.arange(len(rewards))

# Reward plot
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: 0.006437623762376214

# %%
# Plot of data from Ben 
with open("training_data_from_ben.pkl", "rb") as f:
    training_data_from_ben = pickle.load(f)

# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_from_ben['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
rewards = training_data_from_ben['reward_history']
x_reward = np.arange(len(rewards))

# Reward plot
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: 0.0036410441044104364

# %%
# Plot of data from Ben 
with open("training_data_simplereward.pkl", "rb") as f:
    training_data_simplereward = pickle.load(f)

# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_simplereward['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()
rewards = training_data_simplereward['reward_history']
x_reward = np.arange(len(rewards))

# Reward plot
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: 0.0013515151515151485

# %%
# Plot of data 1 layer - 64 
with open("training_data_1_hidden_layer-64.pkl", "rb") as f:
    training_data_1_hidden_layer_64 = pickle.load(f)

# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_1_hidden_layer_64['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()

# Reward plot
rewards = training_data_1_hidden_layer_64['reward_history']
x_reward = np.arange(len(rewards))
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: 0.005641044104410438

# %%
# Plot of data 2 layers - 32 32
with open("training_data_model_2_hidden_layers-32-32.pkl", "rb") as f:
    training_data_2_hidden_layers_32_32 = pickle.load(f)

# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_2_hidden_layers_32_32['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()

# Reward plot
rewards = training_data_2_hidden_layers_32_32['reward_history']
x_reward = np.arange(len(rewards))
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: -0.002100690069006863

# %%
# Plot of data 1 layer - 64, 500 episodes, epsilon non 0
with open("training_data_1_hidden_layer-64-500episodes.pkl", "rb") as f:
    training_data_1_hidden_layer_64_500episodes = pickle.load(f)

# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_1_hidden_layer_64_500episodes['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()

# Reward plot
rewards = training_data_1_hidden_layer_64_500episodes['reward_history']
x_reward = np.arange(len(rewards))
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: 0.0002516357265429031

# %%
# training_data_1_hidden_layer-64-500episodes_v2

# Plot of data 1 layer - 64, 500 episodes, v2
with open("training_data_1_hidden_layer-64-500episodes_v2.pkl", 'rb') as f:
    training_data_1_hidden_layer_64_500episodes_v2 = pickle.load(f)

# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_1_hidden_layer_64_500episodes_v2['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()

# Reward plot
rewards = training_data_1_hidden_layer_64_500episodes_v2['reward_history']
x_reward = np.arange(len(rewards))
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: -5.2110928443714e-05

# %%
# training_data_1_hidden_layer-64-500episodes_v2 lower epsilon 
filename ="training_data_1_hidden_layer-64-500_lower_eps.pkl" 

# Plot of data 1 layer - 64, 500 episodes, v2
with open(filename, 'rb') as f:
    training_data_1_hidden_layer_64_500episodes_v2 = pickle.load(f)

# Loss plot
# Define the window size for the moving average
window_size = 50  # You can tweak this based on how smooth you want the curve

losses = training_data_1_hidden_layer_64_500episodes_v2['losses']
x_loss = np.arange(len(losses))

# Compute moving average
if len(losses) >= window_size:
    moving_avg = np.convolve(losses, np.ones(window_size)/window_size, mode='valid')
    x_moving_avg = np.arange(window_size - 1, len(losses))
else:
    moving_avg = losses
    x_moving_avg = x_loss

# Plot
plt.plot(x_loss, losses, label="Raw Loss")
plt.plot(x_moving_avg, moving_avg, label=f"Moving Avg ({window_size})", color="orange")
plt.title("Training Loss")
plt.xlabel("Steps")
plt.ylabel("Loss")
plt.yscale("log")
plt.grid(True)
plt.legend()
plt.show()

# Reward plot
rewards = training_data_1_hidden_layer_64_500episodes_v2['reward_history']
x_reward = np.arange(len(rewards))
plt.plot(x_reward, rewards, label="Reward")
if len(rewards) > 1:
    coeffs_reward = np.polyfit(x_reward, rewards, deg=1)
    fit_reward = np.poly1d(coeffs_reward)(x_reward)
    plt.plot(x_reward, fit_reward, "--", color="orange", label="Best Fit")

plt.title("Reward Over Time")
plt.xlabel("Episodes")
plt.ylabel("Reward")
plt.grid(True)
plt.legend()
plt.show()
print("Reward slope:", coeffs_reward[0])
# Out:
# Reward slope: 0.0006326958107832425
