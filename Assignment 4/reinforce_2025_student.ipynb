# %% [markdown]
# # Large Notebook 3: Reinfocement Learning
# ## Ex. 3: Control problem MountainCar-v0
#
# In the exercise class we will cover the control problem of a car at the bottom of a valley which should pick-up enough momentum to get over the hill. We will use the environment from the OpenAI Gym, which allows you to play and visualize the 'game'. Use RL to train a policy that gets the car over the hill in the least amount of time.
#
# **Before you can start this exercise you have to install the package OpenAI Gym. Start your anaconda environment with python3 and install:**
#
# * pip install gymnasium[classic-control]

# %%
# UNCOMMENT IF GYMNASIUM FAILS TO IMPORT
# %pip install gymnasium[classic-control]

import gymnasium as gym
import numpy as np
import random
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# If you have properly installed the openAI gym you should be able to import it. We will now run a DEMO to see if everything is working. The code already is able to simulate the MountainCar problem for the case that it actions are **random**. To be able to view the rendered video of the poor and helpless car, desperately trying to drive up the hill, you should run the code on your own computer.
# For more info on this particular environment see e.g. the website: https://gymnasium.farama.org/environments/classic_control/mountain_car/

# %%
def demo():
    """run the MountainCar environment with random actions"""
    
    env = gym.make('MountainCar-v0', render_mode='human')  #  create an instance of the environment

    state = env.reset()  # reset the current game

    for _ in range(200):  # play 200 random actions
        env.render()  # render the current game state to screen
        a = env.action_space.sample()  # get a random action
        state, reward, terminated, truncated, info = env.step(a) # take the action and return the outcome
        
    env.close()
    
# run the demo
demo()

# %% [markdown]
# ## Building your RL player, ie. training your policy.
# We have to start by creating the game environment and checking some properties of the state and action space:

# %%
env = gym.make('MountainCar-v0')  # no rendering!

# get usefull information about the environment:
state = env.reset()
print('start state:', state)
print('Number of sctions in the action space:', env.action_space.n)
print('Lowest state in the state space:', env.observation_space.low)
print('Hightest state in the state space:', env.observation_space.high)

#perform one step of the game for action a=1
a=1
state, reward, terminated, truncated, info = env.step(a)
print('After the step with (a=1):',state, reward, terminated, truncated, info )
# Out:
# start state: (array([-0.4002321,  0.       ], dtype=float32), {})
# Number of sctions in the action space: 3
# Lowest state in the state space: [-1.2  -0.07]
# Hightest state in the state space: [0.6  0.07]
# After the step with (a=1): [-0.40113637 -0.00090427] -1.0 False False {}

# %% [markdown]
# We see that the car starts out in state with two floats [-0.525, 0] (as it initializes random these numbers will differ each time you reset). You can perform any of 3 actions (a = 0 or 1 or 2). We don't know what the numbers in the state mean, they could be the $x$, $y$ coordinates of the car or the velocity and height, but **we also don't have to know!** We will let the RL algortithm learn how to drive the car regardless of the exact meaning of the state.
#
# You should now code a function `s2q(s)` that links state `s` to a location in the Q-matrix. This can quickly be done by discretizing the state space into bins and determine the bin number corresponding to a certain value. The function should return a tuple (or list) `loc` that holds the two bin numbers.

# %%
def s2q(s, num_bins_x = 20, num_bins_y = 20):
    # convert continous state values to discrete location indices inside the Q matrix
    
    x = s[0]
    bins_x = np.linspace(env.observation_space.low[0], env.observation_space.high[0], num_bins_x)

    y = s[1]
    bins_y = np.linspace(env.observation_space.low[1], env.observation_space.high[1], num_bins_y)

    loc = [np.digitize(x, bins_x), np.digitize(y, bins_y)]

    return loc

print(s2q(np.array([0.6, 0.065])))
# Out:
# [19, 19]

# %% [markdown]
# The next function `qlearn()` should train your Q-matrix by playing `num_games` games according to an 'epsilon-greedy' strategy (Google it!) and update the Q-matrix accoding to the following Bellmann equation:
#
# $$ \mathbf{Q}^{\rm new}[s_t,a_t]=(1-\alpha)\mathbf{Q}[s_t,a_t]+\alpha\left(R_t+\gamma\, \text{max}_a  \mathbf{Q}[s_{t+1},a]\right). $$
#
# Here, $\alpha$ is the learning rate and $\gamma$ is the discount factor and are bounded by $\alpha,\gamma\in[0,1]$. These parameters have to be set with care, as they influence the speed of convergence of the Q-matrix. The discount factor lets you weigh the importance of future over immediate rewards. This is done by mixing-in the term $\text{max}_a  \mathbf{Q}[s_{t+1},a]$, which gives the maximum Q value in the future state.

# %%
def qLearn(Q, α, γ, ϵ, ϵ_min, num_games):
    """ 
    learns the Q table by interacting with the environment and applying the Bellman eqation 
    Q: q-table (n-dimensional ndarray)
    α: learning rate
    γ: discount factor
    ϵ: probability of taking a random action in the epsilon-greedy policy
    ϵ_min: minimum value ϵ can take when applying a reduction algortihm to ϵ
    """
    wins = 0
    for _ in range(0, num_games):
        s = env.reset()[0]  # reset the current game
        s = s2q(s)
        won = False
        max_iterations = 1000
        current_iteration = 0
        
        while current_iteration != max_iterations and not won:
            p = random.random()
            if p > ϵ:
                a = np.argmax(Q[s[0]][s[1]])
            else: 
                a = env.action_space.sample() # get a random action
            new_s, reward, won, _, _ = env.step(a) # take the action and return the outcome
            new_s = s2q(new_s)
            Q[s[0]][s[1]][a] = (1-α) * Q[s[0]][s[1]][a] + α*(reward + γ * np.max(Q[new_s[0]][new_s[1]]))
            current_iteration = current_iteration + 1
            s = new_s
        if won:
            wins = wins + 1
    
        ϵ = max(ϵ_min, 0.9 * ϵ)

    print(f'Training ended. Number of wins: {wins}')
    return wins

# %% [markdown]
# Finally you put everything together. It is almost completly finished for you. What values for the hyperparameters do you choose?

# %%
# initialize the Q matrix as a numpy array with zeros
Q = np.zeros(shape=(20, 20, 3))

# set the hyperparameters
α = 0.5  # learning rate [0,1]
γ = 0.5  # discount rate [0,1]
ϵ = 0.5  # epsilon greedy strategy [0,1]
ϵ_min = 0.01  # minimu value of epsilon [0,1]
num_games = 100 # number of training games

# train the agent and store results
qLearn(Q, α, γ, ϵ, ϵ_min, num_games)
np.save('qrun1.npy', Q)
# Out:
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -0.875
# -1.15625
# -1.296875
# -1.15625
# -1.15625
# -1.3671875
# -1.4375
# -1.3671875
# -1.525390625
# -1.525390625
# -1.2626953125
# -0.5
# -0.5
# -0.5
# -0.5
# -0.875
# -1.0625
# -0.875
# -0.875
# -1.15625
# -1.15625
# -1.296875
# -1.3671875
# -1.3671875
# -1.5078125
# -1.47265625
# -1.525390625
# -1.6044921875
# -1.630859375
# -1.64404296875
# -1.703369140625
# -1.72314453125
# -1.7330322265625
# -1.77752685546875
# -1.7923583984375
# -1.799774169921875
# -1.844268798828125
# -1.8331451416015625
# -1.844268798828125
# -1.8748588562011719
# -1.8832015991210938
# -1.8984966278076172
# -1.8832015991210938
# -1.920048713684082
# -1.9124011993408203
# -1.9270009994506836
# -1.9124011993408203
# -1.9343008995056152
# -1.9435126781463623
# -1.9400365352630615
# -1.9507256746292114
# -1.9550274014472961
# -1.9576345086097717
# -1.9630442559719086
# -1.966270551085472
# -1.9709307551383972
# -1.9682258814573288
# -1.798809103667736
# -1.447021484375
# -1.5828857421875
# -1.578125
# -1.67041015625
# -1.64404296875
# -1.687164306640625
# -1.7330322265625
# -1.7528076171875
# -1.7653732299804688
# -1.8159446716308594
# -1.799774169921875
# -1.8380889892578125
# -1.814605712890625
# -1.8609542846679688
# -1.8619585037231445
# -1.8785667419433594
# -1.9045219421386719
# -1.8957157135009766
# -1.9133474826812744
# -1.8964688777923584
# -1.9223516583442688
# -1.928391456604004
# -1.9350106120109558
# -1.9447836428880692
# -1.9220940973609686
# -1.849106827750802
# -1.946389647666365
# -1.8868301208131015
# -1.9449023540364578
# -1.957172907772474
# -1.9441587072215043
# -1.9437868838140275
# -1.9151225906098261
# -1.9363419429573696
# -1.9522564572180272
# -1.9578401628605206
# -1.9641923429135204
# -1.9713893983998787
# -1.9749879261430578
# -1.9678796808293555
# -1.9683801221453905
# -1.9759097606220166
# -1.9762850916090429
# -1.9812409446072934
# -1.9819323204665125
# -1.9822138187067821
# -1.9862763963850796
# -1.98593070845547
# -1.9866603640300866
# -1.9894480313416025
# -1.9898992811113132
# -1.9897072972888097
# -1.992086023506202
# -1.9922804729666073
# -1.993615056761132
# -1.9935178320309292
# -1.992424460833485
# -1.9949136435889372
# -1.9943183456251137
# -1.995138374023197
# -1.9957387592188351
# -1.996185232691703
# -1.9968772098516507
# -1.9966539731152169
# -1.9963537805173979
# -1.9972653353880485
# -1.9977961609728285
# -1.9980615737652185
# -1.9974904798364128
# -1.9976579073887382
# -1.9982015736534722
# -1.9981178598773095
# -1.9985743233799593
# -1.9985461803239137
# -1.9988375551033477
# -1.9986511802401041
# -1.9989096352429354
# -1.9990815726117
# -1.9989883851800783
# -1.9991822264322017
# -1.9992412888850586
# -1.999311179458775
# -1.9994162010505798
# -1.9993866698241511
# -1.9994833845940811
# -1.9995400023681134
# -1.9995621507879349
# -1.999612538445561
# -1.999655001776085
# -1.9996968069197643
# -1.999671613090951
# -1.9997412513320638
# -1.9997885289387698
# -1.9997537098182132
# -1.9997726051898232
# -1.9998326919239382
# -1.99981528236366
# -1.9998294538923673
# -1.999861461772745
# -1.999873709435061
# -1.9998942181906223
# -1.9998720904192755
# -1.9998960963295587
# -1.9999040678144566
# -1.9999206636429667
# -1.999922072247169
# -1.9999363487750976
# -1.9999280508608424
# -1.9999415541853767
# -1.999952789807899
# -1.9999460381456318
# -1.999960482097724
# -1.9999522615813232
# -1.999959528609224
# -1.9999678296999428
# -1.9999641961859924
# -1.9999703615732929
# -1.9999762298331445
# -1.9999791639630704
# -1.9999731471394941
# -1.9999758722749572
# -1.9999798603546206
# -1.9999838982460496
# -1.999981904206218
# -1.9999843729723028
# -1.9999874251745793
# -1.9999864281546635
# -1.999988279729227
# -1.9999898211159977
# -1.9999905688809343
# -1.9999912097969204
# -1.9999923658369982
# -1.9999938251387328
# -1.9999929266607008
# -1.9999934073476902
# -1.9999946949955256
# -1.9999950555107677
# -1.9999953688540497
# -1.9999963581759062
# -1.9999962015042652
# -1.9999960212466443
# -1.9999971843996143
# -1.9999975975114683
# -1.9999970159349831
# -1.9999971511281989
# -1.9999977619512372
# -1.9999978633461493
# -1.9999981981336012
# -1.99999853955461
# -1.999998321463428
# -1.9999986265682512
# -1.999998397509612
# -1.999998798132209
# -1.9999989046659574
# -1.9999991089750415
# -1.9999989699261884
# -1.9999990985991567
# -1.9999992274446412
# -1.9999993883721099
# -1.9999993239493676
# -1.999999331731281
# -1.9999994968529824
# -1.9999994929620257
# -1.9999995412790823
# -1.9999996438800476
# -1.499999821940024
# -0.5
# -0.75
# -0.875
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -0.875
# -1.15625
# -1.15625
# -1.15625
# -1.3671875
# -1.3671875
# -1.5586485243402421
# -1.9415705730207264
# -1.948093220591545
# -1.9546345248818398
# -1.9417637437582016
# -1.9561779297655448
# -1.9563228078186512
# -1.9668200351297855
# -1.4834100175648928
# -0.5
# -0.5
# -0.75
# -0.875
# -0.5
# -0.875
# -0.875
# -1.15625
# -1.15625
# -0.9375
# -0.5
# -0.75
# -0.875
# -0.5
# -0.875
# -0.875
# -1.15625
# -1.15625
# -1.15625
# -1.3671875
# -1.18359375
# -0.5
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -0.875
# -1.15625
# -1.15625
# -1.312499955485006
# -1.874999701966019
# -1.4374998509830095
# -0.8593749627457523
# -1.2187499254915046
# -0.5
# -1.0546874813728762
# -0.875
# -1.15625
# -1.15625
# -1.2910156110296571
# -1.3671875
# -1.3671875
# -1.4682617082722427
# -1.525390625
# -1.5759277291361213
# -1.6044921875
# -1.525390625
# -1.6044921875
# -1.621121137170121
# -1.525390625
# -1.525390625
# -1.6919082248350605
# -1.64404296875
# -1.64404296875
# -1.7330322265625
# -1.77752685546875
# -1.799774169921875
# -1.7330322265625
# -1.7689311686262954
# -1.799774169921875
# -1.755318088704371
# -1.848169766832143
# -1.6125575131736696
# -1.7094181348802522
# -1.9054434986028355
# -1.7820636011601891
# -1.6254068005800946
# -1.203125
# -1.3671875
# -1.3671875
# -1.40234375
# -1.525390625
# -1.525390625
# -1.5517578125
# -1.64404296875
# -1.64404296875
# -1.56494140625
# -1.3671875
# -1.380859375
# -1.3671875
# -1.525390625
# -1.525390625
# -1.53564453125
# -1.64404296875
# -1.64404296875
# -1.6517333984375
# -1.322021484375
# -0.5
# -0.5
# -0.875
# -0.875
# -0.875
# -1.15625
# -1.2265625
# -1.3671875
# -1.3671875
# -1.4843749666137547
# -1.525390625
# -1.525390625
# -1.2626953125
# -0.5
# -0.5
# -0.75
# -0.875
# -0.9375
# -0.5
# -0.75
# -0.5
# -0.5
# -0.875
# -0.75
# -0.5
# -0.75
# -0.5
# -0.5
# -0.875
# -1.0
# -0.75
# -0.5
# -0.5
# -0.75
# -0.75
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -0.9375
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -0.9375
# -0.5
# -0.5
# -0.75
# -0.875
# -0.9375
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -0.75
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -0.9375
# -0.5
# -0.5
# -0.96875
# -1.296875
# -1.33203125
# -1.3671875
# -1.15625
# -1.499267578125
# -1.447021484375
# -1.62445068359375
# -1.58526611328125
# -1.6833190834503138
# -1.613281224960316
# -1.292633056640625
# -0.96875
# -0.5
# -0.875
# -0.875
# -1.15625
# -1.203125
# -1.2890625
# -1.0625
# -1.0625
# -1.15625
# -1.296875
# -1.296875
# -1.3671875
# -1.3359375
# -1.125
# -1.1875
# -1.25
# -1.0625
# -1.359375
# -1.296875
# -1.25
# -0.9375
# -0.625
# -0.875
# -1.15625
# -1.203125
# -1.203125
# -1.09375
# -0.875
# -1.265625
# -1.3515625
# -1.15625
# -1.0625
# -1.09375
# -0.875
# -0.875
# -1.15625
# -1.3287353515625
# -1.469970703125
# -1.0625
# -1.25
# -1.15625
# -1.15625
# -1.4140625
# -1.203125
# -0.875
# -1.15625
# -1.1875
# -1.15625
# -1.3828125
# -1.078125
# -0.5
# -0.875
# -0.875
# -1.203125
# -1.15625
# -1.2265625
# -1.3671875
# -1.2496337890625
# -0.5
# -0.5
# -0.75
# -0.5
# -0.75
# -0.875
# -0.5
# -0.5
# -0.75
# -0.71875
# -1.15625
# -1.3671875
# -1.3671875
# -1.14453125
# -0.5
# -0.5
# -0.75
# -1.07421875
# -1.47265625
# -1.501953125
# -1.578125
# -1.2509765625
# -0.8125
# -1.4375
# -1.47265625
# -1.55859375
# -1.51953125
# -1.6044921875
# -1.416015625
# -1.03125
# -0.96875
# -1.171875
# -1.109375
# -1.3359375
# -1.203125
# -1.46875
# -1.40234375
# -1.53515625
# -1.1015625
# -0.5
# -0.5
# -0.75
# -0.875
# -0.5
# -0.7734375
# -1.43780517578125
# -1.3203125
# -1.3671875
# -1.490234375
# -1.30859375
# -0.875
# -1.0625
# -0.875
# -1.0390625
# -1.390625
# -1.3671875
# -1.525390625
# -1.5546875
# -1.54296875
# -1.546875
# -1.30859375
# -1.078125
# -0.76953125
# -1.0390625
# -0.7890625
# -1.078125
# -0.5
# -0.76953125
# -1.37109375
# -1.455078125
# -1.0390625
# -0.5
# -0.5
# -0.5
# -0.875
# -0.875
# -1.125
# -1.0625
# -1.0625
# -0.875
# -1.0625
# -1.03125
# -0.5
# -0.5
# -0.875
# -0.875
# -0.859375
# -0.5
# -0.5
# -1.037109375
# -0.5
# -0.875
# -1.0625
# -1.25
# -1.250244140625
# -1.438232421875
# -1.18359375
# -0.5
# -0.90625
# -1.30712890625
# -1.2080078125
# -0.802001953125
# -1.581298828125
# -1.604248046875
# -1.406005859375
# -1.4608154296875
# -1.34375
# -1.2734375
# -1.4140625
# -1.33203125
# -1.447265625
# -1.326171875
# -1.49462890625
# -1.372314453125
# -1.01171875
# -1.0625
# -0.875
# -1.15625
# -1.271484375
# -1.3583984375
# -1.4814453125
# -1.6001739501953125
# -1.4638671875
# -1.15625
# -1.279296875
# -1.296875
# -1.52099609375
# -1.2734375
# -0.5
# -0.5
# -0.5
# -0.75
# -0.5
# -0.875
# -1.1298828125
# -1.0771484375
# -0.89453125
# -0.5
# -1.009765625
# -1.279296875
# -1.419921875
# -1.1396484375
# -0.5
# -0.875
# -0.875
# -1.203125
# -1.296875
# -1.4140625
# -1.296875
# -1.28125
# -1.234375
# -1.15625
# -1.15625
# -1.3671875
# -1.29296875
# -1.14453125
# -1.15625
# -1.15625
# -1.072265625
# -0.5
# -1.00927734375
# -1.0185546875
# -0.5
# -0.5
# -0.5
# -0.75
# -0.75
# -0.5
# -1.0
# -0.75
# -0.5
# -0.5
# -0.875
# -0.75
# -0.5
# -0.5
# -0.5
# -0.75
# -0.5
# -0.5
# -0.75
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.75
# -0.5
# -0.5
# -0.5
# -0.75
# -0.875
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.75
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.5
# -0.625
# -1.0
# -0.9736328125
# -1.1708984375
# -1.307861328125
# -1.347412109375
# -1.2987060546875
# -0.75
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 12
#       9 num_games = 100 # number of training games
#      11 # train the agent and store results
# ---> 12 qLearn(Q, α, γ, ϵ, ϵ_min, num_games)
#      13 np.save('qrun1.npy', Q)
#
# Cell In[19], line 24, in qLearn(Q, α, γ, ε, ε_min, num_games)
#      22 else:
#      23     a = env.action_space.sample() # get a random action
# ---> 24 new_s, reward, won, _, _ = env.step(a) # take the action and return the outcome
#      25 new_s = s2q(new_s)
#      26 print((1-α) * Q[s[0]][s[1]][a] + α*(reward + γ * np.max(Q[new_s[0]][new_s[1]])))
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:125, in TimeLimit.step(self, action)
#     112 def step(
#     113     self, action: ActType
#     114 ) -> tuple[ObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     115     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#     116
#     117     Args:
#    (...)
#     123
#     124     """
# --> 125     observation, reward, terminated, truncated, info = self.env.step(action)
#     126     self._elapsed_steps += 1
#     128     if self._elapsed_steps >= self._max_episode_steps:
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\classic_control\mountain_car.py:153, in MountainCarEnv.step(self, action)
#     151 self.state = (position, velocity)
#     152 if self.render_mode == "human":
# --> 153     self.render()
#     154 # truncation=False as the time limit is handled by the `TimeLimit` wrapper added during `make`
#     155 return np.array(self.state, dtype=np.float32), reward, terminated, False, {}
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\classic_control\mountain_car.py:272, in MountainCarEnv.render(self)
#     270 if self.render_mode == "human":
#     271     pygame.event.pump()
# --> 272     self.clock.tick(self.metadata["render_fps"])
#     273     pygame.display.flip()
#     275 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %% [markdown]
# Once a Q-matrix has been trained we can use it as a policy and play a game. Write code that performs actions according to the input Q-matrix to play a single episode.

# %%
# replay the game using the trained Q matrix
Q = np.load('qrun1.npy')

# create and reset the environment with render mode on
env = gym.make('MountainCar-v0', render_mode='human')
state = env.reset()[0]  
    
# play a single episode with max. 1000 actions
for _ in range(1000):           
    env.render()                
    loc = s2q(state)
    a = np.argmax(Q[loc[0]][loc[1]]) 
    state, reward, terminated, truncated, info = env.step(a) 
        
    if terminated: 
        print('Qplay Output:', reward, terminated, truncated, info)
        break

env.close()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 10
#       8 # play a single episode with max. 1000 actions
#       9 for _ in range(1000):
# ---> 10     env.render()
#      11     loc = s2q(state)
#      12     a = np.argmax(Q[loc[0]][loc[1]])
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:409, in OrderEnforcing.render(self)
#     404 if not self._disable_render_order_enforcing and not self._has_reset:
#     405     raise ResetNeeded(
#     406         "Cannot call `env.render()` before calling `env.reset()`, if this is an intended action, "
#     407         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#     408     )
# --> 409 return super().render()
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\core.py:337, in Wrapper.render(self)
#     335 def render(self) -> RenderFrame | list[RenderFrame] | None:
#     336     """Uses the :meth:`render` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 337     return self.env.render()
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\wrappers\common.py:303, in PassiveEnvChecker.render(self)
#     301     return env_render_passive_checker(self.env)
#     302 else:
# --> 303     return self.env.render()
#
# File c:\Users\Olga\AppData\Local\Programs\Python\Python311\Lib\site-packages\gymnasium\envs\classic_control\mountain_car.py:272, in MountainCarEnv.render(self)
#     270 if self.render_mode == "human":
#     271     pygame.event.pump()
# --> 272     self.clock.tick(self.metadata["render_fps"])
#     273     pygame.display.flip()
#     275 elif self.render_mode == "rgb_array":
#
# KeyboardInterrupt:

# %% [markdown]
# # Experiments
# Set up a couple fo experiments to figure oyt the following things:
# * How do $\alpha$ and $\gamma$ effect your learning perfomance?
# * Are both elements of the state vector equally important and can we reduce the dimensions of the Q-matrix of one (or both) of them?

# %%
α_list = np.linspace(0, 1, 5)
γ_list = np.linspace(0, 1, 5)


env = gym.make('MountainCar-v0')  # no rendering!

α_grid, γ_grid = np.meshgrid(α_list, γ_list)
wins_grid = np.zeros_like(α_grid)

# Run simulations and store results
for i in range(len(α_list)):
    for j in range(len(γ_list)):
        avg = 0
        for _ in range(3):
            Q = np.zeros(shape=(20, 20, 3))
            wins = qLearn(Q, α_grid[i, j], γ_grid[i, j], ϵ, ϵ_min, num_games)
            avg += wins
        wins_grid[j, i] = avg/3
        print(f'a:{ α_grid[i, j]}, g:{γ_grid[i, j]}, avg:{avg/3}')
# Out:
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.0, g:0.0, avg:0.0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.25, g:0.0, avg:0.0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.5, g:0.0, avg:0.0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.75, g:0.0, avg:0.0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:1.0, g:0.0, avg:0.0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.0, g:0.25, avg:0.0
# Training ended. Number of wins: 58
# Training ended. Number of wins: 54
# Training ended. Number of wins: 58
# a:0.25, g:0.25, avg:56.666666666666664
# Training ended. Number of wins: 64
# Training ended. Number of wins: 74
# Training ended. Number of wins: 68
# a:0.5, g:0.25, avg:68.66666666666667
# Training ended. Number of wins: 23
# Training ended. Number of wins: 61
# Training ended. Number of wins: 30
# a:0.75, g:0.25, avg:38.0
# Training ended. Number of wins: 3
# Training ended. Number of wins: 3
# Training ended. Number of wins: 3
# a:1.0, g:0.25, avg:3.0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.0, g:0.5, avg:0.0
# Training ended. Number of wins: 52
# Training ended. Number of wins: 67
# Training ended. Number of wins: 66
# a:0.25, g:0.5, avg:61.666666666666664
# Training ended. Number of wins: 78
# Training ended. Number of wins: 54
# Training ended. Number of wins: 67
# a:0.5, g:0.5, avg:66.33333333333333
# Training ended. Number of wins: 65
# Training ended. Number of wins: 65
# Training ended. Number of wins: 69
# a:0.75, g:0.5, avg:66.33333333333333
# Training ended. Number of wins: 18
# Training ended. Number of wins: 30
# Training ended. Number of wins: 28
# a:1.0, g:0.5, avg:25.333333333333332
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.0, g:0.75, avg:0.0
# Training ended. Number of wins: 68
# Training ended. Number of wins: 59
# Training ended. Number of wins: 68
# a:0.25, g:0.75, avg:65.0
# Training ended. Number of wins: 77
# Training ended. Number of wins: 77
# Training ended. Number of wins: 75
# a:0.5, g:0.75, avg:76.33333333333333
# Training ended. Number of wins: 57
# Training ended. Number of wins: 69
# Training ended. Number of wins: 74
# a:0.75, g:0.75, avg:66.66666666666667
# Training ended. Number of wins: 38
# Training ended. Number of wins: 41
# Training ended. Number of wins: 48
# a:1.0, g:0.75, avg:42.333333333333336
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# Training ended. Number of wins: 0
# a:0.0, g:1.0, avg:0.0
# Training ended. Number of wins: 50
# Training ended. Number of wins: 67
# Training ended. Number of wins: 57
# a:0.25, g:1.0, avg:58.0
# Training ended. Number of wins: 64
# Training ended. Number of wins: 65
# Training ended. Number of wins: 73
# a:0.5, g:1.0, avg:67.33333333333333
# Training ended. Number of wins: 56
# Training ended. Number of wins: 58
# Training ended. Number of wins: 60
# a:0.75, g:1.0, avg:58.0
# Training ended. Number of wins: 46
# Training ended. Number of wins: 27
# Training ended. Number of wins: 45
# a:1.0, g:1.0, avg:39.333333333333336

# %%
# Plot the results
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

print(wins_grid)

ax.plot_surface(α_grid, γ_grid, wins_grid, cmap='viridis')

# Labels
ax.set_xlabel('Alpha (α)')
ax.set_ylabel('Gamma (γ)')
ax.set_zlabel('Wins')
ax.set_title('Optimization of α and γ')

plt.show()
# Out:
# [[ 0.          0.          0.          0.          0.        ]
#  [ 0.         56.66666667 61.66666667 65.         58.        ]
#  [ 0.         68.66666667 66.33333333 76.33333333 67.33333333]
#  [ 0.         38.         66.33333333 66.66666667 58.        ]
#  [ 0.          3.         25.33333333 42.33333333 39.33333333]]

# %% [markdown]
# To check how alfa and gamma influence the learning performance, we decided to train the model 3 times with each combination of alfa and gamma. We took the average of the number of wins for each combination, and ploted that against alfa and gamma. As expected, when alfa=0 the number of wins is 0, as  according to the Bellmann equation, Q stays the same as in the previous iteration. When gamma=0, the equation doesn't consider the predicted highest Q for the next iteration, which also results in an average of 0 wins.
# The peak value of wins (76.3) can be seen for the parameter combination of alfa=0.5, gamma=0.75.
