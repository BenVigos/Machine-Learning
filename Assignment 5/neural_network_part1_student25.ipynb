# %% [markdown]
# # Neural Networks (part 1)

# %% [markdown]
# ## 1. Introduction
# Start by watching the following youtube video from 3blue1brown for a nice introduction in the concepts of neural networks (NN). The example that is used in the video is about handwriting digits classification. You will build a neural network that does exactly that.
#
# The link to the video: https://www.youtube.com/watch?v=aircAruvnKk
#
# Refer to the lecture notes on Canvas for the mathematical description of the network. In this notebook we will use the same names and conventions as used in the lecture notes.

# %% [markdown]
# ## 2. Loading the data
#
# In this notebook you will use a NN to classify the dataset `NNdata1.txt`. It contains the scores of $M$ students, their scores on two separte tests, and the label (0/1) wether they passed the course or not.
#
# **Notebook aim:** Build a NN model to predict wether a student will pass or not based on the two inputs of the two test scores.

# %%
# importing the required modules
import numpy as np
import matplotlib.pyplot as plt

# to get matplot figures render correctly in the notebook use:
# %matplotlib inline

# %%
# load the data
data = np.loadtxt('NNdata1.txt', delimiter=',')

X1 = data[:,0]
X2 = data[:,1]
Y = data[:,2]

plt.scatter(X1[Y==0], X2[Y==0])
plt.scatter(X1[Y==1], X2[Y==1], marker = '*')

# %% [markdown]
# ## 3. Create the feature matrix X and labels matrix Y
#
# The data that is fed into the NN constist of column vectors $\textbf x_i$ containing the features of the sample $i$. Because usually many samples are required to train and test the NN it is computationally not very efficient to pass them one-by-one. Therefore we have to write the code such that a whole batch of samples can be passed through the network simultaneously. To do so the data is organised in 2 matrices $\textbf X$ and $\textbf Y$
# The feature matrix $\textbf X$ contains the features $\textbf x_i$ of the different samples as columns. If we have $m$ samples then $\textbf X \in \mathbb{R}^{n_0 \times m}$. $\color{red}\text{Note that this is different than used sofar!}$
#
# For every sample $\textbf x_i$ a corresponding column vector $\textbf y_i$ exists that gives the category to which the sample belongs. The vector $\textbf y_i$ is a so-called one-hot-encoded label and has $n_L$ (the number of nodes in the output layer) elements. Since each output node of the NN corresponds to one of the possible categories to which a sample belongs, the element of the vector $\textbf y_i$ that corresponds to the category of the sample is equal to 1 and all other elements are zero. For example, if we have two categories '0' and '1' (as is the case in the current problem where the student is either rejected or accepted), and let's say we have 4 samples belonging to category 1, 0, 0, 1 respectively then $\textbf Y$ is given by:
#
# $$ \textbf Y = \begin{bmatrix}
# 0 & 1 & 1 & 0\\
# 1 & 0 & 0 & 1
# \end{bmatrix} $$
#
# The matrix $\textbf Y$ contains the one-hot encoded labels $\textbf y_i$ of the samples as columns. If we have $m$ samples then $\textbf Y \in \mathbb{R}^{n_L \times m}$

# %%
#create feature matrix
X = np.column_stack((X1, X2))

#apply feature scaling to the matix
X =  (X-np.mean(X,axis=0))/np.std(X,axis=0)
X = X.T

#create one-hot encoded Y matrix
Y_hot = np.column_stack(((Y-1)**2, Y)).T

# %% [markdown]
# Next you need to split $X$ and $Y$ in a training set (data used to train the network) and a test set (data used to test the network). Normally you would also use a validation set to tune hyperparameters of the model/training but we leave that to part 2 of the NN notebook

# %%
# create a train and test dataset with size-ratio 9:1

cutoff = int(len(X1)*0.9)

X_train = X[:,:cutoff]
Y_train = Y_hot[:,:cutoff]

X_test = X[:,cutoff:]
Y_test = Y_hot[:,cutoff:]

# %% [markdown]
# ## 4. The Neural Network
#
# The NN that you will make has the following layout:
#
#
# It consists of an input layer with two nodes because each sample consists of two features (score test 1 and score test 2). Then we have one hidden layer consisting of three nodes. Finally the output layer has two nodes corresponding to the two categories that need to be distinghuished.
#
# The hidden layer has a **sigmoid** activation function while the outputlayer has a **softmax** activation function.

# %% [markdown]
# ### Define the activation functions
#
# Below you define the required activation functions and their derivatives

# %%
# define some activation functions

def sigmoid(z):
    """
    returns the sigmoid function of z

    Parameters
    ----------
    z : float or ndarray

    Returns
    -------
    out : same type and shape as z

    """
    
    return 1/(1+np.exp(-z))


def sigmoid_diff(z):
    """
    returns the derivative of the sigmoid function of z

    Parameters
    ----------
    z : float or ndarray

    Returns
    -------
    out : same type and shape as z

    """
    
    sigma = sigmoid(z)
    
    return sigma*(1-sigma)


def softmax(z):
    """
    returns the softmax function of z

    Parameters
    ----------
    z : 2D ndarray

    Returns
    -------
    out : same type and shape as z

    """
    
    e = np.exp(z)
    
    return e/np.sum(e, axis=0)

# %% [markdown]
# ### Initalize the weights and biases
# The layers are denoted with $l$. Our NN has an input layer ($l=0$), an output layer ($l=L=2$) and a hidden layer ($l=1$).
#
# For each layer $l$ we have:
# 1. A number of nodes: $n_l$
# 2. A weight matrix: $\textbf W^{l} \in \mathbb{R}^{n_l \times n_{l-1}}$
# 3. A bias (column) vector: $\textbf b^{l} \in \mathbb{R}^{n_l \times 1}$
#
# The input layer actually does not do much, it just passes the sample data to the output which then acts as input for the first hidden layer. So the input layer does not have a weight and bias.
#
# The biases can be initialized with zeros; the weight's of layer $l$ are best intialized with random numbers from a normal distribution with mean 0 and standard deviation of $\sqrt{1/n_{l-1}}$.

# %%
# intialize the neural network

# number of nodes in each layer
n0 = 2
n1 = 3
n2 = 2

# input layer
# no weights and biases

# hidden layer (l=1)
W1 = np.random.normal(scale=np.sqrt(1/n0), size=(n1, n0))
b1 = np.zeros(shape=(n1,1))

# output layer (l=2)
W2 = np.random.normal(scale=np.sqrt(1/n1), size=(n2, n1))
b2 = np.zeros(shape=(n2,1))

# %% [markdown]
# ## 5. Train the NN

# %% [markdown]
# Firt you define three parameters that can be adjusted for optimal training.
# - **learning_rate**: determines to what extend we update the weights and biases in the gradient descent step
# - **no_epochs**: the number of times we pass the training data set through the network for training
# - **batch_size**: how many samples we pass through the network before doing a gradient descent update

# %%
# train settings
learning_rate = 0.1
no_epochs = 1000
batch_size = 10

# %% [markdown]
# Below you implement the training of the network. A general layout (pseudocode) is already given. Note that we use the **Cross Entropy** (CE) loss function.

# %%
# perform the training
accuracies = []
losses = []


for epoch in range(1, no_epochs + 1):
    
    # for each epoch train over all batches
    for b in range(int(np.floor(len(X_train.T)/batch_size))):
        X_batch = X_train[:, batch_size*b:(batch_size*(b+1))]
        Y_batch = Y_train[:, batch_size*b:(batch_size*(b+1))]
        
        # forward pass
        # compute the output of the network for the batch
        a0 = X_batch
        z1 = W1@a0+b1
        a1 = sigmoid(z1)
        z2 = W2@a1+b2        
        a2 = softmax(z2)
        
        # backward pass
        # compute the derivatives dLdW and dLdb for the layers (use CE loss)
        dLdz2 = a2 - Y_batch
        dLdW2 = dLdz2@a1.T
        dLdb2 = dLdz2
        
        dLdz1 = sigmoid_diff(z1)*(W2.T@dLdz2)
        dLdW1 = dLdz1@a0.T
        dLdb1 = dLdz1
        
        # gradient descent step / update weights and biases
        prefactor = learning_rate*1/batch_size
        
        W1 = W1 - prefactor*dLdW1 #Should sum over entire batch
        W2 = W2 - prefactor*dLdW2 #Should sum over entire batch
        
        b1 = b1 - prefactor*np.sum(dLdb1, axis=1).reshape(-1, 1)
        b2 = b2 - prefactor*np.sum(dLdb2, axis=1).reshape(-1, 1)
    
    # for each epoch evaluate the network performance
    # compute accuracy of train set and store for later analysis
    
    a0 = X_train
    z1 = W1@a0+b1
    a1 = sigmoid(z1)
    z2 = W2@a1+b2        
    a2 = softmax(z2)
    
    interim = np.round(a2)==Y_train
    
    accuracy = np.sum(interim[1,:])/len(X_train.T)
    loss = - np.mean(Y_train*np.log(a2))
    
    accuracies.append(accuracy)
    losses.append(loss)
    
    # for each epoch print info on learning progress
    print(f"Epoch {epoch} \n Accuracy: {accuracy:.3} \n Loss:{loss} \n")
# Out:
# Epoch 1
#  Accuracy: 0.422
#  Loss:0.35543818201875776
#
# Epoch 2
#  Accuracy: 0.556
#  Loss:0.34021926705810807
#
# Epoch 3
#  Accuracy: 0.6
#  Loss:0.3337097813010375
#
# Epoch 4
#  Accuracy: 0.6
#  Loss:0.328483032495092
#
# Epoch 5
#  Accuracy: 0.6
#  Loss:0.3231764893270283
#
# Epoch 6
#  Accuracy: 0.6
#  Loss:0.3175149474646583
#
# Epoch 7
#  Accuracy: 0.644
#  Loss:0.31142073231293893
#
# Epoch 8
#  Accuracy: 0.711
#  Loss:0.30486340136399265
#
# Epoch 9
#  Accuracy: 0.756
#  Loss:0.29783968776247727
#
# Epoch 10
#  Accuracy: 0.767
#  Loss:0.2903729670742774
#
# Epoch 11
#  Accuracy: 0.789
#  Loss:0.2825128132006684
#
# Epoch 12
#  Accuracy: 0.8
#  Loss:0.27433191547145547
#
# Epoch 13
#  Accuracy: 0.8
#  Loss:0.2659206813374079
#
# Epoch 14
#  Accuracy: 0.822
#  Loss:0.257380451545096
#
# Epoch 15
#  Accuracy: 0.811
#  Loss:0.24881634322143664
#
# Epoch 16
#  Accuracy: 0.844
#  Loss:0.24033061021539406
#
# Epoch 17
#  Accuracy: 0.878
#  Loss:0.23201715500696174
#
# Epoch 18
#  Accuracy: 0.878
#  Loss:0.22395752743011385
#
# Epoch 19
#  Accuracy: 0.878
#  Loss:0.21621847791240098
#
# Epoch 20
#  Accuracy: 0.878
#  Loss:0.20885093962199947
#
# Epoch 21
#  Accuracy: 0.878
#  Loss:0.2018902023231131
#
# Epoch 22
#  Accuracy: 0.878
#  Loss:0.19535699563850614
#
# Epoch 23
#  Accuracy: 0.867
#  Loss:0.18925919816667158
#
# Epoch 24
#  Accuracy: 0.878
#  Loss:0.1835939121776157
#
# Epoch 25
#  Accuracy: 0.889
#  Loss:0.1783496794409967
#
# Epoch 26
#  Accuracy: 0.889
#  Loss:0.17350865630357148
#
# Epoch 27
#  Accuracy: 0.889
#  Loss:0.16904861239547989
#
# Epoch 28
#  Accuracy: 0.889
#  Loss:0.16494466432727833
#
# Epoch 29
#  Accuracy: 0.889
#  Loss:0.1611706997043229
#
# Epoch 30
#  Accuracy: 0.889
#  Loss:0.15770048397815892
#
# Epoch 31
#  Accuracy: 0.889
#  Loss:0.15450847046606314
#
# Epoch 32
#  Accuracy: 0.889
#  Loss:0.1515703514978259
#
# Epoch 33
#  Accuracy: 0.889
#  Loss:0.14886339700474302
#
# Epoch 34
#  Accuracy: 0.889
#  Loss:0.1463666279669784
#
# Epoch 35
#  Accuracy: 0.889
#  Loss:0.14406086837770266
#
# Epoch 36
#  Accuracy: 0.889
#  Loss:0.14192871297399534
#
# Epoch 37
#  Accuracy: 0.889
#  Loss:0.1399544406414854
#
# Epoch 38
#  Accuracy: 0.889
#  Loss:0.1381238962693926
#
# Epoch 39
#  Accuracy: 0.889
#  Loss:0.1364243575596987
#
# Epoch 40
#  Accuracy: 0.889
#  Loss:0.1348443981471383
#
# Epoch 41
#  Accuracy: 0.9
#  Loss:0.13337375438911753
#
# Epoch 42
#  Accuracy: 0.9
#  Loss:0.1320032002232776
#
# Epoch 43
#  Accuracy: 0.9
#  Loss:0.13072443239209944
#
# Epoch 44
#  Accuracy: 0.9
#  Loss:0.12952996691413962
#
# Epoch 45
#  Accuracy: 0.9
#  Loss:0.12841304677076432
#
# Epoch 46
#  Accuracy: 0.9
#  Loss:0.1273675602330411
#
# Epoch 47
#  Accuracy: 0.9
#  Loss:0.12638796896281182
#
# Epoch 48
#  Accuracy: 0.9
#  Loss:0.12546924489949257
#
# Epoch 49
#  Accuracy: 0.9
#  Loss:0.12460681492774629
#
# Epoch 50
#  Accuracy: 0.9
#  Loss:0.12379651236732074
#
# Epoch 51
#  Accuracy: 0.9
#  Loss:0.12303453440564122
#
# Epoch 52
#  Accuracy: 0.9
#  Loss:0.12231740468709892
#
# Epoch 53
#  Accuracy: 0.9
#  Loss:0.12164194036859718
#
# Epoch 54
#  Accuracy: 0.9
#  Loss:0.12100522304200886
#
# Epoch 55
#  Accuracy: 0.9
#  Loss:0.120404573007251
#
# Epoch 56
#  Accuracy: 0.9
#  Loss:0.11983752645328352
#
# Epoch 57
#  Accuracy: 0.9
#  Loss:0.11930181516832292
#
# Epoch 58
#  Accuracy: 0.9
#  Loss:0.11879534845548202
#
# Epoch 59
#  Accuracy: 0.9
#  Loss:0.11831619697678313
#
# Epoch 60
#  Accuracy: 0.9
#  Loss:0.11786257828807088
#
# Epoch 61
#  Accuracy: 0.9
#  Loss:0.11743284386077353
#
# Epoch 62
#  Accuracy: 0.9
#  Loss:0.11702546741467386
#
# Epoch 63
#  Accuracy: 0.9
#  Loss:0.11663903440967956
#
# Epoch 64
#  Accuracy: 0.9
#  Loss:0.11627223256475314
#
# Epoch 65
#  Accuracy: 0.9
#  Loss:0.11592384328927637
#
# Epoch 66
#  Accuracy: 0.9
#  Loss:0.11559273392669793
#
# Epoch 67
#  Accuracy: 0.9
#  Loss:0.11527785072276656
#
# Epoch 68
#  Accuracy: 0.9
#  Loss:0.11497821244132969
#
# Epoch 69
#  Accuracy: 0.9
#  Loss:0.11469290455987434
#
# Epoch 70
#  Accuracy: 0.9
#  Loss:0.11442107398492792
#
# Epoch 71
#  Accuracy: 0.9
#  Loss:0.11416192423432435
#
# Epoch 72
#  Accuracy: 0.9
#  Loss:0.11391471103933165
#
# Epoch 73
#  Accuracy: 0.9
#  Loss:0.11367873832486153
#
# Epoch 74
#  Accuracy: 0.9
#  Loss:0.1134533545305553
#
# Epoch 75
#  Accuracy: 0.9
#  Loss:0.11323794923954966
#
# Epoch 76
#  Accuracy: 0.9
#  Loss:0.1130319500852522
#
# Epoch 77
#  Accuracy: 0.9
#  Loss:0.11283481990956273
#
# Epoch 78
#  Accuracy: 0.9
#  Loss:0.11264605414871899
#
# Epoch 79
#  Accuracy: 0.9
#  Loss:0.11246517842537042
#
# Epoch 80
#  Accuracy: 0.9
#  Loss:0.11229174632763177
#
# Epoch 81
#  Accuracy: 0.9
#  Loss:0.1121253373577748
#
# Epoch 82
#  Accuracy: 0.9
#  Loss:0.11196555503490961
#
# Epoch 83
#  Accuracy: 0.9
#  Loss:0.11181202513751397
#
# Epoch 84
#  Accuracy: 0.9
#  Loss:0.11166439407301074
#
# Epoch 85
#  Accuracy: 0.9
#  Loss:0.11152232736279204
#
# Epoch 86
#  Accuracy: 0.9
#  Loss:0.11138550823215713
#
# Epoch 87
#  Accuracy: 0.9
#  Loss:0.11125363629558858
#
# Epoch 88
#  Accuracy: 0.9
#  Loss:0.1111264263286473
#
# Epoch 89
#  Accuracy: 0.9
#  Loss:0.11100360711853632
#
# Epoch 90
#  Accuracy: 0.9
#  Loss:0.11088492038607371
#
# Epoch 91
#  Accuracy: 0.9
#  Loss:0.1107701197724366
#
# Epoch 92
#  Accuracy: 0.9
#  Loss:0.1106589698846009
#
# Epoch 93
#  Accuracy: 0.9
#  Loss:0.11055124539390869
#
# Epoch 94
#  Accuracy: 0.9
#  Loss:0.1104467301826576
#
# Epoch 95
#  Accuracy: 0.9
#  Loss:0.11034521653402843
#
# Epoch 96
#  Accuracy: 0.9
#  Loss:0.1102465043610544
#
# Epoch 97
#  Accuracy: 0.9
#  Loss:0.11015040047069226
#
# Epoch 98
#  Accuracy: 0.9
#  Loss:0.1100567178593905
#
# Epoch 99
#  Accuracy: 0.9
#  Loss:0.10996527503686124
#
# Epoch 100
#  Accuracy: 0.9
#  Loss:0.10987589537506341
#
# Epoch 101
#  Accuracy: 0.9
#  Loss:0.10978840647968995
#
# Epoch 102
#  Accuracy: 0.9
#  Loss:0.10970263958173569
#
# Epoch 103
#  Accuracy: 0.9
#  Loss:0.10961842894700011
#
# Epoch 104
#  Accuracy: 0.9
#  Loss:0.10953561130166227
#
# Epoch 105
#  Accuracy: 0.9
#  Loss:0.10945402527235357
#
# Epoch 106
#  Accuracy: 0.9
#  Loss:0.10937351083945401
#
# Epoch 107
#  Accuracy: 0.9
#  Loss:0.10929390880265437
#
# Epoch 108
#  Accuracy: 0.9
#  Loss:0.10921506025816215
#
# Epoch 109
#  Accuracy: 0.9
#  Loss:0.1091368060872925
#
# Epoch 110
#  Accuracy: 0.9
#  Loss:0.10905898645657537
#
# Epoch 111
#  Accuracy: 0.9
#  Loss:0.10898144032993738
#
# Epoch 112
#  Accuracy: 0.9
#  Loss:0.10890400499398022
#
# Epoch 113
#  Accuracy: 0.9
#  Loss:0.10882651559788473
#
# Epoch 114
#  Accuracy: 0.9
#  Loss:0.10874880471002248
#
# Epoch 115
#  Accuracy: 0.9
#  Loss:0.10867070189395649
#
# Epoch 116
#  Accuracy: 0.9
#  Loss:0.10859203330716255
#
# Epoch 117
#  Accuracy: 0.9
#  Loss:0.10851262132650219
#
# Epoch 118
#  Accuracy: 0.9
#  Loss:0.10843228420522195
#
# Epoch 119
#  Accuracy: 0.9
#  Loss:0.10835083576704198
#
# Epoch 120
#  Accuracy: 0.9
#  Loss:0.10826808514371665
#
# Epoch 121
#  Accuracy: 0.9
#  Loss:0.10818383656329272
#
# Epoch 122
#  Accuracy: 0.9
#  Loss:0.10809788919713839
#
# Epoch 123
#  Accuracy: 0.9
#  Loss:0.1080100370746489
#
# Epoch 124
#  Accuracy: 0.9
#  Loss:0.10792006907532362
#
# Epoch 125
#  Accuracy: 0.9
#  Loss:0.10782776900862107
#
# Epoch 126
#  Accuracy: 0.9
#  Loss:0.10773291579259293
#
# Epoch 127
#  Accuracy: 0.9
#  Loss:0.10763528374272617
#
# Epoch 128
#  Accuracy: 0.9
#  Loss:0.10753464298262892
#
# Epoch 129
#  Accuracy: 0.9
#  Loss:0.10743075998812143
#
# Epoch 130
#  Accuracy: 0.9
#  Loss:0.10732339827586466
#
# Epoch 131
#  Accuracy: 0.9
#  Loss:0.10721231924681275
#
# Epoch 132
#  Accuracy: 0.9
#  Loss:0.10709728319343406
#
# Epoch 133
#  Accuracy: 0.9
#  Loss:0.10697805047774014
#
# Epoch 134
#  Accuracy: 0.9
#  Loss:0.10685438288463477
#
# Epoch 135
#  Accuracy: 0.9
#  Loss:0.1067260451518929
#
# Epoch 136
#  Accuracy: 0.9
#  Loss:0.10659280667417678
#
# Epoch 137
#  Accuracy: 0.9
#  Loss:0.10645444337389187
#
# Epoch 138
#  Accuracy: 0.9
#  Loss:0.10631073972641387
#
# Epoch 139
#  Accuracy: 0.9
#  Loss:0.10616149092135482
#
# Epoch 140
#  Accuracy: 0.9
#  Loss:0.10600650513521358
#
# Epoch 141
#  Accuracy: 0.889
#  Loss:0.10584560588414954
#
# Epoch 142
#  Accuracy: 0.889
#  Loss:0.10567863441896842
#
# Epoch 143
#  Accuracy: 0.889
#  Loss:0.10550545211801036
#
# Epoch 144
#  Accuracy: 0.889
#  Loss:0.10532594282781417
#
# Epoch 145
#  Accuracy: 0.889
#  Loss:0.1051400150965808
#
# Epoch 146
#  Accuracy: 0.889
#  Loss:0.10494760424195353
#
# Epoch 147
#  Accuracy: 0.889
#  Loss:0.10474867419285996
#
# Epoch 148
#  Accuracy: 0.889
#  Loss:0.10454321904546146
#
# Epoch 149
#  Accuracy: 0.889
#  Loss:0.10433126427590453
#
# Epoch 150
#  Accuracy: 0.889
#  Loss:0.10411286755773896
#
# Epoch 151
#  Accuracy: 0.889
#  Loss:0.10388811913960533
#
# Epoch 152
#  Accuracy: 0.889
#  Loss:0.10365714174898619
#
# Epoch 153
#  Accuracy: 0.889
#  Loss:0.10342009000019278
#
# Epoch 154
#  Accuracy: 0.889
#  Loss:0.10317714929888021
#
# Epoch 155
#  Accuracy: 0.889
#  Loss:0.10292853425066407
#
# Epoch 156
#  Accuracy: 0.889
#  Loss:0.10267448659714569
#
# Epoch 157
#  Accuracy: 0.889
#  Loss:0.1024152727180576
#
# Epoch 158
#  Accuracy: 0.889
#  Loss:0.1021511807525215
#
# Epoch 159
#  Accuracy: 0.889
#  Loss:0.10188251740479957
#
# Epoch 160
#  Accuracy: 0.889
#  Loss:0.1016096045097591
#
# Epoch 161
#  Accuracy: 0.889
#  Loss:0.1013327754400428
#
# Epoch 162
#  Accuracy: 0.889
#  Loss:0.1010523714403249
#
# Epoch 163
#  Accuracy: 0.889
#  Loss:0.10076873797392369
#
# Epoch 164
#  Accuracy: 0.889
#  Loss:0.10048222116354301
#
# Epoch 165
#  Accuracy: 0.889
#  Loss:0.10019316440134435
#
# Epoch 166
#  Accuracy: 0.889
#  Loss:0.09990190519438108
#
# Epoch 167
#  Accuracy: 0.889
#  Loss:0.09960877230027351
#
# Epoch 168
#  Accuracy: 0.889
#  Loss:0.09931408319554187
#
# Epoch 169
#  Accuracy: 0.889
#  Loss:0.09901814190594951
#
# Epoch 170
#  Accuracy: 0.889
#  Loss:0.09872123721520908
#
# Epoch 171
#  Accuracy: 0.889
#  Loss:0.0984236412560663
#
# Epoch 172
#  Accuracy: 0.889
#  Loss:0.09812560847659009
#
# Epoch 173
#  Accuracy: 0.889
#  Loss:0.0978273749648339
#
# Epoch 174
#  Accuracy: 0.889
#  Loss:0.09752915810712158
#
# Epoch 175
#  Accuracy: 0.889
#  Loss:0.09723115654916761
#
# Epoch 176
#  Accuracy: 0.889
#  Loss:0.09693355042505444
#
# Epoch 177
#  Accuracy: 0.889
#  Loss:0.09663650181666558
#
# Epoch 178
#  Accuracy: 0.889
#  Loss:0.09634015540533186
#
# Epoch 179
#  Accuracy: 0.889
#  Loss:0.096044639277978
#
# Epoch 180
#  Accuracy: 0.889
#  Loss:0.09575006585170007
#
# Epoch 181
#  Accuracy: 0.889
#  Loss:0.09545653288321121
#
# Epoch 182
#  Accuracy: 0.889
#  Loss:0.09516412453271374
#
# Epoch 183
#  Accuracy: 0.889
#  Loss:0.09487291245526062
#
# Epoch 184
#  Accuracy: 0.889
#  Loss:0.09458295689636351
#
# Epoch 185
#  Accuracy: 0.889
#  Loss:0.09429430777231357
#
# Epoch 186
#  Accuracy: 0.889
#  Loss:0.0940070057192791
#
# Epoch 187
#  Accuracy: 0.889
#  Loss:0.09372108309862325
#
# Epoch 188
#  Accuracy: 0.889
#  Loss:0.09343656494898019
#
# Epoch 189
#  Accuracy: 0.889
#  Loss:0.09315346987839249
#
# Epoch 190
#  Accuracy: 0.889
#  Loss:0.09287181089222567
#
# Epoch 191
#  Accuracy: 0.889
#  Loss:0.09259159615463472
#
# Epoch 192
#  Accuracy: 0.889
#  Loss:0.09231282968307397
#
# Epoch 193
#  Accuracy: 0.889
#  Loss:0.09203551197673233
#
# Epoch 194
#  Accuracy: 0.889
#  Loss:0.09175964058087464
#
# Epoch 195
#  Accuracy: 0.889
#  Loss:0.0914852105899029
#
# Epoch 196
#  Accuracy: 0.889
#  Loss:0.09121221509255349
#
# Epoch 197
#  Accuracy: 0.889
#  Loss:0.09094064556305222
#
# Epoch 198
#  Accuracy: 0.889
#  Loss:0.0906704922022891
#
# Epoch 199
#  Accuracy: 0.889
#  Loss:0.09040174423317751
#
# Epoch 200
#  Accuracy: 0.889
#  Loss:0.09013439015435877
#
# Epoch 201
#  Accuracy: 0.889
#  Loss:0.08986841795632156
#
# Epoch 202
#  Accuracy: 0.889
#  Loss:0.0896038153038523
#
# Epoch 203
#  Accuracy: 0.889
#  Loss:0.08934056968853087
#
# Epoch 204
#  Accuracy: 0.889
#  Loss:0.08907866855475537
#
# Epoch 205
#  Accuracy: 0.889
#  Loss:0.088818099402526
#
# Epoch 206
#  Accuracy: 0.889
#  Loss:0.08855884986995917
#
# Epoch 207
#  Accuracy: 0.889
#  Loss:0.08830090779824039
#
# Epoch 208
#  Accuracy: 0.889
#  Loss:0.08804426128146586
#
# Epoch 209
#  Accuracy: 0.9
#  Loss:0.08778889870357622
#
# Epoch 210
#  Accuracy: 0.9
#  Loss:0.08753480876434715
#
# Epoch 211
#  Accuracy: 0.911
#  Loss:0.08728198049618209
#
# Epoch 212
#  Accuracy: 0.911
#  Loss:0.08703040327324511
#
# Epoch 213
#  Accuracy: 0.911
#  Loss:0.08678006681428244
#
# Epoch 214
#  Accuracy: 0.911
#  Loss:0.08653096118030887
#
# Epoch 215
#  Accuracy: 0.922
#  Loss:0.08628307676817767
#
# Epoch 216
#  Accuracy: 0.922
#  Loss:0.08603640430091225
#
# Epoch 217
#  Accuracy: 0.922
#  Loss:0.08579093481555095
#
# Epoch 218
#  Accuracy: 0.922
#  Loss:0.08554665964914476
#
# Epoch 219
#  Accuracy: 0.922
#  Loss:0.08530357042344801
#
# Epoch 220
#  Accuracy: 0.922
#  Loss:0.08506165902875483
#
# Epoch 221
#  Accuracy: 0.922
#  Loss:0.08482091760725796
#
# Epoch 222
#  Accuracy: 0.922
#  Loss:0.08458133853623967
#
# Epoch 223
#  Accuracy: 0.922
#  Loss:0.08434291441134685
#
# Epoch 224
#  Accuracy: 0.922
#  Loss:0.08410563803015256
#
# Epoch 225
#  Accuracy: 0.922
#  Loss:0.08386950237616404
#
# Epoch 226
#  Accuracy: 0.922
#  Loss:0.08363450060340007
#
# Epoch 227
#  Accuracy: 0.922
#  Loss:0.08340062602163018
#
# Epoch 228
#  Accuracy: 0.922
#  Loss:0.08316787208234258
#
# Epoch 229
#  Accuracy: 0.922
#  Loss:0.0829362323654846
#
# Epoch 230
#  Accuracy: 0.922
#  Loss:0.08270570056700303
#
# Epoch 231
#  Accuracy: 0.922
#  Loss:0.0824762704871955
#
# Epoch 232
#  Accuracy: 0.922
#  Loss:0.08224793601987276
#
# Epoch 233
#  Accuracy: 0.922
#  Loss:0.0820206911423217
#
# Epoch 234
#  Accuracy: 0.922
#  Loss:0.0817945299060508
#
# Epoch 235
#  Accuracy: 0.922
#  Loss:0.08156944642829472
#
# Epoch 236
#  Accuracy: 0.922
#  Loss:0.08134543488424932
#
# Epoch 237
#  Accuracy: 0.922
#  Loss:0.08112248950000499
#
# Epoch 238
#  Accuracy: 0.922
#  Loss:0.080900604546145
#
# Epoch 239
#  Accuracy: 0.922
#  Loss:0.08067977433197276
#
# Epoch 240
#  Accuracy: 0.922
#  Loss:0.08045999320033184
#
# Epoch 241
#  Accuracy: 0.922
#  Loss:0.08024125552298267
#
# Epoch 242
#  Accuracy: 0.922
#  Loss:0.08002355569649938
#
# Epoch 243
#  Accuracy: 0.922
#  Loss:0.07980688813865162
#
# Epoch 244
#  Accuracy: 0.922
#  Loss:0.07959124728523649
#
# Epoch 245
#  Accuracy: 0.922
#  Loss:0.07937662758732768
#
# Epoch 246
#  Accuracy: 0.922
#  Loss:0.07916302350890907
#
# Epoch 247
#  Accuracy: 0.922
#  Loss:0.078950429524863
#
# Epoch 248
#  Accuracy: 0.922
#  Loss:0.07873884011928324
#
# Epoch 249
#  Accuracy: 0.922
#  Loss:0.07852824978408555
#
# Epoch 250
#  Accuracy: 0.922
#  Loss:0.07831865301789002
#
# Epoch 251
#  Accuracy: 0.922
#  Loss:0.07811004432514991
#
# Epoch 252
#  Accuracy: 0.922
#  Loss:0.07790241821550506
#
# Epoch 253
#  Accuracy: 0.933
#  Loss:0.07769576920333776
#
# Epoch 254
#  Accuracy: 0.933
#  Loss:0.07749009180751144
#
# Epoch 255
#  Accuracy: 0.933
#  Loss:0.07728538055127337
#
# Epoch 256
#  Accuracy: 0.933
#  Loss:0.07708162996230464
#
# Epoch 257
#  Accuracy: 0.933
#  Loss:0.0768788345729006
#
# Epoch 258
#  Accuracy: 0.933
#  Loss:0.07667698892026825
#
# Epoch 259
#  Accuracy: 0.933
#  Loss:0.07647608754692578
#
# Epoch 260
#  Accuracy: 0.933
#  Loss:0.07627612500119256
#
# Epoch 261
#  Accuracy: 0.944
#  Loss:0.07607709583775794
#
# Epoch 262
#  Accuracy: 0.944
#  Loss:0.07587899461831817
#
# Epoch 263
#  Accuracy: 0.944
#  Loss:0.07568181591227172
#
# Epoch 264
#  Accuracy: 0.944
#  Loss:0.07548555429746474
#
# Epoch 265
#  Accuracy: 0.956
#  Loss:0.07529020436097801
#
# Epoch 266
#  Accuracy: 0.956
#  Loss:0.07509576069994822
#
# Epoch 267
#  Accuracy: 0.956
#  Loss:0.07490221792241734
#
# Epoch 268
#  Accuracy: 0.956
#  Loss:0.0747095706482034
#
# Epoch 269
#  Accuracy: 0.956
#  Loss:0.07451781350978755
#
# Epoch 270
#  Accuracy: 0.956
#  Loss:0.07432694115321264
#
# Epoch 271
#  Accuracy: 0.956
#  Loss:0.07413694823898842
#
# Epoch 272
#  Accuracy: 0.956
#  Loss:0.07394782944299952
#
# Epoch 273
#  Accuracy: 0.956
#  Loss:0.0737595794574128
#
# Epoch 274
#  Accuracy: 0.956
#  Loss:0.07357219299158038
#
# Epoch 275
#  Accuracy: 0.956
#  Loss:0.07338566477293601
#
# Epoch 276
#  Accuracy: 0.956
#  Loss:0.07319998954788146
#
# Epoch 277
#  Accuracy: 0.956
#  Loss:0.07301516208266147
#
# Epoch 278
#  Accuracy: 0.956
#  Loss:0.07283117716422448
#
# Epoch 279
#  Accuracy: 0.956
#  Loss:0.0726480296010678
#
# Epoch 280
#  Accuracy: 0.956
#  Loss:0.07246571422406543
#
# Epoch 281
#  Accuracy: 0.956
#  Loss:0.07228422588727715
#
# Epoch 282
#  Accuracy: 0.956
#  Loss:0.07210355946873769
#
# Epoch 283
#  Accuracy: 0.956
#  Loss:0.071923709871225
#
# Epoch 284
#  Accuracy: 0.956
#  Loss:0.07174467202300668
#
# Epoch 285
#  Accuracy: 0.956
#  Loss:0.07156644087856366
#
# Epoch 286
#  Accuracy: 0.956
#  Loss:0.07138901141929076
#
# Epoch 287
#  Accuracy: 0.956
#  Loss:0.07121237865417335
#
# Epoch 288
#  Accuracy: 0.956
#  Loss:0.07103653762043985
#
# Epoch 289
#  Accuracy: 0.956
#  Loss:0.07086148338418961
#
# Epoch 290
#  Accuracy: 0.956
#  Loss:0.07068721104099605
#
# Epoch 291
#  Accuracy: 0.956
#  Loss:0.0705137157164847
#
# Epoch 292
#  Accuracy: 0.956
#  Loss:0.070340992566886
#
# Epoch 293
#  Accuracy: 0.956
#  Loss:0.07016903677956338
#
# Epoch 294
#  Accuracy: 0.956
#  Loss:0.06999784357351543
#
# Epoch 295
#  Accuracy: 0.956
#  Loss:0.0698274081998536
#
# Epoch 296
#  Accuracy: 0.956
#  Loss:0.06965772594225432
#
# Epoch 297
#  Accuracy: 0.956
#  Loss:0.06948879211738661
#
# Epoch 298
#  Accuracy: 0.956
#  Loss:0.06932060207531456
#
# Epoch 299
#  Accuracy: 0.956
#  Loss:0.06915315119987546
#
# Epoch 300
#  Accuracy: 0.956
#  Loss:0.06898643490903343
#
# Epoch 301
#  Accuracy: 0.956
#  Loss:0.06882044865520914
#
# Epoch 302
#  Accuracy: 0.956
#  Loss:0.06865518792558543
#
# Epoch 303
#  Accuracy: 0.956
#  Loss:0.06849064824238955
#
# Epoch 304
#  Accuracy: 0.956
#  Loss:0.06832682516315221
#
# Epoch 305
#  Accuracy: 0.956
#  Loss:0.06816371428094346
#
# Epoch 306
#  Accuracy: 0.956
#  Loss:0.06800131122458636
#
# Epoch 307
#  Accuracy: 0.956
#  Loss:0.06783961165884808
#
# Epoch 308
#  Accuracy: 0.956
#  Loss:0.06767861128460942
#
# Epoch 309
#  Accuracy: 0.956
#  Loss:0.06751830583901268
#
# Epoch 310
#  Accuracy: 0.956
#  Loss:0.06735869109558844
#
# Epoch 311
#  Accuracy: 0.956
#  Loss:0.06719976286436166
#
# Epoch 312
#  Accuracy: 0.956
#  Loss:0.0670415169919376
#
# Epoch 313
#  Accuracy: 0.956
#  Loss:0.06688394936156745
#
# Epoch 314
#  Accuracy: 0.956
#  Loss:0.06672705589319498
#
# Epoch 315
#  Accuracy: 0.956
#  Loss:0.0665708325434837
#
# Epoch 316
#  Accuracy: 0.956
#  Loss:0.0664152753058254
#
# Epoch 317
#  Accuracy: 0.956
#  Loss:0.06626038021033069
#
# Epoch 318
#  Accuracy: 0.956
#  Loss:0.06610614332380142
#
# Epoch 319
#  Accuracy: 0.956
#  Loss:0.06595256074968595
#
# Epoch 320
#  Accuracy: 0.956
#  Loss:0.06579962862801714
#
# Epoch 321
#  Accuracy: 0.956
#  Loss:0.06564734313533419
#
# Epoch 322
#  Accuracy: 0.956
#  Loss:0.065495700484588
#
# Epoch 323
#  Accuracy: 0.956
#  Loss:0.0653446969250312
#
# Epoch 324
#  Accuracy: 0.956
#  Loss:0.06519432874209252
#
# Epoch 325
#  Accuracy: 0.956
#  Loss:0.06504459225723676
#
# Epoch 326
#  Accuracy: 0.956
#  Loss:0.06489548382781016
#
# Epoch 327
#  Accuracy: 0.956
#  Loss:0.06474699984687185
#
# Epoch 328
#  Accuracy: 0.956
#  Loss:0.06459913674301175
#
# Epoch 329
#  Accuracy: 0.956
#  Loss:0.06445189098015558
#
# Epoch 330
#  Accuracy: 0.956
#  Loss:0.06430525905735683
#
# Epoch 331
#  Accuracy: 0.956
#  Loss:0.06415923750857704
#
# Epoch 332
#  Accuracy: 0.956
#  Loss:0.06401382290245375
#
# Epoch 333
#  Accuracy: 0.956
#  Loss:0.06386901184205745
#
# Epoch 334
#  Accuracy: 0.956
#  Loss:0.0637248009646374
#
# Epoch 335
#  Accuracy: 0.956
#  Loss:0.06358118694135695
#
# Epoch 336
#  Accuracy: 0.956
#  Loss:0.06343816647701887
#
# Epoch 337
#  Accuracy: 0.956
#  Loss:0.06329573630978091
#
# Epoch 338
#  Accuracy: 0.956
#  Loss:0.06315389321086194
#
# Epoch 339
#  Accuracy: 0.956
#  Loss:0.06301263398423952
#
# Epoch 340
#  Accuracy: 0.956
#  Loss:0.06287195546633882
#
# Epoch 341
#  Accuracy: 0.956
#  Loss:0.06273185452571362
#
# Epoch 342
#  Accuracy: 0.956
#  Loss:0.06259232806271943
#
# Epoch 343
#  Accuracy: 0.956
#  Loss:0.06245337300917975
#
# Epoch 344
#  Accuracy: 0.956
#  Loss:0.06231498632804513
#
# Epoch 345
#  Accuracy: 0.956
#  Loss:0.06217716501304597
#
# Epoch 346
#  Accuracy: 0.956
#  Loss:0.06203990608833916
#
# Epoch 347
#  Accuracy: 0.956
#  Loss:0.061903206608149186
#
# Epoch 348
#  Accuracy: 0.956
#  Loss:0.06176706365640367
#
# Epoch 349
#  Accuracy: 0.956
#  Loss:0.06163147434636422
#
# Epoch 350
#  Accuracy: 0.967
#  Loss:0.06149643582025267
#
# Epoch 351
#  Accuracy: 0.967
#  Loss:0.061361945248872965
#
# Epoch 352
#  Accuracy: 0.967
#  Loss:0.06122799983122946
#
# Epoch 353
#  Accuracy: 0.967
#  Loss:0.06109459679414151
#
# Epoch 354
#  Accuracy: 0.978
#  Loss:0.060961733391855136
#
# Epoch 355
#  Accuracy: 0.978
#  Loss:0.060829406905651716
#
# Epoch 356
#  Accuracy: 0.978
#  Loss:0.0606976146434543
#
# Epoch 357
#  Accuracy: 0.978
#  Loss:0.060566353939431966
#
# Epoch 358
#  Accuracy: 0.978
#  Loss:0.06043562215360203
#
# Epoch 359
#  Accuracy: 0.978
#  Loss:0.06030541667143111
#
# Epoch 360
#  Accuracy: 0.978
#  Loss:0.060175734903434974
#
# Epoch 361
#  Accuracy: 0.978
#  Loss:0.0600465742847774
#
# Epoch 362
#  Accuracy: 0.978
#  Loss:0.05991793227486864
#
# Epoch 363
#  Accuracy: 0.978
#  Loss:0.05978980635696348
#
# Epoch 364
#  Accuracy: 0.978
#  Loss:0.05966219403775962
#
# Epoch 365
#  Accuracy: 0.978
#  Loss:0.05953509284699599
#
# Epoch 366
#  Accuracy: 0.978
#  Loss:0.05940850033705196
#
# Epoch 367
#  Accuracy: 0.978
#  Loss:0.05928241408254741
#
# Epoch 368
#  Accuracy: 0.978
#  Loss:0.0591568316799436
#
# Epoch 369
#  Accuracy: 0.978
#  Loss:0.05903175074714588
#
# Epoch 370
#  Accuracy: 0.978
#  Loss:0.05890716892310766
#
# Epoch 371
#  Accuracy: 0.978
#  Loss:0.058783083867436456
#
# Epoch 372
#  Accuracy: 0.978
#  Loss:0.05865949326000191
#
# Epoch 373
#  Accuracy: 0.978
#  Loss:0.05853639480054622
#
# Epoch 374
#  Accuracy: 0.989
#  Loss:0.058413786208297055
#
# Epoch 375
#  Accuracy: 0.989
#  Loss:0.05829166522158331
#
# Epoch 376
#  Accuracy: 0.989
#  Loss:0.05817002959745357
#
# Epoch 377
#  Accuracy: 0.989
#  Loss:0.05804887711129814
#
# Epoch 378
#  Accuracy: 0.989
#  Loss:0.057928205556474044
#
# Epoch 379
#  Accuracy: 0.989
#  Loss:0.057808012743933664
#
# Epoch 380
#  Accuracy: 0.989
#  Loss:0.05768829650185712
#
# Epoch 381
#  Accuracy: 0.989
#  Loss:0.05756905467528849
#
# Epoch 382
#  Accuracy: 0.989
#  Loss:0.05745028512577605
#
# Epoch 383
#  Accuracy: 0.989
#  Loss:0.05733198573101657
#
# Epoch 384
#  Accuracy: 0.989
#  Loss:0.05721415438450413
#
# Epoch 385
#  Accuracy: 0.989
#  Loss:0.057096788995183216
#
# Epoch 386
#  Accuracy: 0.989
#  Loss:0.05697988748710644
#
# Epoch 387
#  Accuracy: 0.989
#  Loss:0.05686344779909705
#
# Epoch 388
#  Accuracy: 0.989
#  Loss:0.056747467884416106
#
# Epoch 389
#  Accuracy: 0.989
#  Loss:0.056631945710434686
#
# Epoch 390
#  Accuracy: 0.989
#  Loss:0.056516879258311135
#
# Epoch 391
#  Accuracy: 0.989
#  Loss:0.05640226652267327
#
# Epoch 392
#  Accuracy: 0.989
#  Loss:0.05628810551130611
#
# Epoch 393
#  Accuracy: 0.989
#  Loss:0.05617439424484445
#
# Epoch 394
#  Accuracy: 0.989
#  Loss:0.05606113075647122
#
# Epoch 395
#  Accuracy: 0.989
#  Loss:0.0559483130916211
#
# Epoch 396
#  Accuracy: 0.989
#  Loss:0.055835939307689535
#
# Epoch 397
#  Accuracy: 0.989
#  Loss:0.055724007473747325
#
# Epoch 398
#  Accuracy: 0.989
#  Loss:0.05561251567026111
#
# Epoch 399
#  Accuracy: 0.989
#  Loss:0.05550146198881904
#
# Epoch 400
#  Accuracy: 0.989
#  Loss:0.05539084453186234
#
# Epoch 401
#  Accuracy: 0.989
#  Loss:0.05528066141242259
#
# Epoch 402
#  Accuracy: 0.989
#  Loss:0.05517091075386477
#
# Epoch 403
#  Accuracy: 0.989
#  Loss:0.055061590689635904
#
# Epoch 404
#  Accuracy: 0.989
#  Loss:0.05495269936301953
#
# Epoch 405
#  Accuracy: 0.989
#  Loss:0.05484423492689599
#
# Epoch 406
#  Accuracy: 0.989
#  Loss:0.05473619554350847
#
# Epoch 407
#  Accuracy: 0.989
#  Loss:0.0546285793842347
#
# Epoch 408
#  Accuracy: 0.989
#  Loss:0.05452138462936463
#
# Epoch 409
#  Accuracy: 0.989
#  Loss:0.0544146094678836
#
# Epoch 410
#  Accuracy: 0.989
#  Loss:0.054308252097261464
#
# Epoch 411
#  Accuracy: 0.989
#  Loss:0.05420231072324726
#
# Epoch 412
#  Accuracy: 0.989
#  Loss:0.05409678355966972
#
# Epoch 413
#  Accuracy: 0.989
#  Loss:0.053991668828243314
#
# Epoch 414
#  Accuracy: 0.989
#  Loss:0.05388696475837998
#
# Epoch 415
#  Accuracy: 0.989
#  Loss:0.05378266958700637
#
# Epoch 416
#  Accuracy: 0.989
#  Loss:0.05367878155838676
#
# Epoch 417
#  Accuracy: 0.989
#  Loss:0.05357529892395141
#
# Epoch 418
#  Accuracy: 0.989
#  Loss:0.053472219942130236
#
# Epoch 419
#  Accuracy: 0.989
#  Loss:0.05336954287819218
#
# Epoch 420
#  Accuracy: 0.989
#  Loss:0.05326726600408963
#
# Epoch 421
#  Accuracy: 0.989
#  Loss:0.05316538759830835
#
# Epoch 422
#  Accuracy: 0.989
#  Loss:0.05306390594572247
#
# Epoch 423
#  Accuracy: 0.989
#  Loss:0.052962819337454704
#
# Epoch 424
#  Accuracy: 0.989
#  Loss:0.052862126070741845
#
# Epoch 425
#  Accuracy: 0.989
#  Loss:0.052761824448804895
#
# Epoch 426
#  Accuracy: 0.989
#  Loss:0.05266191278072459
#
# Epoch 427
#  Accuracy: 0.989
#  Loss:0.052562389381321496
#
# Epoch 428
#  Accuracy: 0.989
#  Loss:0.05246325257104111
#
# Epoch 429
#  Accuracy: 0.989
#  Loss:0.052364500675843674
#
# Epoch 430
#  Accuracy: 0.989
#  Loss:0.05226613202709842
#
# Epoch 431
#  Accuracy: 0.989
#  Loss:0.05216814496148287
#
# Epoch 432
#  Accuracy: 0.989
#  Loss:0.05207053782088613
#
# Epoch 433
#  Accuracy: 0.989
#  Loss:0.051973308952316936
#
# Epoch 434
#  Accuracy: 0.989
#  Loss:0.05187645670781593
#
# Epoch 435
#  Accuracy: 0.989
#  Loss:0.05177997944437214
#
# Epoch 436
#  Accuracy: 0.989
#  Loss:0.0516838755238437
#
# Epoch 437
#  Accuracy: 0.989
#  Loss:0.05158814331288271
#
# Epoch 438
#  Accuracy: 0.989
#  Loss:0.051492781182863816
#
# Epoch 439
#  Accuracy: 0.989
#  Loss:0.0513977875098171
#
# Epoch 440
#  Accuracy: 0.989
#  Loss:0.0513031606743644
#
# Epoch 441
#  Accuracy: 0.989
#  Loss:0.05120889906165961
#
# Epoch 442
#  Accuracy: 0.989
#  Loss:0.05111500106133262
#
# Epoch 443
#  Accuracy: 0.989
#  Loss:0.05102146506743647
#
# Epoch 444
#  Accuracy: 0.989
#  Loss:0.050928289478398545
#
# Epoch 445
#  Accuracy: 0.989
#  Loss:0.05083547269697459
#
# Epoch 446
#  Accuracy: 0.989
#  Loss:0.05074301313020635
#
# Epoch 447
#  Accuracy: 0.989
#  Loss:0.05065090918938223
#
# Epoch 448
#  Accuracy: 0.989
#  Loss:0.050559159290001196
#
# Epoch 449
#  Accuracy: 0.989
#  Loss:0.05046776185173955
#
# Epoch 450
#  Accuracy: 0.989
#  Loss:0.05037671529842073
#
# Epoch 451
#  Accuracy: 0.989
#  Loss:0.05028601805798796
#
# Epoch 452
#  Accuracy: 0.989
#  Loss:0.05019566856247957
#
# Epoch 453
#  Accuracy: 0.989
#  Loss:0.050105665248007095
#
# Epoch 454
#  Accuracy: 0.989
#  Loss:0.05001600655473578
#
# Epoch 455
#  Accuracy: 0.989
#  Loss:0.04992669092686786
#
# Epoch 456
#  Accuracy: 0.989
#  Loss:0.04983771681262799
#
# Epoch 457
#  Accuracy: 0.989
#  Loss:0.04974908266425107
#
# Epoch 458
#  Accuracy: 0.989
#  Loss:0.04966078693797249
#
# Epoch 459
#  Accuracy: 0.989
#  Loss:0.04957282809402022
#
# Epoch 460
#  Accuracy: 0.989
#  Loss:0.0494852045966093
#
# Epoch 461
#  Accuracy: 0.989
#  Loss:0.049397914913938155
#
# Epoch 462
#  Accuracy: 0.989
#  Loss:0.049310957518186864
#
# Epoch 463
#  Accuracy: 0.989
#  Loss:0.049224330885517316
#
# Epoch 464
#  Accuracy: 0.989
#  Loss:0.049138033496075054
#
# Epoch 465
#  Accuracy: 0.989
#  Loss:0.04905206383399295
#
# Epoch 466
#  Accuracy: 0.989
#  Loss:0.048966420387396424
#
# Epoch 467
#  Accuracy: 0.989
#  Loss:0.048881101648410114
#
# Epoch 468
#  Accuracy: 0.989
#  Loss:0.048796106113166184
#
# Epoch 469
#  Accuracy: 0.989
#  Loss:0.04871143228181401
#
# Epoch 470
#  Accuracy: 0.989
#  Loss:0.048627078658531095
#
# Epoch 471
#  Accuracy: 0.989
#  Loss:0.048543043751535384
#
# Epoch 472
#  Accuracy: 0.989
#  Loss:0.0484593260730987
#
# Epoch 473
#  Accuracy: 0.989
#  Loss:0.04837592413956135
#
# Epoch 474
#  Accuracy: 0.989
#  Loss:0.04829283647134777
#
# Epoch 475
#  Accuracy: 0.989
#  Loss:0.048210061592983244
#
# Epoch 476
#  Accuracy: 0.989
#  Loss:0.048127598033111535
#
# Epoch 477
#  Accuracy: 0.989
#  Loss:0.04804544432451336
#
# Epoch 478
#  Accuracy: 0.989
#  Loss:0.04796359900412584
#
# Epoch 479
#  Accuracy: 0.989
#  Loss:0.04788206061306253
#
# Epoch 480
#  Accuracy: 0.989
#  Loss:0.04780082769663431
#
# Epoch 481
#  Accuracy: 0.989
#  Loss:0.04771989880437092
#
# Epoch 482
#  Accuracy: 0.989
#  Loss:0.047639272490043065
#
# Epoch 483
#  Accuracy: 0.989
#  Loss:0.047558947311685064
#
# Epoch 484
#  Accuracy: 0.989
#  Loss:0.04747892183161816
#
# Epoch 485
#  Accuracy: 0.989
#  Loss:0.04739919461647402
#
# Epoch 486
#  Accuracy: 0.989
#  Loss:0.047319764237218925
#
# Epoch 487
#  Accuracy: 0.989
#  Loss:0.04724062926917819
#
# Epoch 488
#  Accuracy: 0.989
#  Loss:0.04716178829206088
#
# Epoch 489
#  Accuracy: 0.989
#  Loss:0.04708323988998486
#
# Epoch 490
#  Accuracy: 0.989
#  Loss:0.047004982651502124
#
# Epoch 491
#  Accuracy: 0.989
#  Loss:0.04692701516962422
#
# Epoch 492
#  Accuracy: 0.989
#  Loss:0.04684933604184786
#
# Epoch 493
#  Accuracy: 0.989
#  Loss:0.04677194387018077
#
# Epoch 494
#  Accuracy: 0.989
#  Loss:0.046694837261167375
#
# Epoch 495
#  Accuracy: 0.989
#  Loss:0.04661801482591483
#
# Epoch 496
#  Accuracy: 0.989
#  Loss:0.04654147518011875
#
# Epoch 497
#  Accuracy: 0.989
#  Loss:0.04646521694408919
#
# Epoch 498
#  Accuracy: 0.989
#  Loss:0.04638923874277642
#
# Epoch 499
#  Accuracy: 0.989
#  Loss:0.04631353920579662
#
# Epoch 500
#  Accuracy: 0.989
#  Loss:0.04623811696745751
#
# Epoch 501
#  Accuracy: 0.989
#  Loss:0.04616297066678384
#
# Epoch 502
#  Accuracy: 0.989
#  Loss:0.046088098947542615
#
# Epoch 503
#  Accuracy: 0.989
#  Loss:0.046013500458268256
#
# Epoch 504
#  Accuracy: 0.989
#  Loss:0.04593917385228747
#
# Epoch 505
#  Accuracy: 0.989
#  Loss:0.04586511778774379
#
# Epoch 506
#  Accuracy: 0.989
#  Loss:0.04579133092762205
#
# Epoch 507
#  Accuracy: 0.989
#  Loss:0.045717811939772326
#
# Epoch 508
#  Accuracy: 0.989
#  Loss:0.04564455949693384
#
# Epoch 509
#  Accuracy: 0.989
#  Loss:0.045571572276758156
#
# Epoch 510
#  Accuracy: 0.989
#  Loss:0.045498848961832365
#
# Epoch 511
#  Accuracy: 0.989
#  Loss:0.045426388239701854
#
# Epoch 512
#  Accuracy: 0.989
#  Loss:0.04535418880289244
#
# Epoch 513
#  Accuracy: 0.989
#  Loss:0.045282249348932345
#
# Epoch 514
#  Accuracy: 0.989
#  Loss:0.04521056858037367
#
# Epoch 515
#  Accuracy: 0.989
#  Loss:0.04513914520481337
#
# Epoch 516
#  Accuracy: 0.989
#  Loss:0.04506797793491395
#
# Epoch 517
#  Accuracy: 0.989
#  Loss:0.0449970654884235
#
# Epoch 518
#  Accuracy: 0.989
#  Loss:0.044926406588195335
#
# Epoch 519
#  Accuracy: 0.989
#  Loss:0.044855999962207224
#
# Epoch 520
#  Accuracy: 0.989
#  Loss:0.044785844343580045
#
# Epoch 521
#  Accuracy: 0.989
#  Loss:0.044715938470595885
#
# Epoch 522
#  Accuracy: 0.989
#  Loss:0.04464628108671571
#
# Epoch 523
#  Accuracy: 0.989
#  Loss:0.04457687094059658
#
# Epoch 524
#  Accuracy: 0.989
#  Loss:0.04450770678610799
#
# Epoch 525
#  Accuracy: 0.989
#  Loss:0.044438787382348244
#
# Epoch 526
#  Accuracy: 0.989
#  Loss:0.044370111493659666
#
# Epoch 527
#  Accuracy: 0.989
#  Loss:0.04430167788964376
#
# Epoch 528
#  Accuracy: 0.989
#  Loss:0.04423348534517547
#
# Epoch 529
#  Accuracy: 0.989
#  Loss:0.04416553264041701
#
# Epoch 530
#  Accuracy: 0.989
#  Loss:0.0440978185608313
#
# Epoch 531
#  Accuracy: 0.989
#  Loss:0.04403034189719436
#
# Epoch 532
#  Accuracy: 0.989
#  Loss:0.04396310144560776
#
# Epoch 533
#  Accuracy: 0.989
#  Loss:0.043896096007509953
#
# Epoch 534
#  Accuracy: 0.989
#  Loss:0.043829324389687285
#
# Epoch 535
#  Accuracy: 0.989
#  Loss:0.04376278540428446
#
# Epoch 536
#  Accuracy: 0.989
#  Loss:0.043696477868814226
#
# Epoch 537
#  Accuracy: 0.989
#  Loss:0.04363040060616675
#
# Epoch 538
#  Accuracy: 0.989
#  Loss:0.043564552444618196
#
# Epoch 539
#  Accuracy: 0.989
#  Loss:0.043498932217838765
#
# Epoch 540
#  Accuracy: 0.989
#  Loss:0.04343353876490026
#
# Epoch 541
#  Accuracy: 0.989
#  Loss:0.043368370930282917
#
# Epoch 542
#  Accuracy: 0.989
#  Loss:0.04330342756388183
#
# Epoch 543
#  Accuracy: 0.989
#  Loss:0.043238707521012616
#
# Epoch 544
#  Accuracy: 0.989
#  Loss:0.043174209662416724
#
# Epoch 545
#  Accuracy: 0.989
#  Loss:0.043109932854265925
#
# Epoch 546
#  Accuracy: 0.989
#  Loss:0.043045875968166385
#
# Epoch 547
#  Accuracy: 0.989
#  Loss:0.042982037881162255
#
# Epoch 548
#  Accuracy: 0.989
#  Loss:0.04291841747573846
#
# Epoch 549
#  Accuracy: 0.989
#  Loss:0.042855013639823095
#
# Epoch 550
#  Accuracy: 0.989
#  Loss:0.04279182526678928
#
# Epoch 551
#  Accuracy: 0.989
#  Loss:0.04272885125545635
#
# Epoch 552
#  Accuracy: 0.989
#  Loss:0.042666090510090605
#
# Epoch 553
#  Accuracy: 0.989
#  Loss:0.04260354194040549
#
# Epoch 554
#  Accuracy: 0.989
#  Loss:0.04254120446156112
#
# Epoch 555
#  Accuracy: 0.989
#  Loss:0.0424790769941636
#
# Epoch 556
#  Accuracy: 0.989
#  Loss:0.04241715846426329
#
# Epoch 557
#  Accuracy: 0.989
#  Loss:0.042355447803353145
#
# Epoch 558
#  Accuracy: 0.989
#  Loss:0.042293943948366046
#
# Epoch 559
#  Accuracy: 0.989
#  Loss:0.04223264584167194
#
# Epoch 560
#  Accuracy: 1.0
#  Loss:0.04217155243107431
#
# Epoch 561
#  Accuracy: 1.0
#  Loss:0.04211066266980616
#
# Epoch 562
#  Accuracy: 1.0
#  Loss:0.04204997551652562
#
# Epoch 563
#  Accuracy: 1.0
#  Loss:0.04198948993531093
#
# Epoch 564
#  Accuracy: 1.0
#  Loss:0.04192920489565502
#
# Epoch 565
#  Accuracy: 1.0
#  Loss:0.04186911937245958
#
# Epoch 566
#  Accuracy: 1.0
#  Loss:0.04180923234602869
#
# Epoch 567
#  Accuracy: 1.0
#  Loss:0.041749542802061994
#
# Epoch 568
#  Accuracy: 1.0
#  Loss:0.04169004973164735
#
# Epoch 569
#  Accuracy: 1.0
#  Loss:0.04163075213125314
#
# Epoch 570
#  Accuracy: 1.0
#  Loss:0.041571649002720076
#
# Epoch 571
#  Accuracy: 1.0
#  Loss:0.04151273935325256
#
# Epoch 572
#  Accuracy: 1.0
#  Loss:0.04145402219540968
#
# Epoch 573
#  Accuracy: 1.0
#  Loss:0.04139549654709565
#
# Epoch 574
#  Accuracy: 1.0
#  Loss:0.04133716143155006
#
# Epoch 575
#  Accuracy: 1.0
#  Loss:0.04127901587733753
#
# Epoch 576
#  Accuracy: 1.0
#  Loss:0.04122105891833704
#
# Epoch 577
#  Accuracy: 1.0
#  Loss:0.04116328959373084
#
# Epoch 578
#  Accuracy: 1.0
#  Loss:0.04110570694799306
#
# Epoch 579
#  Accuracy: 1.0
#  Loss:0.041048310030877735
#
# Epoch 580
#  Accuracy: 1.0
#  Loss:0.040991097897406806
#
# Epoch 581
#  Accuracy: 1.0
#  Loss:0.04093406960785741
#
# Epoch 582
#  Accuracy: 1.0
#  Loss:0.040877224227748976
#
# Epoch 583
#  Accuracy: 1.0
#  Loss:0.04082056082783001
#
# Epoch 584
#  Accuracy: 1.0
#  Loss:0.04076407848406449
#
# Epoch 585
#  Accuracy: 1.0
#  Loss:0.04070777627761785
#
# Epoch 586
#  Accuracy: 1.0
#  Loss:0.040651653294842785
#
# Epoch 587
#  Accuracy: 1.0
#  Loss:0.04059570862726464
#
# Epoch 588
#  Accuracy: 1.0
#  Loss:0.04053994137156652
#
# Epoch 589
#  Accuracy: 1.0
#  Loss:0.04048435062957405
#
# Epoch 590
#  Accuracy: 1.0
#  Loss:0.04042893550823995
#
# Epoch 591
#  Accuracy: 1.0
#  Loss:0.040373695119628135
#
# Epoch 592
#  Accuracy: 1.0
#  Loss:0.04031862858089777
#
# Epoch 593
#  Accuracy: 1.0
#  Loss:0.04026373501428673
#
# Epoch 594
#  Accuracy: 1.0
#  Loss:0.04020901354709522
#
# Epoch 595
#  Accuracy: 1.0
#  Loss:0.04015446331166865
#
# Epoch 596
#  Accuracy: 1.0
#  Loss:0.04010008344538068
#
# Epoch 597
#  Accuracy: 1.0
#  Loss:0.04004587309061566
#
# Epoch 598
#  Accuracy: 1.0
#  Loss:0.03999183139475116
#
# Epoch 599
#  Accuracy: 1.0
#  Loss:0.03993795751013998
#
# Epoch 600
#  Accuracy: 1.0
#  Loss:0.03988425059409205
#
# Epoch 601
#  Accuracy: 1.0
#  Loss:0.039830709808856175
#
# Epoch 602
#  Accuracy: 1.0
#  Loss:0.03977733432160144
#
# Epoch 603
#  Accuracy: 1.0
#  Loss:0.039724123304398465
#
# Epoch 604
#  Accuracy: 1.0
#  Loss:0.03967107593420049
#
# Epoch 605
#  Accuracy: 1.0
#  Loss:0.03961819139282413
#
# Epoch 606
#  Accuracy: 1.0
#  Loss:0.039565468866930124
#
# Epoch 607
#  Accuracy: 1.0
#  Loss:0.03951290754800375
#
# Epoch 608
#  Accuracy: 1.0
#  Loss:0.039460506632335156
#
# Epoch 609
#  Accuracy: 1.0
#  Loss:0.03940826532099944
#
# Epoch 610
#  Accuracy: 1.0
#  Loss:0.03935618281983659
#
# Epoch 611
#  Accuracy: 1.0
#  Loss:0.03930425833943135
#
# Epoch 612
#  Accuracy: 1.0
#  Loss:0.03925249109509277
#
# Epoch 613
#  Accuracy: 1.0
#  Loss:0.03920088030683373
#
# Epoch 614
#  Accuracy: 1.0
#  Loss:0.03914942519935026
#
# Epoch 615
#  Accuracy: 1.0
#  Loss:0.03909812500200082
#
# Epoch 616
#  Accuracy: 1.0
#  Loss:0.03904697894878525
#
# Epoch 617
#  Accuracy: 1.0
#  Loss:0.03899598627832382
#
# Epoch 618
#  Accuracy: 1.0
#  Loss:0.038945146233835964
#
# Epoch 619
#  Accuracy: 1.0
#  Loss:0.038894458063119065
#
# Epoch 620
#  Accuracy: 1.0
#  Loss:0.03884392101852702
#
# Epoch 621
#  Accuracy: 1.0
#  Loss:0.03879353435694872
#
# Epoch 622
#  Accuracy: 1.0
#  Loss:0.03874329733978641
#
# Epoch 623
#  Accuracy: 1.0
#  Loss:0.038693209232934074
#
# Epoch 624
#  Accuracy: 1.0
#  Loss:0.03864326930675554
#
# Epoch 625
#  Accuracy: 1.0
#  Loss:0.03859347683606262
#
# Epoch 626
#  Accuracy: 1.0
#  Loss:0.038543831100093205
#
# Epoch 627
#  Accuracy: 1.0
#  Loss:0.038494331382489144
#
# Epoch 628
#  Accuracy: 1.0
#  Loss:0.03844497697127416
#
# Epoch 629
#  Accuracy: 1.0
#  Loss:0.03839576715883171
#
# Epoch 630
#  Accuracy: 1.0
#  Loss:0.038346701241882664
#
# Epoch 631
#  Accuracy: 1.0
#  Loss:0.038297778521463065
#
# Epoch 632
#  Accuracy: 1.0
#  Loss:0.03824899830290175
#
# Epoch 633
#  Accuracy: 1.0
#  Loss:0.03820035989579796
#
# Epoch 634
#  Accuracy: 1.0
#  Loss:0.038151862613998846
#
# Epoch 635
#  Accuracy: 1.0
#  Loss:0.03810350577557703
#
# Epoch 636
#  Accuracy: 1.0
#  Loss:0.03805528870280809
#
# Epoch 637
#  Accuracy: 1.0
#  Loss:0.03800721072214787
#
# Epoch 638
#  Accuracy: 1.0
#  Loss:0.03795927116421008
#
# Epoch 639
#  Accuracy: 1.0
#  Loss:0.03791146936374353
#
# Epoch 640
#  Accuracy: 1.0
#  Loss:0.03786380465960953
#
# Epoch 641
#  Accuracy: 1.0
#  Loss:0.037816276394759284
#
# Epoch 642
#  Accuracy: 1.0
#  Loss:0.03776888391621111
#
# Epoch 643
#  Accuracy: 1.0
#  Loss:0.03772162657502794
#
# Epoch 644
#  Accuracy: 1.0
#  Loss:0.0376745037262944
#
# Epoch 645
#  Accuracy: 1.0
#  Loss:0.03762751472909428
#
# Epoch 646
#  Accuracy: 1.0
#  Loss:0.03758065894648781
#
# Epoch 647
#  Accuracy: 1.0
#  Loss:0.03753393574548893
#
# Epoch 648
#  Accuracy: 1.0
#  Loss:0.03748734449704261
#
# Epoch 649
#  Accuracy: 1.0
#  Loss:0.0374408845760022
#
# Epoch 650
#  Accuracy: 1.0
#  Loss:0.03739455536110676
#
# Epoch 651
#  Accuracy: 1.0
#  Loss:0.03734835623495837
#
# Epoch 652
#  Accuracy: 1.0
#  Loss:0.03730228658399956
#
# Epoch 653
#  Accuracy: 1.0
#  Loss:0.03725634579849066
#
# Epoch 654
#  Accuracy: 1.0
#  Loss:0.03721053327248721
#
# Epoch 655
#  Accuracy: 1.0
#  Loss:0.03716484840381741
#
# Epoch 656
#  Accuracy: 1.0
#  Loss:0.03711929059405958
#
# Epoch 657
#  Accuracy: 1.0
#  Loss:0.03707385924851968
#
# Epoch 658
#  Accuracy: 1.0
#  Loss:0.0370285537762088
#
# Epoch 659
#  Accuracy: 1.0
#  Loss:0.03698337358982077
#
# Epoch 660
#  Accuracy: 1.0
#  Loss:0.036938318105709814
#
# Epoch 661
#  Accuracy: 1.0
#  Loss:0.03689338674386804
#
# Epoch 662
#  Accuracy: 1.0
#  Loss:0.03684857892790329
#
# Epoch 663
#  Accuracy: 1.0
#  Loss:0.03680389408501686
#
# Epoch 664
#  Accuracy: 1.0
#  Loss:0.036759331645981226
#
# Epoch 665
#  Accuracy: 1.0
#  Loss:0.03671489104511791
#
# Epoch 666
#  Accuracy: 1.0
#  Loss:0.03667057172027541
#
# Epoch 667
#  Accuracy: 1.0
#  Loss:0.0366263731128071
#
# Epoch 668
#  Accuracy: 1.0
#  Loss:0.03658229466754926
#
# Epoch 669
#  Accuracy: 1.0
#  Loss:0.03653833583279915
#
# Epoch 670
#  Accuracy: 1.0
#  Loss:0.03649449606029303
#
# Epoch 671
#  Accuracy: 1.0
#  Loss:0.036450774805184556
#
# Epoch 672
#  Accuracy: 1.0
#  Loss:0.036407171526022845
#
# Epoch 673
#  Accuracy: 1.0
#  Loss:0.03636368568473081
#
# Epoch 674
#  Accuracy: 1.0
#  Loss:0.036320316746583654
#
# Epoch 675
#  Accuracy: 1.0
#  Loss:0.03627706418018718
#
# Epoch 676
#  Accuracy: 1.0
#  Loss:0.03623392745745649
#
# Epoch 677
#  Accuracy: 1.0
#  Loss:0.03619090605359434
#
# Epoch 678
#  Accuracy: 1.0
#  Loss:0.036147999447070076
#
# Epoch 679
#  Accuracy: 1.0
#  Loss:0.03610520711959816
#
# Epoch 680
#  Accuracy: 1.0
#  Loss:0.036062528556117135
#
# Epoch 681
#  Accuracy: 1.0
#  Loss:0.03601996324476841
#
# Epoch 682
#  Accuracy: 1.0
#  Loss:0.03597751067687536
#
# Epoch 683
#  Accuracy: 1.0
#  Loss:0.035935170346922285
#
# Epoch 684
#  Accuracy: 1.0
#  Loss:0.035892941752533596
#
# Epoch 685
#  Accuracy: 1.0
#  Loss:0.03585082439445304
#
# Epoch 686
#  Accuracy: 1.0
#  Loss:0.035808817776523
#
# Epoch 687
#  Accuracy: 1.0
#  Loss:0.03576692140566388
#
# Epoch 688
#  Accuracy: 1.0
#  Loss:0.03572513479185361
#
# Epoch 689
#  Accuracy: 1.0
#  Loss:0.03568345744810718
#
# Epoch 690
#  Accuracy: 1.0
#  Loss:0.03564188889045631
#
# Epoch 691
#  Accuracy: 1.0
#  Loss:0.03560042863792922
#
# Epoch 692
#  Accuracy: 1.0
#  Loss:0.03555907621253043
#
# Epoch 693
#  Accuracy: 1.0
#  Loss:0.035517831139220704
#
# Epoch 694
#  Accuracy: 1.0
#  Loss:0.03547669294589706
#
# Epoch 695
#  Accuracy: 1.0
#  Loss:0.0354356611633729
#
# Epoch 696
#  Accuracy: 1.0
#  Loss:0.035394735325358154
#
# Epoch 697
#  Accuracy: 1.0
#  Loss:0.03535391496843969
#
# Epoch 698
#  Accuracy: 1.0
#  Loss:0.0353131996320616
#
# Epoch 699
#  Accuracy: 1.0
#  Loss:0.03527258885850573
#
# Epoch 700
#  Accuracy: 1.0
#  Loss:0.03523208219287231
#
# Epoch 701
#  Accuracy: 1.0
#  Loss:0.035191679183060556
#
# Epoch 702
#  Accuracy: 1.0
#  Loss:0.035151379379749506
#
# Epoch 703
#  Accuracy: 1.0
#  Loss:0.03511118233637886
#
# Epoch 704
#  Accuracy: 1.0
#  Loss:0.035071087609130025
#
# Epoch 705
#  Accuracy: 1.0
#  Loss:0.03503109475690711
#
# Epoch 706
#  Accuracy: 1.0
#  Loss:0.03499120334131816
#
# Epoch 707
#  Accuracy: 1.0
#  Loss:0.03495141292665636
#
# Epoch 708
#  Accuracy: 1.0
#  Loss:0.03491172307988154
#
# Epoch 709
#  Accuracy: 1.0
#  Loss:0.0348721333706015
#
# Epoch 710
#  Accuracy: 1.0
#  Loss:0.03483264337105371
#
# Epoch 711
#  Accuracy: 1.0
#  Loss:0.03479325265608694
#
# Epoch 712
#  Accuracy: 1.0
#  Loss:0.03475396080314298
#
# Epoch 713
#  Accuracy: 1.0
#  Loss:0.0347147673922387
#
# Epoch 714
#  Accuracy: 1.0
#  Loss:0.03467567200594777
#
# Epoch 715
#  Accuracy: 1.0
#  Loss:0.03463667422938303
#
# Epoch 716
#  Accuracy: 1.0
#  Loss:0.0345977736501785
#
# Epoch 717
#  Accuracy: 1.0
#  Loss:0.034558969858471726
#
# Epoch 718
#  Accuracy: 1.0
#  Loss:0.03452026244688618
#
# Epoch 719
#  Accuracy: 1.0
#  Loss:0.03448165101051373
#
# Epoch 720
#  Accuracy: 1.0
#  Loss:0.03444313514689734
#
# Epoch 721
#  Accuracy: 1.0
#  Loss:0.034404714456013646
#
# Epoch 722
#  Accuracy: 1.0
#  Loss:0.03436638854025586
#
# Epoch 723
#  Accuracy: 1.0
#  Loss:0.03432815700441663
#
# Epoch 724
#  Accuracy: 1.0
#  Loss:0.034290019455671124
#
# Epoch 725
#  Accuracy: 1.0
#  Loss:0.034251975503560086
#
# Epoch 726
#  Accuracy: 1.0
#  Loss:0.0342140247599731
#
# Epoch 727
#  Accuracy: 1.0
#  Loss:0.03417616683913189
#
# Epoch 728
#  Accuracy: 1.0
#  Loss:0.03413840135757379
#
# Epoch 729
#  Accuracy: 1.0
#  Loss:0.03410072793413527
#
# Epoch 730
#  Accuracy: 1.0
#  Loss:0.03406314618993556
#
# Epoch 731
#  Accuracy: 1.0
#  Loss:0.03402565574836042
#
# Epoch 732
#  Accuracy: 1.0
#  Loss:0.033988256235045956
#
# Epoch 733
#  Accuracy: 1.0
#  Loss:0.03395094727786262
#
# Epoch 734
#  Accuracy: 1.0
#  Loss:0.03391372850689917
#
# Epoch 735
#  Accuracy: 1.0
#  Loss:0.03387659955444701
#
# Epoch 736
#  Accuracy: 1.0
#  Loss:0.03383956005498423
#
# Epoch 737
#  Accuracy: 1.0
#  Loss:0.03380260964516013
#
# Epoch 738
#  Accuracy: 1.0
#  Loss:0.03376574796377958
#
# Epoch 739
#  Accuracy: 1.0
#  Loss:0.03372897465178773
#
# Epoch 740
#  Accuracy: 1.0
#  Loss:0.033692289352254524
#
# Epoch 741
#  Accuracy: 1.0
#  Loss:0.03365569171035956
#
# Epoch 742
#  Accuracy: 1.0
#  Loss:0.03361918137337694
#
# Epoch 743
#  Accuracy: 1.0
#  Loss:0.03358275799066028
#
# Epoch 744
#  Accuracy: 1.0
#  Loss:0.033546421213627754
#
# Epoch 745
#  Accuracy: 1.0
#  Loss:0.03351017069574727
#
# Epoch 746
#  Accuracy: 1.0
#  Loss:0.03347400609252178
#
# Epoch 747
#  Accuracy: 1.0
#  Loss:0.03343792706147462
#
# Epoch 748
#  Accuracy: 1.0
#  Loss:0.03340193326213505
#
# Epoch 749
#  Accuracy: 1.0
#  Loss:0.03336602435602382
#
# Epoch 750
#  Accuracy: 1.0
#  Loss:0.03333020000663876
#
# Epoch 751
#  Accuracy: 1.0
#  Loss:0.03329445987944072
#
# Epoch 752
#  Accuracy: 1.0
#  Loss:0.033258803641839245
#
# Epoch 753
#  Accuracy: 1.0
#  Loss:0.033223230963178814
#
# Epoch 754
#  Accuracy: 1.0
#  Loss:0.03318774151472466
#
# Epoch 755
#  Accuracy: 1.0
#  Loss:0.03315233496964911
#
# Epoch 756
#  Accuracy: 1.0
#  Loss:0.033117011003017796
#
# Epoch 757
#  Accuracy: 1.0
#  Loss:0.03308176929177605
#
# Epoch 758
#  Accuracy: 1.0
#  Loss:0.03304660951473534
#
# Epoch 759
#  Accuracy: 1.0
#  Loss:0.033011531352559804
#
# Epoch 760
#  Accuracy: 1.0
#  Loss:0.032976534487753
#
# Epoch 761
#  Accuracy: 1.0
#  Loss:0.03294161860464462
#
# Epoch 762
#  Accuracy: 1.0
#  Loss:0.0329067833893773
#
# Epoch 763
#  Accuracy: 1.0
#  Loss:0.03287202852989361
#
# Epoch 764
#  Accuracy: 1.0
#  Loss:0.03283735371592312
#
# Epoch 765
#  Accuracy: 1.0
#  Loss:0.03280275863896941
#
# Epoch 766
#  Accuracy: 1.0
#  Loss:0.03276824299229745
#
# Epoch 767
#  Accuracy: 1.0
#  Loss:0.03273380647092081
#
# Epoch 768
#  Accuracy: 1.0
#  Loss:0.03269944877158916
#
# Epoch 769
#  Accuracy: 1.0
#  Loss:0.03266516959277569
#
# Epoch 770
#  Accuracy: 1.0
#  Loss:0.03263096863466481
#
# Epoch 771
#  Accuracy: 1.0
#  Loss:0.03259684559913968
#
# Epoch 772
#  Accuracy: 1.0
#  Loss:0.032562800189770195
#
# Epoch 773
#  Accuracy: 1.0
#  Loss:0.03252883211180068
#
# Epoch 774
#  Accuracy: 1.0
#  Loss:0.032494941072137976
#
# Epoch 775
#  Accuracy: 1.0
#  Loss:0.032461126779339364
#
# Epoch 776
#  Accuracy: 1.0
#  Loss:0.03242738894360086
#
# Epoch 777
#  Accuracy: 1.0
#  Loss:0.03239372727674529
#
# Epoch 778
#  Accuracy: 1.0
#  Loss:0.03236014149221074
#
# Epoch 779
#  Accuracy: 1.0
#  Loss:0.032326631305038836
#
# Epoch 780
#  Accuracy: 1.0
#  Loss:0.03229319643186337
#
# Epoch 781
#  Accuracy: 1.0
#  Loss:0.032259836590898774
#
# Epoch 782
#  Accuracy: 1.0
#  Loss:0.0322265515019288
#
# Epoch 783
#  Accuracy: 1.0
#  Loss:0.03219334088629534
#
# Epoch 784
#  Accuracy: 1.0
#  Loss:0.03216020446688717
#
# Epoch 785
#  Accuracy: 1.0
#  Loss:0.032127141968128964
#
# Epoch 786
#  Accuracy: 1.0
#  Loss:0.03209415311597018
#
# Epoch 787
#  Accuracy: 1.0
#  Loss:0.03206123763787429
#
# Epoch 788
#  Accuracy: 1.0
#  Loss:0.032028395262807874
#
# Epoch 789
#  Accuracy: 1.0
#  Loss:0.03199562572122985
#
# Epoch 790
#  Accuracy: 1.0
#  Loss:0.0319629287450809
#
# Epoch 791
#  Accuracy: 1.0
#  Loss:0.03193030406777283
#
# Epoch 792
#  Accuracy: 1.0
#  Loss:0.03189775142417806
#
# Epoch 793
#  Accuracy: 1.0
#  Loss:0.031865270550619246
#
# Epoch 794
#  Accuracy: 1.0
#  Loss:0.031832861184858945
#
# Epoch 795
#  Accuracy: 1.0
#  Loss:0.031800523066089305
#
# Epoch 796
#  Accuracy: 1.0
#  Loss:0.03176825593492195
#
# Epoch 797
#  Accuracy: 1.0
#  Loss:0.03173605953337787
#
# Epoch 798
#  Accuracy: 1.0
#  Loss:0.03170393360487736
#
# Epoch 799
#  Accuracy: 1.0
#  Loss:0.03167187789423011
#
# Epoch 800
#  Accuracy: 1.0
#  Loss:0.03163989214762538
#
# Epoch 801
#  Accuracy: 1.0
#  Loss:0.0316079761126221
#
# Epoch 802
#  Accuracy: 1.0
#  Loss:0.03157612953813929
#
# Epoch 803
#  Accuracy: 1.0
#  Loss:0.03154435217444632
#
# Epoch 804
#  Accuracy: 1.0
#  Loss:0.03151264377315342
#
# Epoch 805
#  Accuracy: 1.0
#  Loss:0.031481004087202176
#
# Epoch 806
#  Accuracy: 1.0
#  Loss:0.031449432870856046
#
# Epoch 807
#  Accuracy: 1.0
#  Loss:0.03141792987969123
#
# Epoch 808
#  Accuracy: 1.0
#  Loss:0.03138649487058707
#
# Epoch 809
#  Accuracy: 1.0
#  Loss:0.03135512760171724
#
# Epoch 810
#  Accuracy: 1.0
#  Loss:0.03132382783254035
#
# Epoch 811
#  Accuracy: 1.0
#  Loss:0.031292595323791014
#
# Epoch 812
#  Accuracy: 1.0
#  Loss:0.031261429837470864
#
# Epoch 813
#  Accuracy: 1.0
#  Loss:0.03123033113683962
#
# Epoch 814
#  Accuracy: 1.0
#  Loss:0.031199298986406273
#
# Epoch 815
#  Accuracy: 1.0
#  Loss:0.03116833315192038
#
# Epoch 816
#  Accuracy: 1.0
#  Loss:0.031137433400363197
#
# Epoch 817
#  Accuracy: 1.0
#  Loss:0.03110659949993932
#
# Epoch 818
#  Accuracy: 1.0
#  Loss:0.031075831220067872
#
# Epoch 819
#  Accuracy: 1.0
#  Loss:0.031045128331374114
#
# Epoch 820
#  Accuracy: 1.0
#  Loss:0.031014490605681105
#
# Epoch 821
#  Accuracy: 1.0
#  Loss:0.030983917816001242
#
# Epoch 822
#  Accuracy: 1.0
#  Loss:0.030953409736527968
#
# Epoch 823
#  Accuracy: 1.0
#  Loss:0.030922966142627642
#
# Epoch 824
#  Accuracy: 1.0
#  Loss:0.030892586810831287
#
# Epoch 825
#  Accuracy: 1.0
#  Loss:0.030862271518826548
#
# Epoch 826
#  Accuracy: 1.0
#  Loss:0.03083202004544966
#
# Epoch 827
#  Accuracy: 1.0
#  Loss:0.03080183217067746
#
# Epoch 828
#  Accuracy: 1.0
#  Loss:0.03077170767561953
#
# Epoch 829
#  Accuracy: 1.0
#  Loss:0.030741646342510334
#
# Epoch 830
#  Accuracy: 1.0
#  Loss:0.030711647954701465
#
# Epoch 831
#  Accuracy: 1.0
#  Loss:0.030681712296653854
#
# Epoch 832
#  Accuracy: 1.0
#  Loss:0.030651839153930247
#
# Epoch 833
#  Accuracy: 1.0
#  Loss:0.030622028313187544
#
# Epoch 834
#  Accuracy: 1.0
#  Loss:0.03059227956216925
#
# Epoch 835
#  Accuracy: 1.0
#  Loss:0.030562592689698027
#
# Epoch 836
#  Accuracy: 1.0
#  Loss:0.030532967485668347
#
# Epoch 837
#  Accuracy: 1.0
#  Loss:0.03050340374103909
#
# Epoch 838
#  Accuracy: 1.0
#  Loss:0.030473901247826212
#
# Epoch 839
#  Accuracy: 1.0
#  Loss:0.030444459799095564
#
# Epoch 840
#  Accuracy: 1.0
#  Loss:0.03041507918895577
#
# Epoch 841
#  Accuracy: 1.0
#  Loss:0.030385759212550954
#
# Epoch 842
#  Accuracy: 1.0
#  Loss:0.0303564996660539
#
# Epoch 843
#  Accuracy: 1.0
#  Loss:0.03032730034665885
#
# Epoch 844
#  Accuracy: 1.0
#  Loss:0.030298161052574706
#
# Epoch 845
#  Accuracy: 1.0
#  Loss:0.03026908158301796
#
# Epoch 846
#  Accuracy: 1.0
#  Loss:0.030240061738206127
#
# Epoch 847
#  Accuracy: 1.0
#  Loss:0.030211101319350696
#
# Epoch 848
#  Accuracy: 1.0
#  Loss:0.03018220012865057
#
# Epoch 849
#  Accuracy: 1.0
#  Loss:0.030153357969285324
#
# Epoch 850
#  Accuracy: 1.0
#  Loss:0.030124574645408634
#
# Epoch 851
#  Accuracy: 1.0
#  Loss:0.030095849962141655
#
# Epoch 852
#  Accuracy: 1.0
#  Loss:0.030067183725566583
#
# Epoch 853
#  Accuracy: 1.0
#  Loss:0.030038575742720085
#
# Epoch 854
#  Accuracy: 1.0
#  Loss:0.030010025821587065
#
# Epoch 855
#  Accuracy: 1.0
#  Loss:0.029981533771094086
#
# Epoch 856
#  Accuracy: 1.0
#  Loss:0.029953099401103245
#
# Epoch 857
#  Accuracy: 1.0
#  Loss:0.02992472252240584
#
# Epoch 858
#  Accuracy: 1.0
#  Loss:0.029896402946716194
#
# Epoch 859
#  Accuracy: 1.0
#  Loss:0.02986814048666545
#
# Epoch 860
#  Accuracy: 1.0
#  Loss:0.029839934955795507
#
# Epoch 861
#  Accuracy: 1.0
#  Loss:0.029811786168553015
#
# Epoch 862
#  Accuracy: 1.0
#  Loss:0.02978369394028322
#
# Epoch 863
#  Accuracy: 1.0
#  Loss:0.029755658087224163
#
# Epoch 864
#  Accuracy: 1.0
#  Loss:0.029727678426500675
#
# Epoch 865
#  Accuracy: 1.0
#  Loss:0.029699754776118505
#
# Epoch 866
#  Accuracy: 1.0
#  Loss:0.029671886954958558
#
# Epoch 867
#  Accuracy: 1.0
#  Loss:0.02964407478277112
#
# Epoch 868
#  Accuracy: 1.0
#  Loss:0.029616318080170047
#
# Epoch 869
#  Accuracy: 1.0
#  Loss:0.02958861666862729
#
# Epoch 870
#  Accuracy: 1.0
#  Loss:0.029560970370466944
#
# Epoch 871
#  Accuracy: 1.0
#  Loss:0.029533379008859946
#
# Epoch 872
#  Accuracy: 1.0
#  Loss:0.029505842407818415
#
# Epoch 873
#  Accuracy: 1.0
#  Loss:0.029478360392190112
#
# Epoch 874
#  Accuracy: 1.0
#  Loss:0.029450932787653126
#
# Epoch 875
#  Accuracy: 1.0
#  Loss:0.029423559420710246
#
# Epoch 876
#  Accuracy: 1.0
#  Loss:0.029396240118683827
#
# Epoch 877
#  Accuracy: 1.0
#  Loss:0.02936897470971028
#
# Epoch 878
#  Accuracy: 1.0
#  Loss:0.029341763022734883
#
# Epoch 879
#  Accuracy: 1.0
#  Loss:0.029314604887506552
#
# Epoch 880
#  Accuracy: 1.0
#  Loss:0.02928750013457256
#
# Epoch 881
#  Accuracy: 1.0
#  Loss:0.02926044859527344
#
# Epoch 882
#  Accuracy: 1.0
#  Loss:0.029233450101737862
#
# Epoch 883
#  Accuracy: 1.0
#  Loss:0.029206504486877557
#
# Epoch 884
#  Accuracy: 1.0
#  Loss:0.029179611584382276
#
# Epoch 885
#  Accuracy: 1.0
#  Loss:0.029152771228714767
#
# Epoch 886
#  Accuracy: 1.0
#  Loss:0.029125983255105837
#
# Epoch 887
#  Accuracy: 1.0
#  Loss:0.02909924749954951
#
# Epoch 888
#  Accuracy: 1.0
#  Loss:0.02907256379879797
#
# Epoch 889
#  Accuracy: 1.0
#  Loss:0.02904593199035696
#
# Epoch 890
#  Accuracy: 1.0
#  Loss:0.029019351912480732
#
# Epoch 891
#  Accuracy: 1.0
#  Loss:0.028992823404167506
#
# Epoch 892
#  Accuracy: 1.0
#  Loss:0.02896634630515457
#
# Epoch 893
#  Accuracy: 1.0
#  Loss:0.028939920455913745
#
# Epoch 894
#  Accuracy: 1.0
#  Loss:0.028913545697646568
#
# Epoch 895
#  Accuracy: 1.0
#  Loss:0.02888722187227983
#
# Epoch 896
#  Accuracy: 1.0
#  Loss:0.02886094882246093
#
# Epoch 897
#  Accuracy: 1.0
#  Loss:0.02883472639155332
#
# Epoch 898
#  Accuracy: 1.0
#  Loss:0.02880855442363198
#
# Epoch 899
#  Accuracy: 1.0
#  Loss:0.028782432763479093
#
# Epoch 900
#  Accuracy: 1.0
#  Loss:0.02875636125657946
#
# Epoch 901
#  Accuracy: 1.0
#  Loss:0.02873033974911605
#
# Epoch 902
#  Accuracy: 1.0
#  Loss:0.028704368087965854
#
# Epoch 903
#  Accuracy: 1.0
#  Loss:0.02867844612069535
#
# Epoch 904
#  Accuracy: 1.0
#  Loss:0.02865257369555635
#
# Epoch 905
#  Accuracy: 1.0
#  Loss:0.028626750661481577
#
# Epoch 906
#  Accuracy: 1.0
#  Loss:0.028600976868080632
#
# Epoch 907
#  Accuracy: 1.0
#  Loss:0.02857525216563563
#
# Epoch 908
#  Accuracy: 1.0
#  Loss:0.02854957640509711
#
# Epoch 909
#  Accuracy: 1.0
#  Loss:0.02852394943807986
#
# Epoch 910
#  Accuracy: 1.0
#  Loss:0.028498371116858923
#
# Epoch 911
#  Accuracy: 1.0
#  Loss:0.028472841294365416
#
# Epoch 912
#  Accuracy: 1.0
#  Loss:0.028447359824182516
#
# Epoch 913
#  Accuracy: 1.0
#  Loss:0.028421926560541492
#
# Epoch 914
#  Accuracy: 1.0
#  Loss:0.028396541358317724
#
# Epoch 915
#  Accuracy: 1.0
#  Loss:0.028371204073026728
#
# Epoch 916
#  Accuracy: 1.0
#  Loss:0.028345914560820265
#
# Epoch 917
#  Accuracy: 1.0
#  Loss:0.028320672678482497
#
# Epoch 918
#  Accuracy: 1.0
#  Loss:0.02829547828342606
#
# Epoch 919
#  Accuracy: 1.0
#  Loss:0.028270331233688294
#
# Epoch 920
#  Accuracy: 1.0
#  Loss:0.028245231387927443
#
# Epoch 921
#  Accuracy: 1.0
#  Loss:0.028220178605418884
#
# Epoch 922
#  Accuracy: 1.0
#  Loss:0.028195172746051413
#
# Epoch 923
#  Accuracy: 1.0
#  Loss:0.028170213670323473
#
# Epoch 924
#  Accuracy: 1.0
#  Loss:0.02814530123933959
#
# Epoch 925
#  Accuracy: 1.0
#  Loss:0.028120435314806628
#
# Epoch 926
#  Accuracy: 1.0
#  Loss:0.028095615759030225
#
# Epoch 927
#  Accuracy: 1.0
#  Loss:0.028070842434911154
#
# Epoch 928
#  Accuracy: 1.0
#  Loss:0.028046115205941795
#
# Epoch 929
#  Accuracy: 1.0
#  Loss:0.028021433936202614
#
# Epoch 930
#  Accuracy: 1.0
#  Loss:0.02799679849035855
#
# Epoch 931
#  Accuracy: 1.0
#  Loss:0.02797220873365571
#
# Epoch 932
#  Accuracy: 1.0
#  Loss:0.02794766453191771
#
# Epoch 933
#  Accuracy: 1.0
#  Loss:0.027923165751542432
#
# Epoch 934
#  Accuracy: 1.0
#  Loss:0.02789871225949844
#
# Epoch 935
#  Accuracy: 1.0
#  Loss:0.02787430392332175
#
# Epoch 936
#  Accuracy: 1.0
#  Loss:0.027849940611112414
#
# Epoch 937
#  Accuracy: 1.0
#  Loss:0.027825622191531185
#
# Epoch 938
#  Accuracy: 1.0
#  Loss:0.02780134853379621
#
# Epoch 939
#  Accuracy: 1.0
#  Loss:0.027777119507679773
#
# Epoch 940
#  Accuracy: 1.0
#  Loss:0.027752934983505093
#
# Epoch 941
#  Accuracy: 1.0
#  Loss:0.027728794832142967
#
# Epoch 942
#  Accuracy: 1.0
#  Loss:0.027704698925008712
#
# Epoch 943
#  Accuracy: 1.0
#  Loss:0.027680647134058815
#
# Epoch 944
#  Accuracy: 1.0
#  Loss:0.027656639331787983
#
# Epoch 945
#  Accuracy: 1.0
#  Loss:0.027632675391225832
#
# Epoch 946
#  Accuracy: 1.0
#  Loss:0.027608755185933878
#
# Epoch 947
#  Accuracy: 1.0
#  Loss:0.027584878590002433
#
# Epoch 948
#  Accuracy: 1.0
#  Loss:0.027561045478047535
#
# Epoch 949
#  Accuracy: 1.0
#  Loss:0.027537255725207876
#
# Epoch 950
#  Accuracy: 1.0
#  Loss:0.02751350920714186
#
# Epoch 951
#  Accuracy: 1.0
#  Loss:0.027489805800024546
#
# Epoch 952
#  Accuracy: 1.0
#  Loss:0.02746614538054469
#
# Epoch 953
#  Accuracy: 1.0
#  Loss:0.02744252782590182
#
# Epoch 954
#  Accuracy: 1.0
#  Loss:0.027418953013803336
#
# Epoch 955
#  Accuracy: 1.0
#  Loss:0.027395420822461443
#
# Epoch 956
#  Accuracy: 1.0
#  Loss:0.02737193113059048
#
# Epoch 957
#  Accuracy: 1.0
#  Loss:0.027348483817403953
#
# Epoch 958
#  Accuracy: 1.0
#  Loss:0.02732507876261167
#
# Epoch 959
#  Accuracy: 1.0
#  Loss:0.02730171584641696
#
# Epoch 960
#  Accuracy: 1.0
#  Loss:0.027278394949513906
#
# Epoch 961
#  Accuracy: 1.0
#  Loss:0.02725511595308444
#
# Epoch 962
#  Accuracy: 1.0
#  Loss:0.027231878738795724
#
# Epoch 963
#  Accuracy: 1.0
#  Loss:0.027208683188797374
#
# Epoch 964
#  Accuracy: 1.0
#  Loss:0.02718552918571871
#
# Epoch 965
#  Accuracy: 1.0
#  Loss:0.027162416612665996
#
# Epoch 966
#  Accuracy: 1.0
#  Loss:0.027139345353219962
#
# Epoch 967
#  Accuracy: 1.0
#  Loss:0.027116315291432942
#
# Epoch 968
#  Accuracy: 1.0
#  Loss:0.02709332631182627
#
# Epoch 969
#  Accuracy: 1.0
#  Loss:0.027070378299387805
#
# Epoch 970
#  Accuracy: 1.0
#  Loss:0.027047471139569134
#
# Epoch 971
#  Accuracy: 1.0
#  Loss:0.027024604718283128
#
# Epoch 972
#  Accuracy: 1.0
#  Loss:0.027001778921901302
#
# Epoch 973
#  Accuracy: 1.0
#  Loss:0.026978993637251304
#
# Epoch 974
#  Accuracy: 1.0
#  Loss:0.0269562487516144
#
# Epoch 975
#  Accuracy: 1.0
#  Loss:0.026933544152722914
#
# Epoch 976
#  Accuracy: 1.0
#  Loss:0.02691087972875775
#
# Epoch 977
#  Accuracy: 1.0
#  Loss:0.026888255368346017
#
# Epoch 978
#  Accuracy: 1.0
#  Loss:0.0268656709605584
#
# Epoch 979
#  Accuracy: 1.0
#  Loss:0.026843126394906887
#
# Epoch 980
#  Accuracy: 1.0
#  Loss:0.026820621561342208
#
# Epoch 981
#  Accuracy: 1.0
#  Loss:0.026798156350251567
#
# Epoch 982
#  Accuracy: 1.0
#  Loss:0.026775730652456156
#
# Epoch 983
#  Accuracy: 1.0
#  Loss:0.026753344359208835
#
# Epoch 984
#  Accuracy: 1.0
#  Loss:0.02673099736219177
#
# Epoch 985
#  Accuracy: 1.0
#  Loss:0.026708689553514065
#
# Epoch 986
#  Accuracy: 1.0
#  Loss:0.026686420825709503
#
# Epoch 987
#  Accuracy: 1.0
#  Loss:0.026664191071734233
#
# Epoch 988
#  Accuracy: 1.0
#  Loss:0.02664200018496441
#
# Epoch 989
#  Accuracy: 1.0
#  Loss:0.02661984805919401
#
# Epoch 990
#  Accuracy: 1.0
#  Loss:0.026597734588632557
#
# Epoch 991
#  Accuracy: 1.0
#  Loss:0.02657565966790288
#
# Epoch 992
#  Accuracy: 1.0
#  Loss:0.026553623192038876
#
# Epoch 993
#  Accuracy: 1.0
#  Loss:0.02653162505648329
#
# Epoch 994
#  Accuracy: 1.0
#  Loss:0.026509665157085582
#
# Epoch 995
#  Accuracy: 1.0
#  Loss:0.026487743390099745
#
# Epoch 996
#  Accuracy: 1.0
#  Loss:0.026465859652182032
#
# Epoch 997
#  Accuracy: 1.0
#  Loss:0.02644401384038898
#
# Epoch 998
#  Accuracy: 1.0
#  Loss:0.02642220585217518
#
# Epoch 999
#  Accuracy: 1.0
#  Loss:0.02640043558539114
#
# Epoch 1000
#  Accuracy: 1.0
#  Loss:0.02637870293828129

# %% [markdown]
# ## 6. Analyze the result
# To analyze the result compute the losses and the accuracy of the test set. Also make a plot of the training loss and training accuracy as function of the epoch.

# %%
# compute the accuracy and losses of the test set
a0 = X_test
z1 = W1@a0+b1
a1 = sigmoid(z1)
z2 = W2@a1+b2        
a2 = softmax(z2)

interim = np.round(a2)==Y_test

accuracy = np.sum(interim[1,:])/len(X_test.T)

loss = - np.mean(Y_test*np.log(a2))

print(f"Test accuracy: {accuracy} \n Test loss: {loss}")
# Out:
# Test accuracy: 1.0
#  Test loss: 0.03579439176640511

# %%
# plot the loss and accuracy as function of the epoch number
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
plt.sca(ax1)
plt.plot(accuracies)
plt.xlabel('epoch')
plt.ylabel('train accuracy')

plt.sca(ax2)
plt.plot(losses)
plt.xlabel('epoch')
plt.ylabel('train loss')
# Out:
# Text(0, 0.5, 'train loss')

# %% [markdown]
# Below you find some code to plot the data and the model prediction.

# %%
# visualize the results

# plot the model as a filled contour plot
# build mesh of gridpoints
x1_min, x1_max = X[0,:].min(), X[0,:].max()
x2_min, x2_max = X[1,:].min(), X[1,:].max()
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max), np.linspace(x2_min, x2_max))

# compute hypothesis on the meshgrid 
# first create a 2xM ndarray with the values of the scores on the mesh 
X_mesh = np.vstack((xx1.ravel(), xx2.ravel()))

# compute the output of the network
a1 = sigmoid(W1 @ X_mesh + b1)
a2 = softmax(W2 @ a1 + b2)
h = a2[0] # select either one of the two features
h = h.reshape(xx1.shape)

# plot the contour level(s)
levels = [0.0, 0.5, 1.0]
plt.contourf(xx1, xx2, h, levels, alpha=0.3)

# plot the data
mask = Y == 1
plt.scatter(*X[:2, mask], s=50, c='g', marker='o', label='OK')
plt.scatter(*X[:2,~mask], s=50, c='r', marker='o', label='failed')
plt.legend()
plt.xlabel('Normalized Score test 1')
plt.ylabel('Normalized Score test 2')
# Out:
# Text(0, 0.5, 'Normalized Score test 2')
