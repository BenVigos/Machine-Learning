# %% [markdown]
# # Neural Networks (part 1)

# %% [markdown]
# ## 1. Introduction
# Start by watching the following youtube video from 3blue1brown for a nice introduction in the concepts of neural networks (NN). The example that is used in the video is about handwriting digits classification. You will build a neural network that does exactly that.
#
# The link to the video: https://www.youtube.com/watch?v=aircAruvnKk
#
# Refer to the lecture notes on Canvas for the mathematical description of the network. In this notebook we will use the same names and conventions as used in the lecture notes.

# %% [markdown]
# ## 2. Loading the data
#
# In this notebook you will use a NN to classify the dataset `NNdata1.txt`. It contains the scores of $M$ students, their scores on two separte tests, and the label (0/1) wether they passed the course or not.
#
# **Notebook aim:** Build a NN model to predict wether a student will pass or not based on the two inputs of the two test scores.

# %%
# importing the required modules
import numpy as np
import matplotlib.pyplot as plt

# to get matplot figures render correctly in the notebook use:
# %matplotlib inline

# %%
# load the data
data = np.loadtxt('NNdata1.txt', delimiter=',')

X1 = data[:,0]
X2 = data[:,1]
Y = data[:,2]

plt.scatter(X1[Y==0], X2[Y==0])
plt.scatter(X1[Y==1], X2[Y==1], marker = '*')

# %% [markdown]
# ## 3. Create the feature matrix X and labels matrix Y
#
# The data that is fed into the NN constist of column vectors $\textbf x_i$ containing the features of the sample $i$. Because usually many samples are required to train and test the NN it is computationally not very efficient to pass them one-by-one. Therefore we have to write the code such that a whole batch of samples can be passed through the network simultaneously. To do so the data is organised in 2 matrices $\textbf X$ and $\textbf Y$
# The feature matrix $\textbf X$ contains the features $\textbf x_i$ of the different samples as columns. If we have $m$ samples then $\textbf X \in \mathbb{R}^{n_0 \times m}$. $\color{red}\text{Note that this is different than used sofar!}$
#
# For every sample $\textbf x_i$ a corresponding column vector $\textbf y_i$ exists that gives the category to which the sample belongs. The vector $\textbf y_i$ is a so-called one-hot-encoded label and has $n_L$ (the number of nodes in the output layer) elements. Since each output node of the NN corresponds to one of the possible categories to which a sample belongs, the element of the vector $\textbf y_i$ that corresponds to the category of the sample is equal to 1 and all other elements are zero. For example, if we have two categories '0' and '1' (as is the case in the current problem where the student is either rejected or accepted), and let's say we have 4 samples belonging to category 1, 0, 0, 1 respectively then $\textbf Y$ is given by:
#
# $$ \textbf Y = \begin{bmatrix}
# 0 & 1 & 1 & 0\\
# 1 & 0 & 0 & 1
# \end{bmatrix} $$
#
# The matrix $\textbf Y$ contains the one-hot encoded labels $\textbf y_i$ of the samples as columns. If we have $m$ samples then $\textbf Y \in \mathbb{R}^{n_L \times m}$

# %%
#create feature matrix
X = np.column_stack((X1, X2))

#apply feature scaling to the matix
X =  (X-np.mean(X,axis=0))/np.std(X,axis=0)
X = X.T

#create one-hot encoded Y matrix
Y_hot = np.column_stack(((Y-1)**2, Y)).T

# %% [markdown]
# Next you need to split $X$ and $Y$ in a training set (data used to train the network) and a test set (data used to test the network). Normally you would also use a validation set to tune hyperparameters of the model/training but we leave that to part 2 of the NN notebook

# %%
# create a train and test dataset with size-ratio 9:1

cutoff = int(len(X1)*0.9)

X_train = X[:,:cutoff]
Y_train = Y_hot[:,:cutoff]

X_test = X[:,cutoff:]
Y_test = Y_hot[:,cutoff:]

# %% [markdown]
# ## 4. The Neural Network
#
# The NN that you will make has the following layout:
#
# ![NNlayout232.png](attachment:411ea2d9-4686-4bd1-ac42-37d0fd0ff5ea.png)
#
# It consists of an input layer with two nodes because each sample consists of two features (score test 1 and score test 2). Then we have one hidden layer consisting of three nodes. Finally the output layer has two nodes corresponding to the two categories that need to be distinghuished.
#
# The hidden layer has a **sigmoid** activation function while the outputlayer has a **softmax** activation function.

# %% [markdown]
# ### Define the activation functions
#
# Below you define the required activation functions and their derivatives

# %%
# define some activation functions

def sigmoid(z):
    """
    returns the sigmoid function of z

    Parameters
    ----------
    z : float or ndarray

    Returns
    -------
    out : same type and shape as z

    """
    
    return 1/(1+np.exp(-z))


def sigmoid_diff(z):
    """
    returns the derivative of the sigmoid function of z

    Parameters
    ----------
    z : float or ndarray

    Returns
    -------
    out : same type and shape as z

    """
    
    sigma = sigmoid(z)
    
    return sigma*(1-sigma)


def softmax(z):
    """
    returns the softmax function of z

    Parameters
    ----------
    z : 2D ndarray

    Returns
    -------
    out : same type and shape as z

    """
    
    e = np.exp(z)
    
    return e/np.sum(e, axis=0)

# %% [markdown]
# ### Initalize the weights and biases
# The layers are denoted with $l$. Our NN has an input layer ($l=0$), an output layer ($l=L=2$) and a hidden layer ($l=1$).
#
# For each layer $l$ we have:
# 1. A number of nodes: $n_l$
# 2. A weight matrix: $\textbf W^{l} \in \mathbb{R}^{n_l \times n_{l-1}}$
# 3. A bias (column) vector: $\textbf b^{l} \in \mathbb{R}^{n_l \times 1}$
#
# The input layer actually does not do much, it just passes the sample data to the output which then acts as input for the first hidden layer. So the input layer does not have a weight and bias.
#
# The biases can be initialized with zeros; the weight's of layer $l$ are best intialized with random numbers from a normal distribution with mean 0 and standard deviation of $\sqrt{1/n_{l-1}}$.

# %%
# intialize the neural network

# number of nodes in each layer
n0 = 2
n1 = 3
n2 = 2

# input layer
# no weights and biases

# hidden layer (l=1)
W1 = np.random.normal(scale=np.sqrt(1/n0), size=(n1, n0))
b1 = np.zeros(shape=(n1,1))

# output layer (l=2)
W2 = np.random.normal(scale=np.sqrt(1/n1), size=(n2, n1))
b2 = np.zeros(shape=(n2,1))

# %% [markdown]
# ## 5. Train the NN

# %% [markdown]
# Firt you define three parameters that can be adjusted for optimal training.
# - **learning_rate**: determines to what extend we update the weights and biases in the gradient descent step
# - **no_epochs**: the number of times we pass the training data set through the network for training
# - **batch_size**: how many samples we pass through the network before doing a gradient descent update

# %%
# train settings
learning_rate = 0.1
no_epochs = 1000
batch_size = 10

# %% [markdown]
# Below you implement the training of the network. A general layout (pseudocode) is already given. Note that we use the **Cross Entropy** (CE) loss function.

# %%
# perform the training
accuracies = []
losses = []


for epoch in range(1, no_epochs + 1):
    
    # for each epoch train over all batches
    for b in range(int(np.floor(len(X_train.T)/batch_size))):
        X_batch = X_train[:, batch_size*b:(batch_size*(b+1))]
        Y_batch = Y_train[:, batch_size*b:(batch_size*(b+1))]
        
        # forward pass
        # compute the output of the network for the batch
        a0 = X_batch
        z1 = W1@a0+b1
        a1 = sigmoid(z1)
        z2 = W2@a1+b2        
        a2 = softmax(z2)
        
        # backward pass
        # compute the derivatives dLdW and dLdb for the layers (use CE loss)
        dLdz2 = a2 - Y_batch
        dLdW2 = dLdz2@a1.T
        dLdb2 = dLdz2
        
        dLdz1 = sigmoid_diff(z1)*(W2.T@dLdz2)
        dLdW1 = dLdz1@a0.T
        dLdb1 = dLdz1
        
        # gradient descent step / update weights and biases
        prefactor = learning_rate*1/batch_size
        
        W1 = W1 - prefactor*dLdW1 #Should sum over entire batch
        W2 = W2 - prefactor*dLdW2 #Should sum over entire batch
        
        b1 = b1 - prefactor*np.sum(dLdb1, axis=1).reshape(-1, 1)
        b2 = b2 - prefactor*np.sum(dLdb2, axis=1).reshape(-1, 1)
    
    # for each epoch evaluate the network performance
    # compute accuracy of train set and store for later analysis
    
    a0 = X_train
    z1 = W1@a0+b1
    a1 = sigmoid(z1)
    z2 = W2@a1+b2        
    a2 = softmax(z2)
    
    interim = np.round(a2)==Y_train
    
    accuracy = np.sum(interim[1,:])/len(X_train.T)
    loss = - np.mean(Y_train*np.log(a2))
    
    accuracies.append(accuracy)
    losses.append(loss)
    
    # for each epoch print info on learning progress
    print(f"Epoch {epoch} \n Accuracy: {accuracy:.3} \n Loss:{loss} \n")
# Out:
# Epoch 1
#  Accuracy: 0.567
#  Loss:0.33194197933917546
#
# Epoch 2
#  Accuracy: 0.567
#  Loss:0.3243735187301981
#
# Epoch 3
#  Accuracy: 0.567
#  Loss:0.3168232416205864
#
# Epoch 4
#  Accuracy: 0.622
#  Loss:0.3090246881411882
#
# Epoch 5
#  Accuracy: 0.633
#  Loss:0.30087725985286695
#
# Epoch 6
#  Accuracy: 0.7
#  Loss:0.29235922431987854
#
# Epoch 7
#  Accuracy: 0.789
#  Loss:0.28350184833893166
#
# Epoch 8
#  Accuracy: 0.822
#  Loss:0.2743760720549618
#
# Epoch 9
#  Accuracy: 0.856
#  Loss:0.2650808089621439
#
# Epoch 10
#  Accuracy: 0.878
#  Loss:0.25573097014481727
#
# Epoch 11
#  Accuracy: 0.9
#  Loss:0.2464458002128437
#
# Epoch 12
#  Accuracy: 0.9
#  Loss:0.23733869464433519
#
# Epoch 13
#  Accuracy: 0.911
#  Loss:0.228509467930014
#
# Epoch 14
#  Accuracy: 0.911
#  Loss:0.2200395184413268
#
# Epoch 15
#  Accuracy: 0.911
#  Loss:0.21198978589846346
#
# Epoch 16
#  Accuracy: 0.922
#  Loss:0.2044009996202235
#
# Epoch 17
#  Accuracy: 0.922
#  Loss:0.19729553127529056
#
# Epoch 18
#  Accuracy: 0.922
#  Loss:0.19068016688629671
#
# Epoch 19
#  Accuracy: 0.922
#  Loss:0.18454923006878585
#
# Epoch 20
#  Accuracy: 0.922
#  Loss:0.1788876512814894
#
# Epoch 21
#  Accuracy: 0.911
#  Loss:0.17367373570525502
#
# Epoch 22
#  Accuracy: 0.911
#  Loss:0.1688815091396505
#
# Epoch 23
#  Accuracy: 0.9
#  Loss:0.1644826099227457
#
# Epoch 24
#  Accuracy: 0.9
#  Loss:0.1604477492705999
#
# Epoch 25
#  Accuracy: 0.889
#  Loss:0.15674779087123394
#
# Epoch 26
#  Accuracy: 0.889
#  Loss:0.15335451156664331
#
# Epoch 27
#  Accuracy: 0.889
#  Loss:0.15024110542015015
#
# Epoch 28
#  Accuracy: 0.889
#  Loss:0.14738248827510717
#
# Epoch 29
#  Accuracy: 0.889
#  Loss:0.14475545219226646
#
# Epoch 30
#  Accuracy: 0.889
#  Loss:0.14233871075742985
#
# Epoch 31
#  Accuracy: 0.889
#  Loss:0.14011286819085902
#
# Epoch 32
#  Accuracy: 0.9
#  Loss:0.138060337965315
#
# Epoch 33
#  Accuracy: 0.9
#  Loss:0.13616523045097137
#
# Epoch 34
#  Accuracy: 0.9
#  Loss:0.134413223983668
#
# Epoch 35
#  Accuracy: 0.9
#  Loss:0.1327914296360775
#
# Epoch 36
#  Accuracy: 0.9
#  Loss:0.13128825674992628
#
# Epoch 37
#  Accuracy: 0.9
#  Loss:0.12989328383215443
#
# Epoch 38
#  Accuracy: 0.9
#  Loss:0.12859713759662195
#
# Epoch 39
#  Accuracy: 0.9
#  Loss:0.1273913816210181
#
# Epoch 40
#  Accuracy: 0.9
#  Loss:0.1262684151747684
#
# Epoch 41
#  Accuracy: 0.9
#  Loss:0.12522138216285042
#
# Epoch 42
#  Accuracy: 0.9
#  Loss:0.12424408974409036
#
# Epoch 43
#  Accuracy: 0.9
#  Loss:0.12333093595800558
#
# Epoch 44
#  Accuracy: 0.9
#  Loss:0.12247684558286838
#
# Epoch 45
#  Accuracy: 0.9
#  Loss:0.1216772134125604
#
# Epoch 46
#  Accuracy: 0.9
#  Loss:0.12092785415381956
#
# Epoch 47
#  Accuracy: 0.9
#  Loss:0.12022495818919564
#
# Epoch 48
#  Accuracy: 0.9
#  Loss:0.11956505251085917
#
# Epoch 49
#  Accuracy: 0.9
#  Loss:0.11894496619720242
#
# Epoch 50
#  Accuracy: 0.9
#  Loss:0.11836179987200575
#
# Epoch 51
#  Accuracy: 0.9
#  Loss:0.11781289865117353
#
# Epoch 52
#  Accuracy: 0.9
#  Loss:0.11729582814262685
#
# Epoch 53
#  Accuracy: 0.9
#  Loss:0.11680835311988194
#
# Epoch 54
#  Accuracy: 0.9
#  Loss:0.11634841853884723
#
# Epoch 55
#  Accuracy: 0.9
#  Loss:0.11591413261056462
#
# Epoch 56
#  Accuracy: 0.9
#  Loss:0.11550375168037151
#
# Epoch 57
#  Accuracy: 0.9
#  Loss:0.11511566669675671
#
# Epoch 58
#  Accuracy: 0.9
#  Loss:0.11474839108157116
#
# Epoch 59
#  Accuracy: 0.9
#  Loss:0.11440054983775616
#
# Epoch 60
#  Accuracy: 0.9
#  Loss:0.11407086975187887
#
# Epoch 61
#  Accuracy: 0.9
#  Loss:0.113758170566972
#
# Epoch 62
#  Accuracy: 0.9
#  Loss:0.11346135701686891
#
# Epoch 63
#  Accuracy: 0.9
#  Loss:0.11317941162676848
#
# Epoch 64
#  Accuracy: 0.9
#  Loss:0.11291138819646192
#
# Epoch 65
#  Accuracy: 0.9
#  Loss:0.11265640589277534
#
# Epoch 66
#  Accuracy: 0.9
#  Loss:0.1124136438865553
#
# Epoch 67
#  Accuracy: 0.9
#  Loss:0.11218233647714142
#
# Epoch 68
#  Accuracy: 0.9
#  Loss:0.11196176865390055
#
# Epoch 69
#  Accuracy: 0.9
#  Loss:0.11175127205017452
#
# Epoch 70
#  Accuracy: 0.9
#  Loss:0.11155022125004395
#
# Epoch 71
#  Accuracy: 0.9
#  Loss:0.11135803041273136
#
# Epoch 72
#  Accuracy: 0.9
#  Loss:0.11117415018334438
#
# Epoch 73
#  Accuracy: 0.9
#  Loss:0.11099806486206927
#
# Epoch 74
#  Accuracy: 0.9
#  Loss:0.11082928980692759
#
# Epoch 75
#  Accuracy: 0.9
#  Loss:0.11066736904785973
#
# Epoch 76
#  Accuracy: 0.9
#  Loss:0.11051187309224084
#
# Epoch 77
#  Accuracy: 0.9
#  Loss:0.11036239690401348
#
# Epoch 78
#  Accuracy: 0.9
#  Loss:0.11021855804046256
#
# Epoch 79
#  Accuracy: 0.9
#  Loss:0.1100799949322996
#
# Epoch 80
#  Accuracy: 0.9
#  Loss:0.1099463652941852
#
# Epoch 81
#  Accuracy: 0.9
#  Loss:0.10981734465412342
#
# Epoch 82
#  Accuracy: 0.9
#  Loss:0.10969262499133241
#
# Epoch 83
#  Accuracy: 0.9
#  Loss:0.10957191347324408
#
# Epoch 84
#  Accuracy: 0.9
#  Loss:0.10945493128322978
#
# Epoch 85
#  Accuracy: 0.9
#  Loss:0.1093414125314997
#
# Epoch 86
#  Accuracy: 0.9
#  Loss:0.10923110324239417
#
# Epoch 87
#  Accuracy: 0.9
#  Loss:0.10912376041198261
#
# Epoch 88
#  Accuracy: 0.9
#  Loss:0.10901915113052091
#
# Epoch 89
#  Accuracy: 0.9
#  Loss:0.10891705176489817
#
# Epoch 90
#  Accuracy: 0.9
#  Loss:0.10881724719673286
#
# Epoch 91
#  Accuracy: 0.9
#  Loss:0.10871953011226745
#
# Epoch 92
#  Accuracy: 0.9
#  Loss:0.108623700340658
#
# Epoch 93
#  Accuracy: 0.9
#  Loss:0.10852956423767139
#
# Epoch 94
#  Accuracy: 0.9
#  Loss:0.10843693411218673
#
# Epoch 95
#  Accuracy: 0.9
#  Loss:0.10834562769325676
#
# Epoch 96
#  Accuracy: 0.9
#  Loss:0.10825546763581527
#
# Epoch 97
#  Accuracy: 0.9
#  Loss:0.1081662810634312
#
# Epoch 98
#  Accuracy: 0.9
#  Loss:0.1080778991467951
#
# Epoch 99
#  Accuracy: 0.9
#  Loss:0.10799015671689711
#
# Epoch 100
#  Accuracy: 0.9
#  Loss:0.10790289191210325
#
# Epoch 101
#  Accuracy: 0.9
#  Loss:0.10781594585856898
#
# Epoch 102
#  Accuracy: 0.9
#  Loss:0.10772916238363996
#
# Epoch 103
#  Accuracy: 0.9
#  Loss:0.10764238776208168
#
# Epoch 104
#  Accuracy: 0.9
#  Loss:0.10755547049514769
#
# Epoch 105
#  Accuracy: 0.9
#  Loss:0.10746826112264407
#
# Epoch 106
#  Accuracy: 0.9
#  Loss:0.10738061206826814
#
# Epoch 107
#  Accuracy: 0.9
#  Loss:0.1072923775185928
#
# Epoch 108
#  Accuracy: 0.9
#  Loss:0.1072034133361317
#
# Epoch 109
#  Accuracy: 0.9
#  Loss:0.10711357700695073
#
# Epoch 110
#  Accuracy: 0.9
#  Loss:0.1070227276232851
#
# Epoch 111
#  Accuracy: 0.9
#  Loss:0.10693072590157675
#
# Epoch 112
#  Accuracy: 0.9
#  Loss:0.10683743423625963
#
# Epoch 113
#  Accuracy: 0.9
#  Loss:0.10674271678948787
#
# Epoch 114
#  Accuracy: 0.9
#  Loss:0.10664643961682309
#
# Epoch 115
#  Accuracy: 0.9
#  Loss:0.10654847082866846
#
# Epoch 116
#  Accuracy: 0.9
#  Loss:0.10644868078695874
#
# Epoch 117
#  Accuracy: 0.9
#  Loss:0.10634694233628737
#
# Epoch 118
#  Accuracy: 0.9
#  Loss:0.10624313106827488
#
# Epoch 119
#  Accuracy: 0.9
#  Loss:0.10613712561755977
#
# Epoch 120
#  Accuracy: 0.9
#  Loss:0.10602880798732972
#
# Epoch 121
#  Accuracy: 0.9
#  Loss:0.1059180639018104
#
# Epoch 122
#  Accuracy: 0.9
#  Loss:0.10580478318260411
#
# Epoch 123
#  Accuracy: 0.9
#  Loss:0.10568886014522674
#
# Epoch 124
#  Accuracy: 0.9
#  Loss:0.10557019401164389
#
# Epoch 125
#  Accuracy: 0.9
#  Loss:0.10544868933406983
#
# Epoch 126
#  Accuracy: 0.889
#  Loss:0.10532425642477992
#
# Epoch 127
#  Accuracy: 0.889
#  Loss:0.10519681178621726
#
# Epoch 128
#  Accuracy: 0.889
#  Loss:0.10506627853526626
#
# Epoch 129
#  Accuracy: 0.889
#  Loss:0.1049325868152351
#
# Epoch 130
#  Accuracy: 0.889
#  Loss:0.10479567418885764
#
# Epoch 131
#  Accuracy: 0.889
#  Loss:0.10465548600550703
#
# Epoch 132
#  Accuracy: 0.889
#  Loss:0.10451197573582575
#
# Epoch 133
#  Accuracy: 0.889
#  Loss:0.10436510526713032
#
# Epoch 134
#  Accuracy: 0.889
#  Loss:0.10421484515325487
#
# Epoch 135
#  Accuracy: 0.889
#  Loss:0.10406117481295808
#
# Epoch 136
#  Accuracy: 0.889
#  Loss:0.10390408267163416
#
# Epoch 137
#  Accuracy: 0.889
#  Loss:0.10374356624183427
#
# Epoch 138
#  Accuracy: 0.889
#  Loss:0.1035796321390085
#
# Epoch 139
#  Accuracy: 0.889
#  Loss:0.10341229602990266
#
# Epoch 140
#  Accuracy: 0.889
#  Loss:0.10324158251216768
#
# Epoch 141
#  Accuracy: 0.889
#  Loss:0.10306752492493455
#
# Epoch 142
#  Accuracy: 0.889
#  Loss:0.10289016509134138
#
# Epoch 143
#  Accuracy: 0.889
#  Loss:0.10270955299524206
#
# Epoch 144
#  Accuracy: 0.889
#  Loss:0.10252574639553862
#
# Epoch 145
#  Accuracy: 0.889
#  Loss:0.10233881038272707
#
# Epoch 146
#  Accuracy: 0.889
#  Loss:0.10214881688329913
#
# Epoch 147
#  Accuracy: 0.889
#  Loss:0.10195584411856326
#
# Epoch 148
#  Accuracy: 0.889
#  Loss:0.10175997602521471
#
# Epoch 149
#  Accuracy: 0.889
#  Loss:0.10156130164557509
#
# Epoch 150
#  Accuracy: 0.889
#  Loss:0.1013599144958198
#
# Epoch 151
#  Accuracy: 0.889
#  Loss:0.1011559119207088
#
# Epoch 152
#  Accuracy: 0.889
#  Loss:0.10094939444333638
#
# Epoch 153
#  Accuracy: 0.889
#  Loss:0.10074046511821642
#
# Epoch 154
#  Accuracy: 0.889
#  Loss:0.10052922889564145
#
# Epoch 155
#  Accuracy: 0.889
#  Loss:0.10031579200471111
#
# Epoch 156
#  Accuracy: 0.889
#  Loss:0.10010026136174091
#
# Epoch 157
#  Accuracy: 0.889
#  Loss:0.09988274400996425
#
# Epoch 158
#  Accuracy: 0.889
#  Loss:0.09966334659555759
#
# Epoch 159
#  Accuracy: 0.889
#  Loss:0.09944217488407785
#
# Epoch 160
#  Accuracy: 0.889
#  Loss:0.09921933332043681
#
# Epoch 161
#  Accuracy: 0.889
#  Loss:0.0989949246345737
#
# Epoch 162
#  Accuracy: 0.889
#  Loss:0.0987690494940509
#
# Epoch 163
#  Accuracy: 0.889
#  Loss:0.09854180620391419
#
# Epoch 164
#  Accuracy: 0.889
#  Loss:0.09831329045334176
#
# Epoch 165
#  Accuracy: 0.889
#  Loss:0.098083595107877
#
# Epoch 166
#  Accuracy: 0.889
#  Loss:0.09785281004540229
#
# Epoch 167
#  Accuracy: 0.889
#  Loss:0.09762102203347832
#
# Epoch 168
#  Accuracy: 0.889
#  Loss:0.0973883146452426
#
# Epoch 169
#  Accuracy: 0.889
#  Loss:0.09715476821073504
#
# Epoch 170
#  Accuracy: 0.889
#  Loss:0.09692045980029233
#
# Epoch 171
#  Accuracy: 0.889
#  Loss:0.0966854632365206
#
# Epoch 172
#  Accuracy: 0.889
#  Loss:0.09644984913130818
#
# Epoch 173
#  Accuracy: 0.889
#  Loss:0.09621368494436988
#
# Epoch 174
#  Accuracy: 0.889
#  Loss:0.09597703505990773
#
# Epoch 175
#  Accuracy: 0.889
#  Loss:0.09573996087812255
#
# Epoch 176
#  Accuracy: 0.889
#  Loss:0.095502520918502
#
# Epoch 177
#  Accuracy: 0.889
#  Loss:0.09526477093203774
#
# Epoch 178
#  Accuracy: 0.889
#  Loss:0.09502676401977123
#
# Epoch 179
#  Accuracy: 0.889
#  Loss:0.09478855075533275
#
# Epoch 180
#  Accuracy: 0.889
#  Loss:0.09455017930940568
#
# Epoch 181
#  Accuracy: 0.889
#  Loss:0.0943116955743185
#
# Epoch 182
#  Accuracy: 0.889
#  Loss:0.09407314328722857
#
# Epoch 183
#  Accuracy: 0.889
#  Loss:0.09383456415061263
#
# Epoch 184
#  Accuracy: 0.889
#  Loss:0.0935959979490166
#
# Epoch 185
#  Accuracy: 0.889
#  Loss:0.0933574826612355
#
# Epoch 186
#  Accuracy: 0.889
#  Loss:0.09311905456729372
#
# Epoch 187
#  Accuracy: 0.889
#  Loss:0.09288074834977669
#
# Epoch 188
#  Accuracy: 0.889
#  Loss:0.09264259718922203
#
# Epoch 189
#  Accuracy: 0.889
#  Loss:0.09240463285341757
#
# Epoch 190
#  Accuracy: 0.889
#  Loss:0.09216688578057156
#
# Epoch 191
#  Accuracy: 0.889
#  Loss:0.09192938515641984
#
# Epoch 192
#  Accuracy: 0.889
#  Loss:0.09169215898541562
#
# Epoch 193
#  Accuracy: 0.889
#  Loss:0.0914552341562149
#
# Epoch 194
#  Accuracy: 0.889
#  Loss:0.09121863650171842
#
# Epoch 195
#  Accuracy: 0.889
#  Loss:0.09098239085397096
#
# Epoch 196
#  Accuracy: 0.889
#  Loss:0.0907465210942433
#
# Epoch 197
#  Accuracy: 0.889
#  Loss:0.09051105019863845
#
# Epoch 198
#  Accuracy: 0.889
#  Loss:0.09027600027957085
#
# Epoch 199
#  Accuracy: 0.889
#  Loss:0.0900413926234678
#
# Epoch 200
#  Accuracy: 0.889
#  Loss:0.08980724772503558
#
# Epoch 201
#  Accuracy: 0.889
#  Loss:0.08957358531842334
#
# Epoch 202
#  Accuracy: 0.889
#  Loss:0.08934042440560279
#
# Epoch 203
#  Accuracy: 0.889
#  Loss:0.08910778328226485
#
# Epoch 204
#  Accuracy: 0.889
#  Loss:0.08887567956151579
#
# Epoch 205
#  Accuracy: 0.889
#  Loss:0.08864413019563473
#
# Epoch 206
#  Accuracy: 0.889
#  Loss:0.08841315149613384
#
# Epoch 207
#  Accuracy: 0.889
#  Loss:0.08818275915234108
#
# Epoch 208
#  Accuracy: 0.889
#  Loss:0.08795296824870515
#
# Epoch 209
#  Accuracy: 0.9
#  Loss:0.08772379328100129
#
# Epoch 210
#  Accuracy: 0.9
#  Loss:0.08749524817159737
#
# Epoch 211
#  Accuracy: 0.9
#  Loss:0.08726734628392185
#
# Epoch 212
#  Accuracy: 0.9
#  Loss:0.08704010043625622
#
# Epoch 213
#  Accuracy: 0.9
#  Loss:0.08681352291496042
#
# Epoch 214
#  Accuracy: 0.911
#  Loss:0.08658762548722297
#
# Epoch 215
#  Accuracy: 0.911
#  Loss:0.0863624194134153
#
# Epoch 216
#  Accuracy: 0.922
#  Loss:0.08613791545911648
#
# Epoch 217
#  Accuracy: 0.922
#  Loss:0.08591412390686406
#
# Epoch 218
#  Accuracy: 0.922
#  Loss:0.08569105456767649
#
# Epoch 219
#  Accuracy: 0.922
#  Loss:0.08546871679238396
#
# Epoch 220
#  Accuracy: 0.922
#  Loss:0.08524711948279659
#
# Epoch 221
#  Accuracy: 0.922
#  Loss:0.08502627110273268
#
# Epoch 222
#  Accuracy: 0.922
#  Loss:0.08480617968892322
#
# Epoch 223
#  Accuracy: 0.922
#  Loss:0.08458685286180465
#
# Epoch 224
#  Accuracy: 0.922
#  Loss:0.08436829783620703
#
# Epoch 225
#  Accuracy: 0.922
#  Loss:0.08415052143194192
#
# Epoch 226
#  Accuracy: 0.922
#  Loss:0.08393353008429101
#
# Epoch 227
#  Accuracy: 0.922
#  Loss:0.08371732985439422
#
# Epoch 228
#  Accuracy: 0.922
#  Loss:0.0835019264395342
#
# Epoch 229
#  Accuracy: 0.922
#  Loss:0.08328732518331351
#
# Epoch 230
#  Accuracy: 0.922
#  Loss:0.08307353108571805
#
# Epoch 231
#  Accuracy: 0.922
#  Loss:0.08286054881306129
#
# Epoch 232
#  Accuracy: 0.922
#  Loss:0.0826483827078029
#
# Epoch 233
#  Accuracy: 0.922
#  Loss:0.08243703679823434
#
# Epoch 234
#  Accuracy: 0.922
#  Loss:0.08222651480802524
#
# Epoch 235
#  Accuracy: 0.922
#  Loss:0.08201682016562377
#
# Epoch 236
#  Accuracy: 0.922
#  Loss:0.08180795601350452
#
# Epoch 237
#  Accuracy: 0.922
#  Loss:0.08159992521725803
#
# Epoch 238
#  Accuracy: 0.922
#  Loss:0.08139273037451665
#
# Epoch 239
#  Accuracy: 0.922
#  Loss:0.08118637382371101
#
# Epoch 240
#  Accuracy: 0.922
#  Loss:0.0809808576526535
#
# Epoch 241
#  Accuracy: 0.922
#  Loss:0.08077618370694431
#
# Epoch 242
#  Accuracy: 0.922
#  Loss:0.08057235359819677
#
# Epoch 243
#  Accuracy: 0.922
#  Loss:0.0803693687120792
#
# Epoch 244
#  Accuracy: 0.922
#  Loss:0.08016723021617149
#
# Epoch 245
#  Accuracy: 0.922
#  Loss:0.07996593906763418
#
# Epoch 246
#  Accuracy: 0.922
#  Loss:0.0797654960206896
#
# Epoch 247
#  Accuracy: 0.922
#  Loss:0.07956590163391392
#
# Epoch 248
#  Accuracy: 0.922
#  Loss:0.07936715627734069
#
# Epoch 249
#  Accuracy: 0.922
#  Loss:0.0791692601393758
#
# Epoch 250
#  Accuracy: 0.922
#  Loss:0.07897221323352474
#
# Epoch 251
#  Accuracy: 0.922
#  Loss:0.07877601540493397
#
# Epoch 252
#  Accuracy: 0.922
#  Loss:0.07858066633674708
#
# Epoch 253
#  Accuracy: 0.922
#  Loss:0.07838616555627846
#
# Epoch 254
#  Accuracy: 0.922
#  Loss:0.07819251244100642
#
# Epoch 255
#  Accuracy: 0.922
#  Loss:0.07799970622438826
#
# Epoch 256
#  Accuracy: 0.922
#  Loss:0.07780774600150006
#
# Epoch 257
#  Accuracy: 0.922
#  Loss:0.07761663073450427
#
# Epoch 258
#  Accuracy: 0.922
#  Loss:0.07742635925794808
#
# Epoch 259
#  Accuracy: 0.922
#  Loss:0.07723693028389607
#
# Epoch 260
#  Accuracy: 0.922
#  Loss:0.07704834240690037
#
# Epoch 261
#  Accuracy: 0.922
#  Loss:0.07686059410881192
#
# Epoch 262
#  Accuracy: 0.922
#  Loss:0.07667368376343699
#
# Epoch 263
#  Accuracy: 0.922
#  Loss:0.07648760964104143
#
# Epoch 264
#  Accuracy: 0.922
#  Loss:0.07630236991270789
#
# Epoch 265
#  Accuracy: 0.922
#  Loss:0.07611796265454882
#
# Epoch 266
#  Accuracy: 0.922
#  Loss:0.07593438585177915
#
# Epoch 267
#  Accuracy: 0.922
#  Loss:0.07575163740265302
#
# Epoch 268
#  Accuracy: 0.922
#  Loss:0.07556971512226755
#
# Epoch 269
#  Accuracy: 0.922
#  Loss:0.07538861674623829
#
# Epoch 270
#  Accuracy: 0.922
#  Loss:0.07520833993424915
#
# Epoch 271
#  Accuracy: 0.933
#  Loss:0.07502888227348152
#
# Epoch 272
#  Accuracy: 0.933
#  Loss:0.07485024128192536
#
# Epoch 273
#  Accuracy: 0.933
#  Loss:0.07467241441157639
#
# Epoch 274
#  Accuracy: 0.933
#  Loss:0.07449539905152278
#
# Epoch 275
#  Accuracy: 0.944
#  Loss:0.07431919253092469
#
# Epoch 276
#  Accuracy: 0.944
#  Loss:0.07414379212189028
#
# Epoch 277
#  Accuracy: 0.944
#  Loss:0.07396919504225138
#
# Epoch 278
#  Accuracy: 0.944
#  Loss:0.07379539845824203
#
# Epoch 279
#  Accuracy: 0.944
#  Loss:0.07362239948708324
#
# Epoch 280
#  Accuracy: 0.944
#  Loss:0.07345019519947676
#
# Epoch 281
#  Accuracy: 0.944
#  Loss:0.07327878262201142
#
# Epoch 282
#  Accuracy: 0.944
#  Loss:0.07310815873948405
#
# Epoch 283
#  Accuracy: 0.944
#  Loss:0.072938320497139
#
# Epoch 284
#  Accuracy: 0.944
#  Loss:0.07276926480282783
#
# Epoch 285
#  Accuracy: 0.944
#  Loss:0.07260098852909279
#
# Epoch 286
#  Accuracy: 0.944
#  Loss:0.07243348851517602
#
# Epoch 287
#  Accuracy: 0.944
#  Loss:0.07226676156895753
#
# Epoch 288
#  Accuracy: 0.944
#  Loss:0.07210080446882373
#
# Epoch 289
#  Accuracy: 0.944
#  Loss:0.07193561396546962
#
# Epoch 290
#  Accuracy: 0.944
#  Loss:0.07177118678363628
#
# Epoch 291
#  Accuracy: 0.944
#  Loss:0.07160751962378617
#
# Epoch 292
#  Accuracy: 0.944
#  Loss:0.0714446091637183
#
# Epoch 293
#  Accuracy: 0.944
#  Loss:0.07128245206012518
#
# Epoch 294
#  Accuracy: 0.944
#  Loss:0.07112104495009393
#
# Epoch 295
#  Accuracy: 0.944
#  Loss:0.07096038445255282
#
# Epoch 296
#  Accuracy: 0.944
#  Loss:0.07080046716966572
#
# Epoch 297
#  Accuracy: 0.944
#  Loss:0.07064128968817569
#
# Epoch 298
#  Accuracy: 0.944
#  Loss:0.07048284858069999
#
# Epoch 299
#  Accuracy: 0.944
#  Loss:0.07032514040697749
#
# Epoch 300
#  Accuracy: 0.944
#  Loss:0.07016816171507075
#
# Epoch 301
#  Accuracy: 0.944
#  Loss:0.07001190904252379
#
# Epoch 302
#  Accuracy: 0.944
#  Loss:0.0698563789174772
#
# Epoch 303
#  Accuracy: 0.944
#  Loss:0.06970156785974232
#
# Epoch 304
#  Accuracy: 0.944
#  Loss:0.06954747238183513
#
# Epoch 305
#  Accuracy: 0.944
#  Loss:0.06939408898997211
#
# Epoch 306
#  Accuracy: 0.944
#  Loss:0.0692414141850286
#
# Epoch 307
#  Accuracy: 0.956
#  Loss:0.06908944446346119
#
# Epoch 308
#  Accuracy: 0.956
#  Loss:0.0689381763181954
#
# Epoch 309
#  Accuracy: 0.956
#  Loss:0.06878760623947976
#
# Epoch 310
#  Accuracy: 0.956
#  Loss:0.06863773071570714
#
# Epoch 311
#  Accuracy: 0.956
#  Loss:0.06848854623420492
#
# Epoch 312
#  Accuracy: 0.956
#  Loss:0.06834004928199455
#
# Epoch 313
#  Accuracy: 0.956
#  Loss:0.06819223634652163
#
# Epoch 314
#  Accuracy: 0.956
#  Loss:0.06804510391635783
#
# Epoch 315
#  Accuracy: 0.956
#  Loss:0.0678986484818749
#
# Epoch 316
#  Accuracy: 0.956
#  Loss:0.06775286653589245
#
# Epoch 317
#  Accuracy: 0.956
#  Loss:0.06760775457429967
#
# Epoch 318
#  Accuracy: 0.956
#  Loss:0.06746330909665238
#
# Epoch 319
#  Accuracy: 0.956
#  Loss:0.0673195266067459
#
# Epoch 320
#  Accuracy: 0.956
#  Loss:0.06717640361316463
#
# Epoch 321
#  Accuracy: 0.956
#  Loss:0.06703393662980905
#
# Epoch 322
#  Accuracy: 0.956
#  Loss:0.0668921221764012
#
# Epoch 323
#  Accuracy: 0.956
#  Loss:0.06675095677896878
#
# Epoch 324
#  Accuracy: 0.956
#  Loss:0.06661043697030898
#
# Epoch 325
#  Accuracy: 0.956
#  Loss:0.06647055929043275
#
# Epoch 326
#  Accuracy: 0.956
#  Loss:0.06633132028698992
#
# Epoch 327
#  Accuracy: 0.956
#  Loss:0.06619271651567582
#
# Epoch 328
#  Accuracy: 0.956
#  Loss:0.06605474454062031
#
# Epoch 329
#  Accuracy: 0.956
#  Loss:0.06591740093475945
#
# Epoch 330
#  Accuracy: 0.956
#  Loss:0.06578068228019056
#
# Epoch 331
#  Accuracy: 0.956
#  Loss:0.06564458516851138
#
# Epoch 332
#  Accuracy: 0.956
#  Loss:0.06550910620114342
#
# Epoch 333
#  Accuracy: 0.956
#  Loss:0.06537424198964058
#
# Epoch 334
#  Accuracy: 0.956
#  Loss:0.06523998915598307
#
# Epoch 335
#  Accuracy: 0.956
#  Loss:0.06510634433285763
#
# Epoch 336
#  Accuracy: 0.956
#  Loss:0.06497330416392372
#
# Epoch 337
#  Accuracy: 0.956
#  Loss:0.06484086530406737
#
# Epoch 338
#  Accuracy: 0.956
#  Loss:0.06470902441964185
#
# Epoch 339
#  Accuracy: 0.956
#  Loss:0.06457777818869632
#
# Epoch 340
#  Accuracy: 0.956
#  Loss:0.06444712330119307
#
# Epoch 341
#  Accuracy: 0.956
#  Loss:0.06431705645921297
#
# Epoch 342
#  Accuracy: 0.956
#  Loss:0.06418757437715039
#
# Epoch 343
#  Accuracy: 0.956
#  Loss:0.06405867378189735
#
# Epoch 344
#  Accuracy: 0.956
#  Loss:0.0639303514130177
#
# Epoch 345
#  Accuracy: 0.956
#  Loss:0.06380260402291135
#
# Epoch 346
#  Accuracy: 0.956
#  Loss:0.06367542837696923
#
# Epoch 347
#  Accuracy: 0.956
#  Loss:0.06354882125371904
#
# Epoch 348
#  Accuracy: 0.956
#  Loss:0.06342277944496236
#
# Epoch 349
#  Accuracy: 0.956
#  Loss:0.06329729975590327
#
# Epoch 350
#  Accuracy: 0.956
#  Loss:0.06317237900526881
#
# Epoch 351
#  Accuracy: 0.956
#  Loss:0.06304801402542183
#
# Epoch 352
#  Accuracy: 0.956
#  Loss:0.06292420166246608
#
# Epoch 353
#  Accuracy: 0.956
#  Loss:0.06280093877634425
#
# Epoch 354
#  Accuracy: 0.967
#  Loss:0.06267822224092896
#
# Epoch 355
#  Accuracy: 0.967
#  Loss:0.06255604894410714
#
# Epoch 356
#  Accuracy: 0.967
#  Loss:0.062434415787858064
#
# Epoch 357
#  Accuracy: 0.967
#  Loss:0.062313319688324834
#
# Epoch 358
#  Accuracy: 0.967
#  Loss:0.06219275757588054
#
# Epoch 359
#  Accuracy: 0.967
#  Loss:0.062072726395188134
#
# Epoch 360
#  Accuracy: 0.967
#  Loss:0.06195322310525531
#
# Epoch 361
#  Accuracy: 0.967
#  Loss:0.06183424467948376
#
# Epoch 362
#  Accuracy: 0.967
#  Loss:0.06171578810571374
#
# Epoch 363
#  Accuracy: 0.967
#  Loss:0.06159785038626349
#
# Epoch 364
#  Accuracy: 0.967
#  Loss:0.06148042853796428
#
# Epoch 365
#  Accuracy: 0.967
#  Loss:0.0613635195921909
#
# Epoch 366
#  Accuracy: 0.967
#  Loss:0.06124712059488787
#
# Epoch 367
#  Accuracy: 0.967
#  Loss:0.06113122860659169
#
# Epoch 368
#  Accuracy: 0.967
#  Loss:0.06101584070244906
#
# Epoch 369
#  Accuracy: 0.967
#  Loss:0.06090095397223152
#
# Epoch 370
#  Accuracy: 0.967
#  Loss:0.06078656552034638
#
# Epoch 371
#  Accuracy: 0.967
#  Loss:0.06067267246584421
#
# Epoch 372
#  Accuracy: 0.967
#  Loss:0.060559271942423325
#
# Epoch 373
#  Accuracy: 0.967
#  Loss:0.060446361098430816
#
# Epoch 374
#  Accuracy: 0.967
#  Loss:0.060333937096860704
#
# Epoch 375
#  Accuracy: 0.967
#  Loss:0.060221997115349445
#
# Epoch 376
#  Accuracy: 0.967
#  Loss:0.060110538346168356
#
# Epoch 377
#  Accuracy: 0.967
#  Loss:0.05999955799621375
#
# Epoch 378
#  Accuracy: 0.967
#  Loss:0.05988905328699445
#
# Epoch 379
#  Accuracy: 0.967
#  Loss:0.05977902145461692
#
# Epoch 380
#  Accuracy: 0.967
#  Loss:0.059669459749768186
#
# Epoch 381
#  Accuracy: 0.967
#  Loss:0.05956036543769662
#
# Epoch 382
#  Accuracy: 0.967
#  Loss:0.05945173579819066
#
# Epoch 383
#  Accuracy: 0.967
#  Loss:0.05934356812555554
#
# Epoch 384
#  Accuracy: 0.967
#  Loss:0.05923585972858823
#
# Epoch 385
#  Accuracy: 0.967
#  Loss:0.0591286079305505
#
# Epoch 386
#  Accuracy: 0.967
#  Loss:0.059021810069140535
#
# Epoch 387
#  Accuracy: 0.967
#  Loss:0.05891546349646262
#
# Epoch 388
#  Accuracy: 0.967
#  Loss:0.05880956557899558
#
# Epoch 389
#  Accuracy: 0.967
#  Loss:0.058704113697559714
#
# Epoch 390
#  Accuracy: 0.967
#  Loss:0.05859910524728225
#
# Epoch 391
#  Accuracy: 0.967
#  Loss:0.05849453763756167
#
# Epoch 392
#  Accuracy: 0.967
#  Loss:0.058390408292030564
#
# Epoch 393
#  Accuracy: 0.967
#  Loss:0.0582867146485177
#
# Epoch 394
#  Accuracy: 0.967
#  Loss:0.05818345415900858
#
# Epoch 395
#  Accuracy: 0.967
#  Loss:0.05808062428960518
#
# Epoch 396
#  Accuracy: 0.967
#  Loss:0.05797822252048466
#
# Epoch 397
#  Accuracy: 0.967
#  Loss:0.0578762463458571
#
# Epoch 398
#  Accuracy: 0.967
#  Loss:0.05777469327392248
#
# Epoch 399
#  Accuracy: 0.967
#  Loss:0.05767356082682659
#
# Epoch 400
#  Accuracy: 0.967
#  Loss:0.057572846540616354
#
# Epoch 401
#  Accuracy: 0.967
#  Loss:0.05747254796519439
#
# Epoch 402
#  Accuracy: 0.967
#  Loss:0.05737266266427269
#
# Epoch 403
#  Accuracy: 0.967
#  Loss:0.05727318821532594
#
# Epoch 404
#  Accuracy: 0.967
#  Loss:0.05717412220954396
#
# Epoch 405
#  Accuracy: 0.967
#  Loss:0.057075462251783685
#
# Epoch 406
#  Accuracy: 0.967
#  Loss:0.05697720596052057
#
# Epoch 407
#  Accuracy: 0.967
#  Loss:0.05687935096779949
#
# Epoch 408
#  Accuracy: 0.978
#  Loss:0.056781894919185144
#
# Epoch 409
#  Accuracy: 0.978
#  Loss:0.05668483547371213
#
# Epoch 410
#  Accuracy: 0.978
#  Loss:0.05658817030383428
#
# Epoch 411
#  Accuracy: 0.978
#  Loss:0.05649189709537406
#
# Epoch 412
#  Accuracy: 0.978
#  Loss:0.056396013547471174
#
# Epoch 413
#  Accuracy: 0.978
#  Loss:0.05630051737253119
#
# Epoch 414
#  Accuracy: 0.978
#  Loss:0.05620540629617348
#
# Epoch 415
#  Accuracy: 0.978
#  Loss:0.056110678057179286
#
# Epoch 416
#  Accuracy: 0.978
#  Loss:0.05601633040743916
#
# Epoch 417
#  Accuracy: 0.978
#  Loss:0.05592236111190038
#
# Epoch 418
#  Accuracy: 0.978
#  Loss:0.055828767948513935
#
# Epoch 419
#  Accuracy: 0.978
#  Loss:0.05573554870818159
#
# Epoch 420
#  Accuracy: 0.978
#  Loss:0.055642701194702514
#
# Epoch 421
#  Accuracy: 0.978
#  Loss:0.05555022322471967
#
# Epoch 422
#  Accuracy: 0.978
#  Loss:0.055458112627666485
#
# Epoch 423
#  Accuracy: 0.978
#  Loss:0.055366367245712825
#
# Epoch 424
#  Accuracy: 0.978
#  Loss:0.05527498493371114
#
# Epoch 425
#  Accuracy: 0.978
#  Loss:0.05518396355914263
#
# Epoch 426
#  Accuracy: 0.978
#  Loss:0.05509330100206286
#
# Epoch 427
#  Accuracy: 0.978
#  Loss:0.05500299515504781
#
# Epoch 428
#  Accuracy: 0.978
#  Loss:0.054913043923139344
#
# Epoch 429
#  Accuracy: 0.978
#  Loss:0.05482344522379119
#
# Epoch 430
#  Accuracy: 0.978
#  Loss:0.05473419698681416
#
# Epoch 431
#  Accuracy: 0.978
#  Loss:0.05464529715432204
#
# Epoch 432
#  Accuracy: 0.978
#  Loss:0.05455674368067693
#
# Epoch 433
#  Accuracy: 0.978
#  Loss:0.05446853453243475
#
# Epoch 434
#  Accuracy: 0.978
#  Loss:0.05438066768829079
#
# Epoch 435
#  Accuracy: 0.978
#  Loss:0.05429314113902518
#
# Epoch 436
#  Accuracy: 0.978
#  Loss:0.05420595288744826
#
# Epoch 437
#  Accuracy: 0.978
#  Loss:0.05411910094834616
#
# Epoch 438
#  Accuracy: 0.978
#  Loss:0.054032583348426214
#
# Epoch 439
#  Accuracy: 0.978
#  Loss:0.05394639812626255
#
# Epoch 440
#  Accuracy: 0.978
#  Loss:0.053860543332241564
#
# Epoch 441
#  Accuracy: 0.978
#  Loss:0.053775017028507476
#
# Epoch 442
#  Accuracy: 0.978
#  Loss:0.053689817288908
#
# Epoch 443
#  Accuracy: 0.978
#  Loss:0.05360494219893991
#
# Epoch 444
#  Accuracy: 0.978
#  Loss:0.05352038985569481
#
# Epoch 445
#  Accuracy: 0.978
#  Loss:0.053436158367804784
#
# Epoch 446
#  Accuracy: 0.978
#  Loss:0.05335224585538834
#
# Epoch 447
#  Accuracy: 0.989
#  Loss:0.05326865044999618
#
# Epoch 448
#  Accuracy: 0.989
#  Loss:0.05318537029455707
#
# Epoch 449
#  Accuracy: 0.989
#  Loss:0.05310240354332393
#
# Epoch 450
#  Accuracy: 0.989
#  Loss:0.05301974836181995
#
# Epoch 451
#  Accuracy: 0.989
#  Loss:0.05293740292678462
#
# Epoch 452
#  Accuracy: 0.989
#  Loss:0.05285536542611998
#
# Epoch 453
#  Accuracy: 0.989
#  Loss:0.052773634058836984
#
# Epoch 454
#  Accuracy: 0.989
#  Loss:0.05269220703500187
#
# Epoch 455
#  Accuracy: 0.989
#  Loss:0.05261108257568257
#
# Epoch 456
#  Accuracy: 0.989
#  Loss:0.052530258912895325
#
# Epoch 457
#  Accuracy: 0.989
#  Loss:0.05244973428955143
#
# Epoch 458
#  Accuracy: 0.989
#  Loss:0.05236950695940384
#
# Epoch 459
#  Accuracy: 0.989
#  Loss:0.052289575186994085
#
# Epoch 460
#  Accuracy: 0.989
#  Loss:0.05220993724759923
#
# Epoch 461
#  Accuracy: 0.989
#  Loss:0.052130591427178984
#
# Epoch 462
#  Accuracy: 0.989
#  Loss:0.052051536022322625
#
# Epoch 463
#  Accuracy: 0.989
#  Loss:0.05197276934019663
#
# Epoch 464
#  Accuracy: 0.989
#  Loss:0.05189428969849161
#
# Epoch 465
#  Accuracy: 0.989
#  Loss:0.05181609542537011
#
# Epoch 466
#  Accuracy: 0.989
#  Loss:0.05173818485941403
#
# Epoch 467
#  Accuracy: 0.989
#  Loss:0.051660556349572374
#
# Epoch 468
#  Accuracy: 0.989
#  Loss:0.051583208255109016
#
# Epoch 469
#  Accuracy: 0.989
#  Loss:0.05150613894555055
#
# Epoch 470
#  Accuracy: 0.989
#  Loss:0.051429346800634476
#
# Epoch 471
#  Accuracy: 0.989
#  Loss:0.05135283021025716
#
# Epoch 472
#  Accuracy: 0.989
#  Loss:0.051276587574422265
#
# Epoch 473
#  Accuracy: 0.989
#  Loss:0.051200617303188915
#
# Epoch 474
#  Accuracy: 0.989
#  Loss:0.0511249178166204
#
# Epoch 475
#  Accuracy: 0.989
#  Loss:0.051049487544732625
#
# Epoch 476
#  Accuracy: 0.989
#  Loss:0.05097432492744293
#
# Epoch 477
#  Accuracy: 0.989
#  Loss:0.0508994284145189
#
# Epoch 478
#  Accuracy: 0.989
#  Loss:0.050824796465527296
#
# Epoch 479
#  Accuracy: 0.989
#  Loss:0.05075042754978328
#
# Epoch 480
#  Accuracy: 0.989
#  Loss:0.05067632014629942
#
# Epoch 481
#  Accuracy: 0.989
#  Loss:0.050602472743735284
#
# Epoch 482
#  Accuracy: 0.989
#  Loss:0.05052888384034666
#
# Epoch 483
#  Accuracy: 0.989
#  Loss:0.0504555519439353
#
# Epoch 484
#  Accuracy: 0.989
#  Loss:0.05038247557179857
#
# Epoch 485
#  Accuracy: 0.989
#  Loss:0.050309653250679286
#
# Epoch 486
#  Accuracy: 0.989
#  Loss:0.05023708351671574
#
# Epoch 487
#  Accuracy: 0.989
#  Loss:0.050164764915391694
#
# Epoch 488
#  Accuracy: 0.989
#  Loss:0.050092696001486706
#
# Epoch 489
#  Accuracy: 0.989
#  Loss:0.05002087533902639
#
# Epoch 490
#  Accuracy: 0.989
#  Loss:0.04994930150123297
#
# Epoch 491
#  Accuracy: 0.989
#  Loss:0.04987797307047579
#
# Epoch 492
#  Accuracy: 0.989
#  Loss:0.04980688863822219
#
# Epoch 493
#  Accuracy: 0.989
#  Loss:0.04973604680498825
#
# Epoch 494
#  Accuracy: 0.989
#  Loss:0.04966544618028986
#
# Epoch 495
#  Accuracy: 0.989
#  Loss:0.049595085382593815
#
# Epoch 496
#  Accuracy: 0.989
#  Loss:0.0495249630392691
#
# Epoch 497
#  Accuracy: 0.989
#  Loss:0.04945507778653831
#
# Epoch 498
#  Accuracy: 0.989
#  Loss:0.04938542826942914
#
# Epoch 499
#  Accuracy: 0.989
#  Loss:0.04931601314172602
#
# Epoch 500
#  Accuracy: 0.989
#  Loss:0.04924683106592201
#
# Epoch 501
#  Accuracy: 0.989
#  Loss:0.04917788071317066
#
# Epoch 502
#  Accuracy: 0.989
#  Loss:0.04910916076323809
#
# Epoch 503
#  Accuracy: 0.989
#  Loss:0.04904066990445521
#
# Epoch 504
#  Accuracy: 0.989
#  Loss:0.04897240683367004
#
# Epoch 505
#  Accuracy: 0.989
#  Loss:0.04890437025620018
#
# Epoch 506
#  Accuracy: 0.989
#  Loss:0.0488365588857855
#
# Epoch 507
#  Accuracy: 0.989
#  Loss:0.048768971444540773
#
# Epoch 508
#  Accuracy: 0.989
#  Loss:0.04870160666290866
#
# Epoch 509
#  Accuracy: 0.989
#  Loss:0.048634463279612676
#
# Epoch 510
#  Accuracy: 0.989
#  Loss:0.048567540041610374
#
# Epoch 511
#  Accuracy: 0.989
#  Loss:0.04850083570404671
#
# Epoch 512
#  Accuracy: 0.989
#  Loss:0.04843434903020738
#
# Epoch 513
#  Accuracy: 0.989
#  Loss:0.048368078791472514
#
# Epoch 514
#  Accuracy: 0.989
#  Loss:0.048302023767270344
#
# Epoch 515
#  Accuracy: 0.989
#  Loss:0.048236182745031046
#
# Epoch 516
#  Accuracy: 0.989
#  Loss:0.04817055452014088
#
# Epoch 517
#  Accuracy: 0.989
#  Loss:0.048105137895896176
#
# Epoch 518
#  Accuracy: 0.989
#  Loss:0.04803993168345777
#
# Epoch 519
#  Accuracy: 0.989
#  Loss:0.04797493470180536
#
# Epoch 520
#  Accuracy: 0.989
#  Loss:0.04791014577769211
#
# Epoch 521
#  Accuracy: 0.989
#  Loss:0.047845563745599465
#
# Epoch 522
#  Accuracy: 0.989
#  Loss:0.04778118744769179
#
# Epoch 523
#  Accuracy: 0.989
#  Loss:0.04771701573377175
#
# Epoch 524
#  Accuracy: 0.989
#  Loss:0.04765304746123514
#
# Epoch 525
#  Accuracy: 0.989
#  Loss:0.04758928149502639
#
# Epoch 526
#  Accuracy: 0.989
#  Loss:0.04752571670759397
#
# Epoch 527
#  Accuracy: 0.989
#  Loss:0.04746235197884597
#
# Epoch 528
#  Accuracy: 0.989
#  Loss:0.0473991861961059
#
# Epoch 529
#  Accuracy: 0.989
#  Loss:0.0473362182540686
#
# Epoch 530
#  Accuracy: 0.989
#  Loss:0.04727344705475625
#
# Epoch 531
#  Accuracy: 0.989
#  Loss:0.04721087150747457
#
# Epoch 532
#  Accuracy: 0.989
#  Loss:0.04714849052876927
#
# Epoch 533
#  Accuracy: 0.989
#  Loss:0.047086303042382455
#
# Epoch 534
#  Accuracy: 0.989
#  Loss:0.04702430797920927
#
# Epoch 535
#  Accuracy: 0.989
#  Loss:0.046962504277254784
#
# Epoch 536
#  Accuracy: 0.989
#  Loss:0.0469008908815909
#
# Epoch 537
#  Accuracy: 0.989
#  Loss:0.0468394667443135
#
# Epoch 538
#  Accuracy: 0.989
#  Loss:0.04677823082449966
#
# Epoch 539
#  Accuracy: 0.989
#  Loss:0.04671718208816512
#
# Epoch 540
#  Accuracy: 0.989
#  Loss:0.046656319508221855
#
# Epoch 541
#  Accuracy: 0.989
#  Loss:0.046595642064435706
#
# Epoch 542
#  Accuracy: 0.989
#  Loss:0.04653514874338443
#
# Epoch 543
#  Accuracy: 0.989
#  Loss:0.046474838538415615
#
# Epoch 544
#  Accuracy: 0.989
#  Loss:0.04641471044960493
#
# Epoch 545
#  Accuracy: 0.989
#  Loss:0.046354763483714416
#
# Epoch 546
#  Accuracy: 0.989
#  Loss:0.0462949966541511
#
# Epoch 547
#  Accuracy: 0.989
#  Loss:0.04623540898092556
#
# Epoch 548
#  Accuracy: 0.989
#  Loss:0.046175999490610804
#
# Epoch 549
#  Accuracy: 0.989
#  Loss:0.04611676721630125
#
# Epoch 550
#  Accuracy: 0.989
#  Loss:0.046057711197571904
#
# Epoch 551
#  Accuracy: 0.989
#  Loss:0.04599883048043751
#
# Epoch 552
#  Accuracy: 0.989
#  Loss:0.04594012411731225
#
# Epoch 553
#  Accuracy: 0.989
#  Loss:0.045881591166969195
#
# Epoch 554
#  Accuracy: 0.989
#  Loss:0.045823230694500124
#
# Epoch 555
#  Accuracy: 0.989
#  Loss:0.04576504177127551
#
# Epoch 556
#  Accuracy: 0.989
#  Loss:0.0457070234749046
#
# Epoch 557
#  Accuracy: 0.989
#  Loss:0.04564917488919574
#
# Epoch 558
#  Accuracy: 0.989
#  Loss:0.04559149510411669
#
# Epoch 559
#  Accuracy: 0.989
#  Loss:0.045533983215755344
#
# Epoch 560
#  Accuracy: 0.989
#  Loss:0.04547663832628041
#
# Epoch 561
#  Accuracy: 0.989
#  Loss:0.04541945954390244
#
# Epoch 562
#  Accuracy: 0.989
#  Loss:0.04536244598283476
#
# Epoch 563
#  Accuracy: 0.989
#  Loss:0.045305596763254886
#
# Epoch 564
#  Accuracy: 0.989
#  Loss:0.04524891101126581
#
# Epoch 565
#  Accuracy: 0.989
#  Loss:0.045192387858857735
#
# Epoch 566
#  Accuracy: 0.989
#  Loss:0.04513602644386965
#
# Epoch 567
#  Accuracy: 0.989
#  Loss:0.04507982590995143
#
# Epoch 568
#  Accuracy: 0.989
#  Loss:0.04502378540652577
#
# Epoch 569
#  Accuracy: 0.989
#  Loss:0.044967904088750565
#
# Epoch 570
#  Accuracy: 0.989
#  Loss:0.044912181117481215
#
# Epoch 571
#  Accuracy: 0.989
#  Loss:0.044856615659233316
#
# Epoch 572
#  Accuracy: 0.989
#  Loss:0.044801206886145355
#
# Epoch 573
#  Accuracy: 0.989
#  Loss:0.04474595397594164
#
# Epoch 574
#  Accuracy: 0.989
#  Loss:0.04469085611189545
#
# Epoch 575
#  Accuracy: 0.989
#  Loss:0.04463591248279224
#
# Epoch 576
#  Accuracy: 0.989
#  Loss:0.044581122282893085
#
# Epoch 577
#  Accuracy: 0.989
#  Loss:0.044526484711898316
#
# Epoch 578
#  Accuracy: 0.989
#  Loss:0.04447199897491125
#
# Epoch 579
#  Accuracy: 0.989
#  Loss:0.044417664282402215
#
# Epoch 580
#  Accuracy: 0.989
#  Loss:0.04436347985017253
#
# Epoch 581
#  Accuracy: 0.989
#  Loss:0.04430944489931895
#
# Epoch 582
#  Accuracy: 0.989
#  Loss:0.04425555865619802
#
# Epoch 583
#  Accuracy: 0.989
#  Loss:0.04420182035239072
#
# Epoch 584
#  Accuracy: 0.989
#  Loss:0.0441482292246673
#
# Epoch 585
#  Accuracy: 0.989
#  Loss:0.04409478451495222
#
# Epoch 586
#  Accuracy: 0.989
#  Loss:0.044041485470289334
#
# Epoch 587
#  Accuracy: 0.989
#  Loss:0.043988331342807115
#
# Epoch 588
#  Accuracy: 0.989
#  Loss:0.04393532138968433
#
# Epoch 589
#  Accuracy: 0.989
#  Loss:0.043882454873115505
#
# Epoch 590
#  Accuracy: 0.989
#  Loss:0.043829731060276836
#
# Epoch 591
#  Accuracy: 0.989
#  Loss:0.043777149223292254
#
# Epoch 592
#  Accuracy: 0.989
#  Loss:0.04372470863919957
#
# Epoch 593
#  Accuracy: 0.989
#  Loss:0.04367240858991675
#
# Epoch 594
#  Accuracy: 0.989
#  Loss:0.0436202483622086
#
# Epoch 595
#  Accuracy: 0.989
#  Loss:0.0435682272476533
#
# Epoch 596
#  Accuracy: 0.989
#  Loss:0.043516344542609484
#
# Epoch 597
#  Accuracy: 0.989
#  Loss:0.043464599548183026
#
# Epoch 598
#  Accuracy: 1.0
#  Loss:0.043412991570194515
#
# Epoch 599
#  Accuracy: 1.0
#  Loss:0.043361519919146524
#
# Epoch 600
#  Accuracy: 1.0
#  Loss:0.04331018391019118
#
# Epoch 601
#  Accuracy: 1.0
#  Loss:0.04325898286309802
#
# Epoch 602
#  Accuracy: 1.0
#  Loss:0.043207916102221716
#
# Epoch 603
#  Accuracy: 1.0
#  Loss:0.043156982956470365
#
# Epoch 604
#  Accuracy: 1.0
#  Loss:0.04310618275927362
#
# Epoch 605
#  Accuracy: 1.0
#  Loss:0.04305551484855126
#
# Epoch 606
#  Accuracy: 1.0
#  Loss:0.04300497856668164
#
# Epoch 607
#  Accuracy: 1.0
#  Loss:0.042954573260470634
#
# Epoch 608
#  Accuracy: 1.0
#  Loss:0.04290429828112055
#
# Epoch 609
#  Accuracy: 1.0
#  Loss:0.042854152984199236
#
# Epoch 610
#  Accuracy: 1.0
#  Loss:0.04280413672960943
#
# Epoch 611
#  Accuracy: 1.0
#  Loss:0.04275424888155824
#
# Epoch 612
#  Accuracy: 1.0
#  Loss:0.04270448880852674
#
# Epoch 613
#  Accuracy: 1.0
#  Loss:0.04265485588323995
#
# Epoch 614
#  Accuracy: 1.0
#  Loss:0.0426053494826367
#
# Epoch 615
#  Accuracy: 1.0
#  Loss:0.042555968987839886
#
# Epoch 616
#  Accuracy: 1.0
#  Loss:0.04250671378412684
#
# Epoch 617
#  Accuracy: 1.0
#  Loss:0.042457583260899746
#
# Epoch 618
#  Accuracy: 1.0
#  Loss:0.042408576811656495
#
# Epoch 619
#  Accuracy: 1.0
#  Loss:0.04235969383396143
#
# Epoch 620
#  Accuracy: 1.0
#  Loss:0.042310933729416494
#
# Epoch 621
#  Accuracy: 1.0
#  Loss:0.042262295903632376
#
# Epoch 622
#  Accuracy: 1.0
#  Loss:0.04221377976619991
#
# Epoch 623
#  Accuracy: 1.0
#  Loss:0.04216538473066173
#
# Epoch 624
#  Accuracy: 1.0
#  Loss:0.04211711021448387
#
# Epoch 625
#  Accuracy: 1.0
#  Loss:0.042068955639027766
#
# Epoch 626
#  Accuracy: 1.0
#  Loss:0.04202092042952228
#
# Epoch 627
#  Accuracy: 1.0
#  Loss:0.041973004015036036
#
# Epoch 628
#  Accuracy: 1.0
#  Loss:0.04192520582844974
#
# Epoch 629
#  Accuracy: 1.0
#  Loss:0.041877525306428846
#
# Epoch 630
#  Accuracy: 1.0
#  Loss:0.04182996188939628
#
# Epoch 631
#  Accuracy: 1.0
#  Loss:0.0417825150215054
#
# Epoch 632
#  Accuracy: 1.0
#  Loss:0.041735184150613065
#
# Epoch 633
#  Accuracy: 1.0
#  Loss:0.041687968728253005
#
# Epoch 634
#  Accuracy: 1.0
#  Loss:0.04164086820960906
#
# Epoch 635
#  Accuracy: 1.0
#  Loss:0.04159388205348909
#
# Epoch 636
#  Accuracy: 1.0
#  Loss:0.04154700972229848
#
# Epoch 637
#  Accuracy: 1.0
#  Loss:0.04150025068201423
#
# Epoch 638
#  Accuracy: 1.0
#  Loss:0.0414536044021591
#
# Epoch 639
#  Accuracy: 1.0
#  Loss:0.04140707035577576
#
# Epoch 640
#  Accuracy: 1.0
#  Loss:0.0413606480194014
#
# Epoch 641
#  Accuracy: 1.0
#  Loss:0.04131433687304225
#
# Epoch 642
#  Accuracy: 1.0
#  Loss:0.04126813640014836
#
# Epoch 643
#  Accuracy: 1.0
#  Loss:0.041222046087588685
#
# Epoch 644
#  Accuracy: 1.0
#  Loss:0.04117606542562601
#
# Epoch 645
#  Accuracy: 1.0
#  Loss:0.041130193907892396
#
# Epoch 646
#  Accuracy: 1.0
#  Loss:0.04108443103136456
#
# Epoch 647
#  Accuracy: 1.0
#  Loss:0.04103877629633949
#
# Epoch 648
#  Accuracy: 1.0
#  Loss:0.04099322920641023
#
# Epoch 649
#  Accuracy: 1.0
#  Loss:0.04094778926844184
#
# Epoch 650
#  Accuracy: 1.0
#  Loss:0.04090245599254752
#
# Epoch 651
#  Accuracy: 1.0
#  Loss:0.04085722889206478
#
# Epoch 652
#  Accuracy: 1.0
#  Loss:0.04081210748353196
#
# Epoch 653
#  Accuracy: 1.0
#  Loss:0.040767091286664815
#
# Epoch 654
#  Accuracy: 1.0
#  Loss:0.0407221798243333
#
# Epoch 655
#  Accuracy: 1.0
#  Loss:0.04067737262253838
#
# Epoch 656
#  Accuracy: 1.0
#  Loss:0.04063266921038921
#
# Epoch 657
#  Accuracy: 1.0
#  Loss:0.04058806912008027
#
# Epoch 658
#  Accuracy: 1.0
#  Loss:0.040543571886868926
#
# Epoch 659
#  Accuracy: 1.0
#  Loss:0.040499177049052794
#
# Epoch 660
#  Accuracy: 1.0
#  Loss:0.04045488414794754
#
# Epoch 661
#  Accuracy: 1.0
#  Loss:0.04041069272786483
#
# Epoch 662
#  Accuracy: 1.0
#  Loss:0.04036660233609016
#
# Epoch 663
#  Accuracy: 1.0
#  Loss:0.04032261252286125
#
# Epoch 664
#  Accuracy: 1.0
#  Loss:0.040278722841346266
#
# Epoch 665
#  Accuracy: 1.0
#  Loss:0.040234932847622314
#
# Epoch 666
#  Accuracy: 1.0
#  Loss:0.04019124210065416
#
# Epoch 667
#  Accuracy: 1.0
#  Loss:0.04014765016227299
#
# Epoch 668
#  Accuracy: 1.0
#  Loss:0.040104156597155306
#
# Epoch 669
#  Accuracy: 1.0
#  Loss:0.04006076097280223
#
# Epoch 670
#  Accuracy: 1.0
#  Loss:0.040017462859518536
#
# Epoch 671
#  Accuracy: 1.0
#  Loss:0.03997426183039224
#
# Epoch 672
#  Accuracy: 1.0
#  Loss:0.039931157461274076
#
# Epoch 673
#  Accuracy: 1.0
#  Loss:0.03988814933075727
#
# Epoch 674
#  Accuracy: 1.0
#  Loss:0.03984523702015737
#
# Epoch 675
#  Accuracy: 1.0
#  Loss:0.03980242011349226
#
# Epoch 676
#  Accuracy: 1.0
#  Loss:0.03975969819746243
#
# Epoch 677
#  Accuracy: 1.0
#  Loss:0.03971707086143112
#
# Epoch 678
#  Accuracy: 1.0
#  Loss:0.03967453769740493
#
# Epoch 679
#  Accuracy: 1.0
#  Loss:0.039632098300014344
#
# Epoch 680
#  Accuracy: 1.0
#  Loss:0.039589752266494554
#
# Epoch 681
#  Accuracy: 1.0
#  Loss:0.0395474991966663
#
# Epoch 682
#  Accuracy: 1.0
#  Loss:0.039505338692916996
#
# Epoch 683
#  Accuracy: 1.0
#  Loss:0.039463270360181796
#
# Epoch 684
#  Accuracy: 1.0
#  Loss:0.039421293805925094
#
# Epoch 685
#  Accuracy: 1.0
#  Loss:0.03937940864012186
#
# Epoch 686
#  Accuracy: 1.0
#  Loss:0.039337614475239334
#
# Epoch 687
#  Accuracy: 1.0
#  Loss:0.03929591092621882
#
# Epoch 688
#  Accuracy: 1.0
#  Loss:0.03925429761045743
#
# Epoch 689
#  Accuracy: 1.0
#  Loss:0.03921277414779034
#
# Epoch 690
#  Accuracy: 1.0
#  Loss:0.03917134016047286
#
# Epoch 691
#  Accuracy: 1.0
#  Loss:0.039129995273162736
#
# Epoch 692
#  Accuracy: 1.0
#  Loss:0.03908873911290267
#
# Epoch 693
#  Accuracy: 1.0
#  Loss:0.039047571309102865
#
# Epoch 694
#  Accuracy: 1.0
#  Loss:0.039006491493523816
#
# Epoch 695
#  Accuracy: 1.0
#  Loss:0.03896549930025913
#
# Epoch 696
#  Accuracy: 1.0
#  Loss:0.03892459436571855
#
# Epoch 697
#  Accuracy: 1.0
#  Loss:0.03888377632861109
#
# Epoch 698
#  Accuracy: 1.0
#  Loss:0.03884304482992832
#
# Epoch 699
#  Accuracy: 1.0
#  Loss:0.03880239951292776
#
# Epoch 700
#  Accuracy: 1.0
#  Loss:0.038761840023116424
#
# Epoch 701
#  Accuracy: 1.0
#  Loss:0.038721366008234455
#
# Epoch 702
#  Accuracy: 1.0
#  Loss:0.038680977118239014
#
# Epoch 703
#  Accuracy: 1.0
#  Loss:0.03864067300528808
#
# Epoch 704
#  Accuracy: 1.0
#  Loss:0.03860045332372465
#
# Epoch 705
#  Accuracy: 1.0
#  Loss:0.038560317730060814
#
# Epoch 706
#  Accuracy: 1.0
#  Loss:0.038520265882962104
#
# Epoch 707
#  Accuracy: 1.0
#  Loss:0.038480297443231976
#
# Epoch 708
#  Accuracy: 1.0
#  Loss:0.03844041207379633
#
# Epoch 709
#  Accuracy: 1.0
#  Loss:0.038400609439688184
#
# Epoch 710
#  Accuracy: 1.0
#  Loss:0.0383608892080326
#
# Epoch 711
#  Accuracy: 1.0
#  Loss:0.0383212510480315
#
# Epoch 712
#  Accuracy: 1.0
#  Loss:0.038281694630948764
#
# Epoch 713
#  Accuracy: 1.0
#  Loss:0.03824221963009549
#
# Epoch 714
#  Accuracy: 1.0
#  Loss:0.03820282572081521
#
# Epoch 715
#  Accuracy: 1.0
#  Loss:0.03816351258046934
#
# Epoch 716
#  Accuracy: 1.0
#  Loss:0.03812427988842281
#
# Epoch 717
#  Accuracy: 1.0
#  Loss:0.03808512732602956
#
# Epoch 718
#  Accuracy: 1.0
#  Loss:0.03804605457661852
#
# Epoch 719
#  Accuracy: 1.0
#  Loss:0.03800706132547936
#
# Epoch 720
#  Accuracy: 1.0
#  Loss:0.03796814725984862
#
# Epoch 721
#  Accuracy: 1.0
#  Loss:0.03792931206889578
#
# Epoch 722
#  Accuracy: 1.0
#  Loss:0.037890555443709485
#
# Epoch 723
#  Accuracy: 1.0
#  Loss:0.03785187707728404
#
# Epoch 724
#  Accuracy: 1.0
#  Loss:0.03781327666450569
#
# Epoch 725
#  Accuracy: 1.0
#  Loss:0.037774753902139434
#
# Epoch 726
#  Accuracy: 1.0
#  Loss:0.037736308488815526
#
# Epoch 727
#  Accuracy: 1.0
#  Loss:0.037697940125016406
#
# Epoch 728
#  Accuracy: 1.0
#  Loss:0.037659648513063644
#
# Epoch 729
#  Accuracy: 1.0
#  Loss:0.03762143335710485
#
# Epoch 730
#  Accuracy: 1.0
#  Loss:0.0375832943631009
#
# Epoch 731
#  Accuracy: 1.0
#  Loss:0.037545231238813245
#
# Epoch 732
#  Accuracy: 1.0
#  Loss:0.03750724369379113
#
# Epoch 733
#  Accuracy: 1.0
#  Loss:0.03746933143935917
#
# Epoch 734
#  Accuracy: 1.0
#  Loss:0.03743149418860482
#
# Epoch 735
#  Accuracy: 1.0
#  Loss:0.037393731656366155
#
# Epoch 736
#  Accuracy: 1.0
#  Loss:0.03735604355921957
#
# Epoch 737
#  Accuracy: 1.0
#  Loss:0.03731842961546767
#
# Epoch 738
#  Accuracy: 1.0
#  Loss:0.037280889545127316
#
# Epoch 739
#  Accuracy: 1.0
#  Loss:0.03724342306991759
#
# Epoch 740
#  Accuracy: 1.0
#  Loss:0.037206029913248125
#
# Epoch 741
#  Accuracy: 1.0
#  Loss:0.03716870980020724
#
# Epoch 742
#  Accuracy: 1.0
#  Loss:0.03713146245755039
#
# Epoch 743
#  Accuracy: 1.0
#  Loss:0.03709428761368873
#
# Epoch 744
#  Accuracy: 1.0
#  Loss:0.03705718499867748
#
# Epoch 745
#  Accuracy: 1.0
#  Loss:0.03702015434420487
#
# Epoch 746
#  Accuracy: 1.0
#  Loss:0.036983195383580664
#
# Epoch 747
#  Accuracy: 1.0
#  Loss:0.03694630785172516
#
# Epoch 748
#  Accuracy: 1.0
#  Loss:0.036909491485158166
#
# Epoch 749
#  Accuracy: 1.0
#  Loss:0.03687274602198789
#
# Epoch 750
#  Accuracy: 1.0
#  Loss:0.03683607120190033
#
# Epoch 751
#  Accuracy: 1.0
#  Loss:0.03679946676614829
#
# Epoch 752
#  Accuracy: 1.0
#  Loss:0.03676293245754083
#
# Epoch 753
#  Accuracy: 1.0
#  Loss:0.03672646802043261
#
# Epoch 754
#  Accuracy: 1.0
#  Loss:0.036690073200713484
#
# Epoch 755
#  Accuracy: 1.0
#  Loss:0.03665374774579798
#
# Epoch 756
#  Accuracy: 1.0
#  Loss:0.03661749140461509
#
# Epoch 757
#  Accuracy: 1.0
#  Loss:0.036581303927598
#
# Epoch 758
#  Accuracy: 1.0
#  Loss:0.03654518506667391
#
# Epoch 759
#  Accuracy: 1.0
#  Loss:0.036509134575253954
#
# Epoch 760
#  Accuracy: 1.0
#  Loss:0.03647315220822336
#
# Epoch 761
#  Accuracy: 1.0
#  Loss:0.036437237721931415
#
# Epoch 762
#  Accuracy: 1.0
#  Loss:0.036401390874181754
#
# Epoch 763
#  Accuracy: 1.0
#  Loss:0.03636561142422251
#
# Epoch 764
#  Accuracy: 1.0
#  Loss:0.03632989913273682
#
# Epoch 765
#  Accuracy: 1.0
#  Loss:0.03629425376183312
#
# Epoch 766
#  Accuracy: 1.0
#  Loss:0.036258675075035794
#
# Epoch 767
#  Accuracy: 1.0
#  Loss:0.03622316283727561
#
# Epoch 768
#  Accuracy: 1.0
#  Loss:0.03618771681488055
#
# Epoch 769
#  Accuracy: 1.0
#  Loss:0.036152336775566465
#
# Epoch 770
#  Accuracy: 1.0
#  Loss:0.036117022488427866
#
# Epoch 771
#  Accuracy: 1.0
#  Loss:0.03608177372392895
#
# Epoch 772
#  Accuracy: 1.0
#  Loss:0.03604659025389448
#
# Epoch 773
#  Accuracy: 1.0
#  Loss:0.03601147185150082
#
# Epoch 774
#  Accuracy: 1.0
#  Loss:0.03597641829126712
#
# Epoch 775
#  Accuracy: 1.0
#  Loss:0.035941429349046525
#
# Epoch 776
#  Accuracy: 1.0
#  Loss:0.03590650480201734
#
# Epoch 777
#  Accuracy: 1.0
#  Loss:0.03587164442867451
#
# Epoch 778
#  Accuracy: 1.0
#  Loss:0.03583684800882086
#
# Epoch 779
#  Accuracy: 1.0
#  Loss:0.03580211532355871
#
# Epoch 780
#  Accuracy: 1.0
#  Loss:0.03576744615528144
#
# Epoch 781
#  Accuracy: 1.0
#  Loss:0.035732840287664956
#
# Epoch 782
#  Accuracy: 1.0
#  Loss:0.03569829750565948
#
# Epoch 783
#  Accuracy: 1.0
#  Loss:0.03566381759548135
#
# Epoch 784
#  Accuracy: 1.0
#  Loss:0.035629400344604704
#
# Epoch 785
#  Accuracy: 1.0
#  Loss:0.03559504554175344
#
# Epoch 786
#  Accuracy: 1.0
#  Loss:0.03556075297689317
#
# Epoch 787
#  Accuracy: 1.0
#  Loss:0.03552652244122321
#
# Epoch 788
#  Accuracy: 1.0
#  Loss:0.03549235372716858
#
# Epoch 789
#  Accuracy: 1.0
#  Loss:0.03545824662837235
#
# Epoch 790
#  Accuracy: 1.0
#  Loss:0.035424200939687574
#
# Epoch 791
#  Accuracy: 1.0
#  Loss:0.03539021645716972
#
# Epoch 792
#  Accuracy: 1.0
#  Loss:0.03535629297806895
#
# Epoch 793
#  Accuracy: 1.0
#  Loss:0.035322430300822466
#
# Epoch 794
#  Accuracy: 1.0
#  Loss:0.03528862822504697
#
# Epoch 795
#  Accuracy: 1.0
#  Loss:0.03525488655153116
#
# Epoch 796
#  Accuracy: 1.0
#  Loss:0.035221205082228264
#
# Epoch 797
#  Accuracy: 1.0
#  Loss:0.035187583620248694
#
# Epoch 798
#  Accuracy: 1.0
#  Loss:0.03515402196985262
#
# Epoch 799
#  Accuracy: 1.0
#  Loss:0.03512051993644283
#
# Epoch 800
#  Accuracy: 1.0
#  Loss:0.03508707732655731
#
# Epoch 801
#  Accuracy: 1.0
#  Loss:0.035053693947862306
#
# Epoch 802
#  Accuracy: 1.0
#  Loss:0.03502036960914496
#
# Epoch 803
#  Accuracy: 1.0
#  Loss:0.03498710412030645
#
# Epoch 804
#  Accuracy: 1.0
#  Loss:0.03495389729235487
#
# Epoch 805
#  Accuracy: 1.0
#  Loss:0.034920748937398285
#
# Epoch 806
#  Accuracy: 1.0
#  Loss:0.03488765886863782
#
# Epoch 807
#  Accuracy: 1.0
#  Loss:0.034854626900360834
#
# Epoch 808
#  Accuracy: 1.0
#  Loss:0.03482165284793404
#
# Epoch 809
#  Accuracy: 1.0
#  Loss:0.03478873652779678
#
# Epoch 810
#  Accuracy: 1.0
#  Loss:0.03475587775745433
#
# Epoch 811
#  Accuracy: 1.0
#  Loss:0.03472307635547124
#
# Epoch 812
#  Accuracy: 1.0
#  Loss:0.03469033214146459
#
# Epoch 813
#  Accuracy: 1.0
#  Loss:0.034657644936097604
#
# Epoch 814
#  Accuracy: 1.0
#  Loss:0.03462501456107296
#
# Epoch 815
#  Accuracy: 1.0
#  Loss:0.034592440839126444
#
# Epoch 816
#  Accuracy: 1.0
#  Loss:0.034559923594020374
#
# Epoch 817
#  Accuracy: 1.0
#  Loss:0.0345274626505373
#
# Epoch 818
#  Accuracy: 1.0
#  Loss:0.03449505783447364
#
# Epoch 819
#  Accuracy: 1.0
#  Loss:0.03446270897263332
#
# Epoch 820
#  Accuracy: 1.0
#  Loss:0.03443041589282155
#
# Epoch 821
#  Accuracy: 1.0
#  Loss:0.03439817842383862
#
# Epoch 822
#  Accuracy: 1.0
#  Loss:0.03436599639547366
#
# Epoch 823
#  Accuracy: 1.0
#  Loss:0.034333869638498535
#
# Epoch 824
#  Accuracy: 1.0
#  Loss:0.034301797984661736
#
# Epoch 825
#  Accuracy: 1.0
#  Loss:0.03426978126668228
#
# Epoch 826
#  Accuracy: 1.0
#  Loss:0.03423781931824371
#
# Epoch 827
#  Accuracy: 1.0
#  Loss:0.03420591197398821
#
# Epoch 828
#  Accuracy: 1.0
#  Loss:0.03417405906951042
#
# Epoch 829
#  Accuracy: 1.0
#  Loss:0.03414226044135176
#
# Epoch 830
#  Accuracy: 1.0
#  Loss:0.0341105159269944
#
# Epoch 831
#  Accuracy: 1.0
#  Loss:0.03407882536485551
#
# Epoch 832
#  Accuracy: 1.0
#  Loss:0.034047188594281394
#
# Epoch 833
#  Accuracy: 1.0
#  Loss:0.03401560545554181
#
# Epoch 834
#  Accuracy: 1.0
#  Loss:0.03398407578982412
#
# Epoch 835
#  Accuracy: 1.0
#  Loss:0.03395259943922767
#
# Epoch 836
#  Accuracy: 1.0
#  Loss:0.03392117624675807
#
# Epoch 837
#  Accuracy: 1.0
#  Loss:0.03388980605632171
#
# Epoch 838
#  Accuracy: 1.0
#  Loss:0.0338584887127199
#
# Epoch 839
#  Accuracy: 1.0
#  Loss:0.03382722406164358
#
# Epoch 840
#  Accuracy: 1.0
#  Loss:0.033796011949667575
#
# Epoch 841
#  Accuracy: 1.0
#  Loss:0.033764852224245204
#
# Epoch 842
#  Accuracy: 1.0
#  Loss:0.033733744733702754
#
# Epoch 843
#  Accuracy: 1.0
#  Loss:0.033702689327234116
#
# Epoch 844
#  Accuracy: 1.0
#  Loss:0.033671685854895245
#
# Epoch 845
#  Accuracy: 1.0
#  Loss:0.033640734167598926
#
# Epoch 846
#  Accuracy: 1.0
#  Loss:0.033609834117109286
#
# Epoch 847
#  Accuracy: 1.0
#  Loss:0.033578985556036604
#
# Epoch 848
#  Accuracy: 1.0
#  Loss:0.03354818833783187
#
# Epoch 849
#  Accuracy: 1.0
#  Loss:0.033517442316781644
#
# Epoch 850
#  Accuracy: 1.0
#  Loss:0.03348674734800276
#
# Epoch 851
#  Accuracy: 1.0
#  Loss:0.03345610328743712
#
# Epoch 852
#  Accuracy: 1.0
#  Loss:0.03342550999184647
#
# Epoch 853
#  Accuracy: 1.0
#  Loss:0.03339496731880736
#
# Epoch 854
#  Accuracy: 1.0
#  Loss:0.03336447512670589
#
# Epoch 855
#  Accuracy: 1.0
#  Loss:0.03333403327473267
#
# Epoch 856
#  Accuracy: 1.0
#  Loss:0.033303641622877675
#
# Epoch 857
#  Accuracy: 1.0
#  Loss:0.0332733000319253
#
# Epoch 858
#  Accuracy: 1.0
#  Loss:0.0332430083634492
#
# Epoch 859
#  Accuracy: 1.0
#  Loss:0.033212766479807414
#
# Epoch 860
#  Accuracy: 1.0
#  Loss:0.03318257424413727
#
# Epoch 861
#  Accuracy: 1.0
#  Loss:0.03315243152035051
#
# Epoch 862
#  Accuracy: 1.0
#  Loss:0.03312233817312829
#
# Epoch 863
#  Accuracy: 1.0
#  Loss:0.033092294067916354
#
# Epoch 864
#  Accuracy: 1.0
#  Loss:0.03306229907092004
#
# Epoch 865
#  Accuracy: 1.0
#  Loss:0.03303235304909949
#
# Epoch 866
#  Accuracy: 1.0
#  Loss:0.03300245587016476
#
# Epoch 867
#  Accuracy: 1.0
#  Loss:0.03297260740257112
#
# Epoch 868
#  Accuracy: 1.0
#  Loss:0.032942807515514066
#
# Epoch 869
#  Accuracy: 1.0
#  Loss:0.03291305607892467
#
# Epoch 870
#  Accuracy: 1.0
#  Loss:0.03288335296346479
#
# Epoch 871
#  Accuracy: 1.0
#  Loss:0.03285369804052238
#
# Epoch 872
#  Accuracy: 1.0
#  Loss:0.032824091182206694
#
# Epoch 873
#  Accuracy: 1.0
#  Loss:0.032794532261343615
#
# Epoch 874
#  Accuracy: 1.0
#  Loss:0.032765021151471056
#
# Epoch 875
#  Accuracy: 1.0
#  Loss:0.03273555772683424
#
# Epoch 876
#  Accuracy: 1.0
#  Loss:0.03270614186238108
#
# Epoch 877
#  Accuracy: 1.0
#  Loss:0.03267677343375751
#
# Epoch 878
#  Accuracy: 1.0
#  Loss:0.03264745231730303
#
# Epoch 879
#  Accuracy: 1.0
#  Loss:0.032618178390046035
#
# Epoch 880
#  Accuracy: 1.0
#  Loss:0.032588951529699234
#
# Epoch 881
#  Accuracy: 1.0
#  Loss:0.032559771614655224
#
# Epoch 882
#  Accuracy: 1.0
#  Loss:0.03253063852398183
#
# Epoch 883
#  Accuracy: 1.0
#  Loss:0.03250155213741772
#
# Epoch 884
#  Accuracy: 1.0
#  Loss:0.03247251233536789
#
# Epoch 885
#  Accuracy: 1.0
#  Loss:0.03244351899889918
#
# Epoch 886
#  Accuracy: 1.0
#  Loss:0.03241457200973586
#
# Epoch 887
#  Accuracy: 1.0
#  Loss:0.03238567125025518
#
# Epoch 888
#  Accuracy: 1.0
#  Loss:0.032356816603482996
#
# Epoch 889
#  Accuracy: 1.0
#  Loss:0.032328007953089315
#
# Epoch 890
#  Accuracy: 1.0
#  Loss:0.032299245183383986
#
# Epoch 891
#  Accuracy: 1.0
#  Loss:0.03227052817931233
#
# Epoch 892
#  Accuracy: 1.0
#  Loss:0.03224185682645077
#
# Epoch 893
#  Accuracy: 1.0
#  Loss:0.032213231011002555
#
# Epoch 894
#  Accuracy: 1.0
#  Loss:0.03218465061979337
#
# Epoch 895
#  Accuracy: 1.0
#  Loss:0.03215611554026718
#
# Epoch 896
#  Accuracy: 1.0
#  Loss:0.03212762566048188
#
# Epoch 897
#  Accuracy: 1.0
#  Loss:0.03209918086910497
#
# Epoch 898
#  Accuracy: 1.0
#  Loss:0.03207078105540949
#
# Epoch 899
#  Accuracy: 1.0
#  Loss:0.03204242610926963
#
# Epoch 900
#  Accuracy: 1.0
#  Loss:0.03201411592115665
#
# Epoch 901
#  Accuracy: 1.0
#  Loss:0.03198585038213461
#
# Epoch 902
#  Accuracy: 1.0
#  Loss:0.0319576293838562
#
# Epoch 903
#  Accuracy: 1.0
#  Loss:0.03192945281855867
#
# Epoch 904
#  Accuracy: 1.0
#  Loss:0.03190132057905958
#
# Epoch 905
#  Accuracy: 1.0
#  Loss:0.03187323255875276
#
# Epoch 906
#  Accuracy: 1.0
#  Loss:0.031845188651604135
#
# Epoch 907
#  Accuracy: 1.0
#  Loss:0.03181718875214768
#
# Epoch 908
#  Accuracy: 1.0
#  Loss:0.03178923275548131
#
# Epoch 909
#  Accuracy: 1.0
#  Loss:0.03176132055726285
#
# Epoch 910
#  Accuracy: 1.0
#  Loss:0.03173345205370601
#
# Epoch 911
#  Accuracy: 1.0
#  Loss:0.03170562714157622
#
# Epoch 912
#  Accuracy: 1.0
#  Loss:0.03167784571818683
#
# Epoch 913
#  Accuracy: 1.0
#  Loss:0.03165010768139494
#
# Epoch 914
#  Accuracy: 1.0
#  Loss:0.031622412929597485
#
# Epoch 915
#  Accuracy: 1.0
#  Loss:0.03159476136172731
#
# Epoch 916
#  Accuracy: 1.0
#  Loss:0.031567152877249094
#
# Epoch 917
#  Accuracy: 1.0
#  Loss:0.03153958737615552
#
# Epoch 918
#  Accuracy: 1.0
#  Loss:0.031512064758963364
#
# Epoch 919
#  Accuracy: 1.0
#  Loss:0.03148458492670952
#
# Epoch 920
#  Accuracy: 1.0
#  Loss:0.03145714778094715
#
# Epoch 921
#  Accuracy: 1.0
#  Loss:0.031429753223741835
#
# Epoch 922
#  Accuracy: 1.0
#  Loss:0.03140240115766766
#
# Epoch 923
#  Accuracy: 1.0
#  Loss:0.03137509148580343
#
# Epoch 924
#  Accuracy: 1.0
#  Loss:0.031347824111728796
#
# Epoch 925
#  Accuracy: 1.0
#  Loss:0.031320598939520466
#
# Epoch 926
#  Accuracy: 1.0
#  Loss:0.03129341587374844
#
# Epoch 927
#  Accuracy: 1.0
#  Loss:0.031266274819472195
#
# Epoch 928
#  Accuracy: 1.0
#  Loss:0.031239175682236924
#
# Epoch 929
#  Accuracy: 1.0
#  Loss:0.031212118368069794
#
# Epoch 930
#  Accuracy: 1.0
#  Loss:0.03118510278347623
#
# Epoch 931
#  Accuracy: 1.0
#  Loss:0.031158128835436196
#
# Epoch 932
#  Accuracy: 1.0
#  Loss:0.031131196431400443
#
# Epoch 933
#  Accuracy: 1.0
#  Loss:0.031104305479286942
#
# Epoch 934
#  Accuracy: 1.0
#  Loss:0.03107745588747708
#
# Epoch 935
#  Accuracy: 1.0
#  Loss:0.031050647564812097
#
# Epoch 936
#  Accuracy: 1.0
#  Loss:0.031023880420589418
#
# Epoch 937
#  Accuracy: 1.0
#  Loss:0.030997154364559097
#
# Epoch 938
#  Accuracy: 1.0
#  Loss:0.030970469306920052
#
# Epoch 939
#  Accuracy: 1.0
#  Loss:0.030943825158316694
#
# Epoch 940
#  Accuracy: 1.0
#  Loss:0.03091722182983516
#
# Epoch 941
#  Accuracy: 1.0
#  Loss:0.0308906592329999
#
# Epoch 942
#  Accuracy: 1.0
#  Loss:0.030864137279770068
#
# Epoch 943
#  Accuracy: 1.0
#  Loss:0.03083765588253603
#
# Epoch 944
#  Accuracy: 1.0
#  Loss:0.030811214954115772
#
# Epoch 945
#  Accuracy: 1.0
#  Loss:0.030784814407751594
#
# Epoch 946
#  Accuracy: 1.0
#  Loss:0.03075845415710646
#
# Epoch 947
#  Accuracy: 1.0
#  Loss:0.030732134116260607
#
# Epoch 948
#  Accuracy: 1.0
#  Loss:0.030705854199708144
#
# Epoch 949
#  Accuracy: 1.0
#  Loss:0.03067961432235353
#
# Epoch 950
#  Accuracy: 1.0
#  Loss:0.030653414399508302
#
# Epoch 951
#  Accuracy: 1.0
#  Loss:0.03062725434688757
#
# Epoch 952
#  Accuracy: 1.0
#  Loss:0.030601134080606752
#
# Epoch 953
#  Accuracy: 1.0
#  Loss:0.030575053517178038
#
# Epoch 954
#  Accuracy: 1.0
#  Loss:0.030549012573507273
#
# Epoch 955
#  Accuracy: 1.0
#  Loss:0.030523011166890532
#
# Epoch 956
#  Accuracy: 1.0
#  Loss:0.030497049215010764
#
# Epoch 957
#  Accuracy: 1.0
#  Loss:0.03047112663593459
#
# Epoch 958
#  Accuracy: 1.0
#  Loss:0.030445243348109004
#
# Epoch 959
#  Accuracy: 1.0
#  Loss:0.030419399270358156
#
# Epoch 960
#  Accuracy: 1.0
#  Loss:0.030393594321880022
#
# Epoch 961
#  Accuracy: 1.0
#  Loss:0.030367828422243268
#
# Epoch 962
#  Accuracy: 1.0
#  Loss:0.03034210149138404
#
# Epoch 963
#  Accuracy: 1.0
#  Loss:0.03031641344960281
#
# Epoch 964
#  Accuracy: 1.0
#  Loss:0.03029076421756108
#
# Epoch 965
#  Accuracy: 1.0
#  Loss:0.030265153716278453
#
# Epoch 966
#  Accuracy: 1.0
#  Loss:0.030239581867129276
#
# Epoch 967
#  Accuracy: 1.0
#  Loss:0.03021404859183972
#
# Epoch 968
#  Accuracy: 1.0
#  Loss:0.030188553812484538
#
# Epoch 969
#  Accuracy: 1.0
#  Loss:0.030163097451484086
#
# Epoch 970
#  Accuracy: 1.0
#  Loss:0.030137679431601273
#
# Epoch 971
#  Accuracy: 1.0
#  Loss:0.03011229967593841
#
# Epoch 972
#  Accuracy: 1.0
#  Loss:0.030086958107934346
#
# Epoch 973
#  Accuracy: 1.0
#  Loss:0.03006165465136132
#
# Epoch 974
#  Accuracy: 1.0
#  Loss:0.0300363892303221
#
# Epoch 975
#  Accuracy: 1.0
#  Loss:0.030011161769246928
#
# Epoch 976
#  Accuracy: 1.0
#  Loss:0.02998597219289062
#
# Epoch 977
#  Accuracy: 1.0
#  Loss:0.02996082042632962
#
# Epoch 978
#  Accuracy: 1.0
#  Loss:0.0299357063949591
#
# Epoch 979
#  Accuracy: 1.0
#  Loss:0.029910630024490088
#
# Epoch 980
#  Accuracy: 1.0
#  Loss:0.029885591240946502
#
# Epoch 981
#  Accuracy: 1.0
#  Loss:0.029860589970662474
#
# Epoch 982
#  Accuracy: 1.0
#  Loss:0.029835626140279292
#
# Epoch 983
#  Accuracy: 1.0
#  Loss:0.029810699676742776
#
# Epoch 984
#  Accuracy: 1.0
#  Loss:0.029785810507300385
#
# Epoch 985
#  Accuracy: 1.0
#  Loss:0.029760958559498465
#
# Epoch 986
#  Accuracy: 1.0
#  Loss:0.02973614376117945
#
# Epoch 987
#  Accuracy: 1.0
#  Loss:0.029711366040479185
#
# Epoch 988
#  Accuracy: 1.0
#  Loss:0.029686625325824136
#
# Epoch 989
#  Accuracy: 1.0
#  Loss:0.02966192154592879
#
# Epoch 990
#  Accuracy: 1.0
#  Loss:0.02963725462979285
#
# Epoch 991
#  Accuracy: 1.0
#  Loss:0.029612624506698628
#
# Epoch 992
#  Accuracy: 1.0
#  Loss:0.02958803110620841
#
# Epoch 993
#  Accuracy: 1.0
#  Loss:0.029563474358161805
#
# Epoch 994
#  Accuracy: 1.0
#  Loss:0.029538954192673172
#
# Epoch 995
#  Accuracy: 1.0
#  Loss:0.02951447054012898
#
# Epoch 996
#  Accuracy: 1.0
#  Loss:0.02949002333118532
#
# Epoch 997
#  Accuracy: 1.0
#  Loss:0.029465612496765263
#
# Epoch 998
#  Accuracy: 1.0
#  Loss:0.029441237968056366
#
# Epoch 999
#  Accuracy: 1.0
#  Loss:0.02941689967650822
#
# Epoch 1000
#  Accuracy: 1.0
#  Loss:0.02939259755382988

# %% [markdown]
# ## 6. Analyze the result
# To analyze the result compute the losses and the accuracy of the test set. Also make a plot of the training loss and training accuracy as function of the epoch.

# %%
# compute the accuracy and losses of the test set
a0 = X_test
z1 = W1@a0+b1
a1 = sigmoid(z1)
z2 = W2@a1+b2        
a2 = softmax(z2)

interim = np.round(a2)==Y_test

accuracy = np.sum(interim[1,:])/len(X_test.T)

loss = - np.mean(Y_test*np.log(a2))

print(f"Test accuracy: {accuracy} \n Test loss: {loss}")
# Out:
# Test accuracy: 1.0
#  Test loss: 0.036521927877235134

# %%
# plot the loss and accuracy as function of the epoch number
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
plt.sca(ax1)
plt.plot(accuracies)
plt.xlabel('epoch')
plt.ylabel('train accuracy')

plt.sca(ax2)
plt.plot(losses)
plt.xlabel('epoch')
plt.ylabel('train loss')
# Out:
# Text(0, 0.5, 'train loss')

# %% [markdown]
# Below you find some code to plot the data and the model prediction.

# %%
# visualize the results

# plot the model as a filled contour plot
# build mesh of gridpoints
x1_min, x1_max = X[0,:].min(), X[0,:].max()
x2_min, x2_max = X[1,:].min(), X[1,:].max()
xx1, xx2 = np.meshgrid(np.linspace(x1_min, x1_max), np.linspace(x2_min, x2_max))

# compute hypothesis on the meshgrid 
# first create a 2xM ndarray with the values of the scores on the mesh 
X_mesh = np.vstack((xx1.ravel(), xx2.ravel()))

# compute the output of the network
a1 = sigmoid(W1 @ X_mesh + b1)
a2 = softmax(W2 @ a1 + b2)
h = a2[0] # select either one of the two features
h = h.reshape(xx1.shape)

# plot the contour level(s)
levels = [0.0, 0.5, 1.0]
plt.contourf(xx1, xx2, h, levels, alpha=0.3)

# plot the data
mask = Y == 1
plt.scatter(*X[:2, mask], s=50, c='g', marker='o', label='OK')
plt.scatter(*X[:2,~mask], s=50, c='r', marker='o', label='failed')
plt.legend()
plt.xlabel('Normalized Score test 1')
plt.ylabel('Normalized Score test 2')
# Out:
# Text(0, 0.5, 'Normalized Score test 2')
